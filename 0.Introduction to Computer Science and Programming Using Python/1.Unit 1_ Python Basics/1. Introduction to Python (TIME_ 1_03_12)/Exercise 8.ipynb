# %% [markdown]
# Ejercicio 8
# 12 puntos posibles (calificables)
# TIEMPO ESTIMADO PARA REALIZARLO: 6 minutos
# Tenga en cuenta que tendrá que responder a todas las preguntas antes de poder hacer clic en el botón Comprobar.
#
# Para cada una de las siguientes expresiones, indique el valor devuelto, o si la evaluación diera lugar a un error, escriba la palabra "error" (tenga en cuenta que es una palabra, no una cadena, sin comillas). Aunque podría simplemente escribir estas expresiones en su IDE, le animamos a que las responda directamente, ya que esto le ayudará a reforzar su comprensión de las expresiones básicas de Python.

# %%
3 > 4
# Out:
# False

# %%
4.0 > 3.999
# Out:
# True

# %%
4 > + 4
# Out:
# False

# %%
2 + 2 == 4
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not False
# Out:
# True

# %%
3.0 - 1.0 != 5.0 - 3.0
# Out:
# False

# %%
3 > 4 or (2 < 3 and 9 > 10)
# Out:
# False

# %%
4 > 5 or 3 < 4 and 9 > 8
# Out:
# True

# %%
not(4 > 3 and 100 > 6)
# Out:
# False
