# %% [markdown]
# Exercises 3
# 5 puntos posibles (calificables)
# ESTIMATED TIME TO COMPLETE: 5 minutes
# Note that you will have to answer all questions before you can click the Check button.

# %% [markdown]
# ¿Verdadero o falso? Una computadora de programa almacenado está diseñada para calcular con precisión un cálculo, como una raíz cuadrada o la trayectoria de un misil.

# %% [markdown]
# False correcto

# %% [markdown]
# 2. ¿Verdadero o falso? Una computadora de programa fijo está diseñada para ejecutar cualquier cálculo, interpretando una secuencia de instrucciones de programa que se leen en ella.

# %% [markdown]
# False

# %% [markdown]
# 3. A program counter

# %% [markdown]
# apunta a la computadora a la siguiente instrucción para ejecutar en el programa. correcto

# %% [markdown]
# 4. ¿Qué significa cuando decimos que "la computadora recorre la secuencia ejecutando algún cálculo"?

# %% [markdown]
# La computadora ejecuta las instrucciones principalmente en una secuencia lineal, excepto que a veces salta a un lugar diferente en la secuencia.

# %% [markdown]
# 5. ¿Verdadero o falso? Para calcular todo lo que es computable, cada computadora debe poder manejar las dieciséis operaciones más primitivas.

# %% [markdown]
# False

# %% [markdown]
# ![desdf.PNG](data:image/png;base64,...)

# %% [markdown]
# ![ddfd.PNG](data:image/png;base64,...)
