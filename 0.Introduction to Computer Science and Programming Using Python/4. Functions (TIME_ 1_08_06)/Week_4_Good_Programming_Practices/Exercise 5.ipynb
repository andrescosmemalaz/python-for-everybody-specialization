# %% [markdown]
# TIEMPO ESTIMADO PARA TERMINAR: 10 minutos
#
# Introduce el valor de las expresiones de abajo.
#
# Para sacar el máximo provecho de este problema, intenta averiguar las respuestas leyendo el código, no ejecutándolo. Ejecuta el código sólo cuando hayas agotado algunas de tus comprobaciones.
#
# Sugerencia: Si estás confundido, puede ser útil dibujar un diagrama de entorno similar al que se presentó en la clase.

# %%
def foo(x, y = 5):
   def bar(x):
      return x + 1
   return bar(y * 2)
# Out:
# 11

# %%
foo(3)
# Out:
# 11

# %%
def foo(x, y = 5):
   def bar(x):
      return x + 1
   return bar(y * 2)

# %%
foo(3, 0)
# Out:
# 1

# %%
def foo (x):
   def bar (z, x = 0):
      return z + x
   return bar(3, x)

foo(2)
# Out:
# 5

# %%
def foo (x):
   def bar (z, x = 0):
      return z + x
   return bar(3)

foo(5)
# Out:
# 3
