# %% [markdown]
# Ejercicio 2
# 14 puntos posibles (calificables)
# TIEMPO ESTIMADO PARA REALIZARLO: 12 minutos
# Tenga en cuenta que tendrá que responder a todas las preguntas antes de poder hacer clic en el botón de verificación.
#
# Transcripción
#
# Tienes las siguientes definiciones de funciones:

# %%
def a(x):
   '''
   x: int or float.
   '''
   return x + 1

def b(x):
   '''
   x: int or float.
   '''
   return x + 1.0
  
def c(x, y):
   '''
   x: int or float. 
   y: int or float.
   '''
   return x + y

def d(x, y):
   '''
   x: Can be of any type.
   y: Can be of any type.
   '''
   return x > y

def e(x, y, z):
   '''
   x: Can be of any type.
   y: Can be of any type.
   z: Can be of any type.
   '''
   return x >= y and x <= z

def f(x, y):
   '''
   x: int or float.
   y: int or float
   '''
   x + y - 2

# %% [markdown]
# A continuación se muestra una transcripción de una sesión con el shell de Python. Indique el tipo y el valor de las expresiones que se están evaluando. Si la evaluación de una expresión causaría un error, seleccione NoneType y escriba 'error' en la casilla. Si el valor de una expresión es una función, seleccione función como tipo y escriba 'función' en la casilla.

# %%
a(6)
# Out:
# 7

# %%
a(-5.3)
# Out:
# -4.3

# %%
a(a(a(6)))
# Out:
# 9

# %%
c(a(1), b(1))
# Out:
# 4.0

# %%
d('apple', 11.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a64b5e917786> in <module>()
# ----> 1 d('apple', 11.1)
#
# <ipython-input-1-0c44a8999595> in d(x, y)
#      23    y: Can be of any type.
#      24    '''
# ---> 25    return x > y
#      26
#      27 def e(x, y, z):
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %%
e(a(3), b(4), c(3, 4))
# Out:
# False

# %%
f
# Out:
# <function __main__.f>

# %% [markdown]
# Ejercicio 3
# 8 puntos posibles (calificables)
# TIEMPO ESTIMADO PARA REALIZARLO: 8 minutos
# Tenga en cuenta que tendrá que responder a todas las preguntas antes de poder pulsar el botón de verificación.
#
# A continuación se muestra una transcripción de una sesión con el shell de Python. Indique el tipo y el valor de las expresiones evaluadas. Si la evaluación de una expresión causaría un error, seleccione NoneType y escriba "error" en la casilla. Si el resultado es una función, selecciona function y escribe 'function' en la casilla. Como siempre, intente hacer este problema a mano antes de recurrir a su intérprete.
#
# Suponga que se han hecho las siguientes definiciones:

# %%
def a(x, y, z):
     if x:
         return y
     else:
         return z

# %%
a(7,8,9)
# Out:
# 8

# %%
def b(q, r):
    return a(q>r, q, r)

# %%
b(7,9)
# Out:
# 9

# %%
a(False, 2, 3)
# Out:
# 3

# %%
b(3, 2)
# Out:
# 3

# %%
a(3>2, a, b)
# Out:
# <function __main__.a>

# %%
b(a, b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ec42cc72733e> in <module>()
# ----> 1 b(a, b)
#
# <ipython-input-11-7b41a394e00b> in b(q, r)
#       1
#       2 def b(q, r):
# ----> 3     return a(q>r, q, r)
#
# TypeError: '>' not supported between instances of 'function' and 'function'

# %% [markdown]
# Ejercicio 4
# 4 puntos posibles (calificables)
# TIEMPO ESTIMADO PARA REALIZARLO: 6 minutos
#
# A continuación se muestra la transcripción de una sesión con la shell de Python. Indique el tipo y el valor de las expresiones que se están evaluando. Si la evaluación de una expresión provocaría un error, seleccione NoneType y escriba "error" en la casilla. Si el resultado es una función, seleccione function y escriba 'function' en la casilla.
#
# Para sacar el máximo provecho de este problema, intenta averiguar las respuestas leyendo el código, no ejecutándolo. Ejecuta el código en tu intérprete sólo después de haber comprobado las respuestas unas cuantas veces.
#
# Sugerencia: Si estás confundido, puede resultarte útil dibujar un diagrama de entorno similar al que se presentó en la clase.

# %%
a = 10
def f(x):
  return x + a

# %%
  a = 3
  f(1)
# Out:
# 4

# %%
x = 12
def g(x):
      x = x + 1
      def h(y):
          return x + y
      return h(6)

# %%
g(x)
# Out:
# 19
