# %% [markdown]
# Ejercicio 6
# 30 puntos posibles (calificables)
# TIEMPO ESTIMADO PARA REALIZARLO: 20 minutos
#
# Como veremos en las siguientes clases, todo en Python es un objeto. Los objetos son especiales porque podemos asociar al objeto funciones especiales, denominadas métodos del objeto. En este problema trabajarás con objetos cadena, y sus métodos incorporados.
#
# Puedes encontrar una descripción completa de los métodos disponibles para los objetos cadena en la referencia de la biblioteca de Python sobre los métodos cadena.
#
# En este ejercicio, queremos que obtengas algo de experiencia en el uso de métodos como funciones. La convención para los métodos de objetos es utilizar la notación "punto", de modo que si s es una cadena, al evaluar s.upper se devolverá la función real, y al evaluar s.upper() se evaluará la propia función (en este caso devuelve una nueva cadena, ya que las cadenas son inmutables) con todos los caracteres ahora en mayúsculas. Un ejemplo de esto es el siguiente:

# %%
s = 'abc'
s.capitalize
# Out:
# <function str.capitalize>

# %%
s.capitalize()

# %% [markdown]
# Para cada una de las expresiones de este problema, especifica su tipo y valor. Si genera un error, selecciona el tipo 'NoneType' y pon la palabra 'error' en la casilla para el valor. Si es una función, selecciona el tipo 'función' y pon la palabra 'función' en la casilla para el valor.
#
# Supongamos que hemos hecho las siguientes asignaciones:

# %%
str1 = 'exterminate!' 
str2 = 'number one - the larch'

# %%
str1.upper
# Out:
# <function str.upper>

# %%
str1.upper()
# Out:
# 'EXTERMINATE!'

# %%
str1
# Out:
# 'exterminate!'

# %%
str1.isupper()
# Out:
# False

# %%
str1.islower()
# Out:
# True

# %%
str2 = str2.capitalize()
str2
# Out:
# 'Number one - the larch'

# %%
str2.swapcase()
# Out:
# 'nUMBER ONE - THE LARCH'

# %%
str1.index('e')
# Out:
# 0

# %%
str2.index('n')
# Out:
# 8

# %%
str2.find('n')
# Out:
# 8

# %%
str2.index('!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-dbd22adbb8d3> in <module>()
# ----> 1 str2.index('!')
#
# ValueError: substring not found

# %%
str2.find('!')
# Out:
# -1

# %%
str1.count('e')
# Out:
# 3

# %%
str1 = str1.replace('e', '*')

# %%
str1
# Out:
# '*xt*rminat*!'

# %%
str2.replace('one', 'seven')
# Out:
# 'Number seven - the larch'

# %% [markdown]
# # ***Exercise: fourth power***

# %% [markdown]
# TIEMPO ESTIMADO PARA TERMINAR: 2 minutos
#
# Escribe una función en Python, cuartaPotencia, que tome un número y devuelva ese valor elevado a la cuarta potencia.
#
# Debes usar el procedimiento cuadrado que definiste en un ejercicio anterior (no necesitas redefinir cuadrado en este cuadro; cuando llames a cuadrado, el calificador usará nuestra definición).
#
# Esta función toma un número y devuelve un número.

# %%
def fourthPower(x):
    '''
    x: int or float.
    '''
    z = x * x* x* x 
    print(z)
fourthPower(4)
# Out:
# 256

# %% [markdown]
# # ***Exercise: odd***

# %% [markdown]
# TIEMPO ESTIMADO PARA TERMINAR: 3 minutos
#
# Escribe una función en Python, impar, que tome un número y devuelva True cuando el número es impar y False en caso contrario.
#
# Debe utilizar el operador % (mod), no si.
#
# Esta función toma un número y devuelve un booleano.

# %%
def odd(x):
    '''
    x: int

    returns: True if x is odd, False otherwise
    '''
    # Your code here
    if x%2 == 0:
      print("par")
    else:
      print("Impar")

# %%
odd(15001)
# Out:
# Impar

# %% [markdown]
# # *`***Exercise: power iter***`*

# %% [markdown]
# Ejercicio: poder del iter
# 0.0/5.0 puntos (calificado)
# TIEMPO ESTIMADO PARA REALIZARLO: 6 minutos
#
# Escribe una función iterPower(base, exp) que calcule la exponencial utilizando simplemente la multiplicación sucesiva. Por ejemplo, iterPower(base, exp) debería calcular multiplicando la base por sí misma exp veces. Escribe una función de este tipo a continuación.
#
# Esta función debe tomar dos valores - base puede ser un flotador o un entero; exp será un entero 0. Debe devolver un valor numérico. Su código debe ser iterativo - no se permite el uso del operador **.

# %%
def iterPower(base, exp):
    '''
    base: int or float.
    exp: int >= 0
 
    returns: int or float, base^exp
    '''
    # Your code here

# %%
exp = 0
pote = input("introduzca número ")
while exp <= 5:
    exp = exp + 1 
    pote = pote * exp
print(pote)
# Out:
# introduzca número 8
# ...

# %% [markdown]
# Part 1: Function Types

# %% [markdown]
# For each of the following functions, specify the type of its return. You can assume each function is called with an appropriate argument, as specified by its docstring.
#
# If the output can be either an int or a float, select num, which isn't a real Python type, but which we'll use to indicate that either basic numeric type is legal.
#
# In fact, in Python, booleans True and False can be operated on as if they were the integers 1 and 0; but it is ugly and confusing to take advantage of this fact, and we will resolutely pretend that it isn't true.

# %%
def a(x):
   '''
   x: int or float.
   '''
   return x + 1

# %%
print(type(a(5)),a(5))
# Out:
# <class 'int'> 6

# %%
def b(x):
   '''
   x: int or float.
   '''
   return x + 1.0

# %%
print(type(b(5)),b(5))
# Out:
# <class 'float'> 6.0

# %%
def c(x, y):
   '''
   x: int or float. 
   y: int or float.
   '''
   return x + y

# %%
type(c(1, 5))
# Out:
# int

# %%
print(c(1, 5))
# Out:
# 6

# %%
def d(x, y):
   '''
   x: Can be int or float.
   y: Can be int or float.
   '''
   return x > y

# %%
print(type(d(5,1)),d(5,1))
# Out:
# <class 'bool'> True

# %%
def e(x, y, z):
   '''
   x: Can be int or float.
   y: Can be int or float.
   z: Can be int or float.
   '''
   return x >= y and x <= z

# %%
print(type(e(5,1,8)),e(5,1,8))
# Out:
# <class 'bool'> True

# %%
def f(x, y):
   '''
   x: int or float.
   y: int or float
   '''
   x + y - 2

# %%
print(type(f(5,1)),f(5,1))
# Out:
# <class 'NoneType'> None

# %% [markdown]
# # ESTIMATED TIME TO COMPLETE: 3 minutes

# %% [markdown]
# Write a Python function, square, that takes in one number and returns the square of that number.
#
# This function takes in one number and returns one number.

# %%
def square(x):
    '''
    x: int or float.
    '''
    # Your code here
    x=x*x
    return x

# %%
square(7)
# Out:
# 49

# %% [markdown]
# ESTIMATED TIME TO COMPLETE: 5 minutes
#
# Write a Python function, evalQuadratic(a, b, c, x), that returns the value of the quadratic .
#
# This function takes in four numbers and returns a single number.

# %% [markdown]
# a * x^2 + b * x + c

# %%
def evalQuadratic(a, b, c, x):
    '''
    a, b, c: numerical values for the coefficients of a quadratic equation
    x: numerical value at which to evaluate the quadratic.
    '''
    # Your code here
    z = a * x*x + b * x + c
    return z

# %%
evalQuadratic(4,5,7,8)
# Out:
# 303

# %% [markdown]
# Exercise 4
# 4 puntos posibles (calificables)
# ESTIMATED TIME TO COMPLETE: 6 minutes

# %% [markdown]
# Below is a transcript of a session with the Python shell. Provide the type and value of the expressions being evaluated. If evaluating an expression would cause an error, select NoneType and write 'error' in the box. If the result is a function, select function and write 'function' in the box.
#
# To get the most out of this problem, try to figure out the answers by reading the code, not running it. Run the code in your interpreter only after you've checked your answers a few times.
#
# Hint: If you are confused, you may find it helpful to draw out an environment diagram similar to what was presented in lecture.

# %%
a = 10
def f(x):
    return x + a
a = 3
f(1)
# Out:
# 4

# %% [markdown]
# Exercise 5

# %% [markdown]
# ESTIMATED TIME TO COMPLETE: 10 minutes
#
# Enter the value of the expressions below.
#
# To get the most out of this problem, try to figure out the answers by reading the code, not running it. Run the code only after you've used up a few of your checks.
#
# Hint: If you are confused, you may find it helpful to draw out an environment diagram similar to what was presented in lecture.

# %%
def foo(x, y = 5):
   def bar(x):
      return x + 1
   return bar(y * 2)
          
foo(3)
# Out:
# 11

# %%
def andres(x, z = 4):
  def maximo(x):
    return x + 10
  return maximo(z*4)

# %%
andres(1)
# Out:
# 26

# %%
def foo(x, y = 5):
   def bar(x):
      return x + 1
   return bar(y * 2)
          
foo(3, 0)
# Out:
# 1

# %%
def foo (x):
   def bar (z, x = 0):
      return z + x
   return bar(3, x)

foo(2)
# Out:
# 5

# %%
def foo (x):
   def bar (z, x = 0):
      return z + x
   return bar(3)

foo(5)
# Out:
# 3

# %% [markdown]
# Exercise 6

# %% [markdown]
# ESTIMATED TIME TO COMPLETE: 20 minutes
#
# As we'll see in subsequent lectures, everything in Python is an object. Objects are special because we can associate special functions, referred to as object methods, with the object. In this problem you'll be working with string objects, and their built-in methods.
#
# A complete description of the methods available to string objects can be found in the Python library reference on string methods.
#
# In this exercise, we want you to get some experience in using methods as functions. The convention for object methods is to use the "dot" notation, so that if s is a string, evaluating s.upper will return the actual function, and evaluating s.upper() will cause the function itself to be evaluated (in this case it returns a new string, since strings are immutable) with every character now in upper case. An example of this follows:

# %%
s = 'abc'

# %%
s.capitalize
# Out:
# <function str.capitalize>

# %%
s.capitalize()
# Out:
# 'Abc'

# %%
str1 = 'exterminate!'

# %%
str2 = 'number one - the larch'

# %% [markdown]
# # ***xercise: fourth power***

# %% [markdown]
# ESTIMATED TIME TO COMPLETE: 2 minutes
#
# Write a Python function, fourthPower, that takes in one number and returns that value raised to the fourth power.
#
# You should use the square procedure that you defined in an earlier exercise (you don't need to redefine square in this box; when you call square, the grader will use our definition).
#
# This function takes in one number and returns one number.

# %%
def fourthPower(x):
  return x ** 4

# %%
def fourthPower(x):
   '''
   x: int or float.
   '''
   return square(square(x))

# %%
fourthPower(2)
# Out:
# 16

# %% [markdown]
# # ***ESTIMATED TIME TO COMPLETE: 3 minutes***

# %% [markdown]
# Write a Python function, odd, that takes in one number and returns True when the number is odd and False otherwise.
#
# You should use the % (mod) operator, not if.
#
# This function takes in one number and returns a boolean.

# %%
def pair(x):
    '''
    x: int

    returns: True if x is odd, False otherwise
    '''
    return x%2==0
    # Your code here

# %%
pair(4)
# Out:
# True

# %%
def odd(x):
    '''
    x: int
    '''
    return (x % 2 == 1)

# %%
odd(4)
# Out:
# False

# %% [markdown]
# # ***Exercise: power iter***

# %% [markdown]
# ESTIMATED TIME TO COMPLETE: 6 minutes
#
# Write an iterative function iterPower(base, exp) that calculates the exponential  by simply using successive multiplication. For example, iterPower(base, exp) should compute  by multiplying base times itself exp times. Write such a function below.
#
# This function should take in two values - base can be a float or an integer; exp will be an integer  0. It should return one numerical value. Your code must be iterative - use of the ** operator is not allowed.

# %%
def iterPower(base, exp):
    '''
    base: int or float.
    exp: int >= 0
 
    returns: int or float, base^exp
    '''
    # Your code here
    veces = 0
    mult = 1
    while veces < exp :
      veces  = veces + 1
      mult = mult * base 
      
    return mult
    # z = 0
    # exp = 0 
    # while z <= exp:
    #   exp = exp + 1
    #   resultado = base * base
    #   return resultado

# %%
iterPower(2,10)
# Out:
# 1024

# %%
def iterPower(base, exp):
    '''
    base: int or float.
    exp: int >= 0

    returns: int or float, base^exp
    '''
    result = 1
    while exp > 0:
        result *=base
        exp -= 1
    return result

# %%
iterPower(2,8)
# Out:
# 256

# %% [markdown]
# # ***Exercise: power recur***

# %% [markdown]
# ESTIMATED TIME TO COMPLETE: 7 minutes
#
# In Problem 1, we computed an exponential by iteratively executing successive multiplications. We can use the same idea, but in a recursive function.
#
# Write a function recurPower(base, exp) which computes  by recursively calling itself to solve a smaller version of the same problem, and then multiplying the result by base to solve the initial problem.
#
# This function should take in two values - base can be a float or an integer; exp will be an integer . It should return one numerical value. Your code must be recursive - use of the ** operator or looping constructs is not allowed.

# %%
def recurPower(base, exp):
    '''
    base: int or float.
    exp: int >= 0

    returns: int or float, base^exp
    '''
    # Base case is when exp = 0
    if exp <= 0:
        return 1

    # Otherwise, exp must be > 0, so return 
    #  base* base^(exp-1). This is the recursive case.
    return base * recurPower(base, exp - 1)

# %%
recurPower(2, 10)
# Out:
# 1024

# %% [markdown]
# # ***Exercise: gcd iter***

# %% [markdown]
# # ***ESTIMATED TIME TO COMPLETE: 5 minutes***

# %% [markdown]
# The greatest common divisor of two positive integers is the largest integer that divides each of them without remainder. For example,
#
# gcd(2, 12) = 2
#
# gcd(6, 12) = 6
#
# gcd(9, 12) = 3
#
# gcd(17, 12) = 1
#
# Write an iterative function, gcdIter(a, b), that implements this idea. One easy way to do this is to begin with a test value equal to the smaller of the two input arguments, and iteratively reduce this test value by 1 until you either reach a case where the test divides both a and b without remainder, or you reach 1.

# %%
def gcdIter(a, b):
    '''
    a, b: positive integers
    
    returns: a positive integer, the greatest common divisor of a & b.
    '''
    testValue = min(a, b)

    # Keep looping until testValue divides both a & b evenly
    while a % testValue != 0 or b % testValue != 0:
        testValue -= 1

    return testValue

# %%
gcdIter(18,12)
# Out:
# 6

# %% [markdown]
# Exercise: gcd recur

# %% [markdown]
# TIEMPO ESTIMADO PARA COMPLETAR: 6 minutos El máximo común divisor de dos números enteros positivos es el número entero más grande que divide a cada uno de ellos sin resto. Por ejemplo, mcd (2, 12) = 2 mcd (6, 12) = 6 mcd (9, 12) = 3 mcd (17, 12) = 1

# %% [markdown]
# Un ingenioso truco matemático (debido a Euclides) facilita la búsqueda de los máximos divisores comunes. Suponga que ayb son dos números enteros positivos: Si b = 0, entonces la respuesta es a De lo contrario, mcd (a, b) es lo mismo que mcd (b, a% b)

# %% [markdown]
# Consulte este sitio web para ver un ejemplo del algoritmo de Euclid que se utiliza para encontrar el gcd. Escribe una función gcdRecur (a, b) que implemente esta idea de forma recursiva. Esta función toma dos enteros positivos y devuelve un entero.

# %% [markdown]
# https://en.wikipedia.org/wiki/Euclidean_algorithm#Worked_example

# %%
def gcdRecur(a, b):
    '''
    a, b: positive integers
    
    returns: a positive integer, the greatest common divisor of a & b.
    '''
    # Base case is when b = 0
    if b == 0:
        return a

    # Recursive case
    return gcdRecur(b, a % b)

# %%
gcdRecur(14, 12)
# Out:
# 2

# %% [markdown]
# # ***Exercise: is in***

# %% [markdown]
# ESTIMATED TIME TO COMPLETE: 18 minutes
#
# We can use the idea of bisection search to determine if a character is in a string, so long as the string is sorted in alphabetical order.
#
# First, test the middle character of a string against the character you're looking for (the "test character"). If they are the same, we are done - we've found the character we're looking for!
#
# If they're not the same, check if the test character is "smaller" than the middle character. If so, we need only consider the lower half of the string; otherwise, we only consider the upper half of the string. (Note that you can compare characters using Python's < function.)
#
# Implement the function isIn(char, aStr) which implements the above idea recursively to test if char is in aStr. char will be a single character and aStr will be a string that is in alphabetical order. The function should return a boolean value.
#
# As you design the function, think very carefully about what the base cases should be.

# %%
def isIn(char, aStr):
   '''
   char: a single character
   aStr: an alphabetized string
   
   returns: True if char is in aStr; False otherwise
   '''
   # Base case: If aStr is empty, we did not find the char.
   if aStr == '':
      return False

   # Base case: if aStr is of length 1, just see if the chars are equal
   if len(aStr) == 1:
      return aStr == char

   # Base case: See if the character in the middle of aStr equals the 
   #   test character 
   midIndex = len(aStr)//2
   midChar = aStr[midIndex]
   if char == midChar:
      # We found the character!
      return True
   
   # Recursive case: If the test character is smaller than the middle 
   #  character, recursively search on the first half of aStr
   elif char < midChar:
      return isIn(char, aStr[:midIndex])

   # Otherwise the test character is larger than the middle character,
   #  so recursively search on the last half of aStr
   else:
      return isIn(char, aStr[midIndex+1:])

# %%
isIn("char", "charStr")
# Out:
# False

# %% [markdown]
# # ***Exercise 7***

# %% [markdown]
# Exercise 7
# 4 puntos posibles (calificables)
# Assume the two files below are in the same folder. You run inventory.py. What happens?
# TWO FILES
#
# batteries.py

# %%
aa = "AA"
aaa = "AAA"
c = "C"
d = "D"

# %%
aa = "aa"
tripleA = "aaa"
print(aa)
# Out:
# aa

# %% [markdown]
# Assume the two files below are in the same folder. You run inventory.py. What happens?
# TWO FILES
#
# FILE: batteries.py

# %%
aa = "AA"
aaa = "AAA"
c = "C"
d = "D"

# %%
aa = "aa"
tripleA = "aaa"
print(batteries.aa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-822e3022de27> in <module>()
#       1 aa = "aa"
#       2 tripleA = "aaa"
# ----> 3 print(batteries.aa)
#
# NameError: name 'batteries' is not defined

# %% [markdown]
# Assume the two files below are in the same folder. You run inventory.py. What happens?
# TWO FILES
#
# FILE: batteries.py
#
# aa = "AA"

# %% [markdown]
# FILE: batteries.py
#
# aa = "AA"
# aaa = "AAA"
# c = "C"
# d = "D"

# %% [markdown]
# FILE: inventory.py
#
# import batteries
# aa = "aa"
# tripleA = "aaa"
# print(batteries.aa)

# %% [markdown]
# FILE: batteries.py
#
# aa = "AA"
# aaa = "AAA"
# c = "C"
# d = "D"

# %% [markdown]
# FILE: inventory.py
#
# from batteries import *
# aa = "aa"
# print(aa, aaa, c, d)

# %% [markdown]
# # ***Grader***

# %% [markdown]
# A regular polygon has n number of sides. Each side has length s.
#
# The area of a regular polygon is:
# The perimeter of a polygon is: length of the boundary of the polygon
# Write a function called polysum that takes 2 arguments, n and s. This function should sum the area and square of the perimeter of the regular polygon. The function returns the sum, rounded to 4 decimal places.

# %% [markdown]
# ![exercise.PNG](data:image/png;base64,...)

# %%
import scipy
import sys
def polysum(n,s):
  numerador = area = 0.25 * n * s**2
  denominador = scipy.tan(math.radians(1)/7)
  area = numerador/denominador
  perimetro = n * s
  frase = "el area es",area,"el perìmetro es", perimetro
  return frase
  sys.os()

# %%
polysum(4,6)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: scipy.tan is deprecated and will be removed in SciPy 2.0.0, use numpy.tan instead
#   """
# ('el area es', 14438.506517354312, 'el perìmetro es', 24)

# %% [markdown]
# # ***Peer Assessment***

# %% [markdown]
# Una gran parte de la programación consiste en ser capaz de escribir un código comprensible y leer el código de otras personas. Los calificadores de código del curso son capaces de calificar la corrección pero no el estilo. Este problema te dará práctica con (1) escribir código que será leído por otros y (2) entender el código que otros escribieron.
#
# Subirás un archivo .py y tu código será calificado por 3 de tus compañeros en cuanto a su estilo de codificación: legibilidad, comentarios del código, nombres de variables y modularidad. En la casilla puedes escribir cualquier cosa, como "archivo adjunto". Es un ejercicio opcional, pero vale la pena intentarlo.

# %% [markdown]
# Regular Polygons: polysum
#
# A regular polygon has 'n' number of sides. Each side has length 's'.
#
# * The area of regular polygon is: (0.25*n*s^2)/tan(pi/n)
# * The perimeter of a polygon is: length of the boundary of the polygon
#
# Write a function called 'polysum' that takes 2 arguments, 'n' and 's'. This function should sum the area and square of the perimeter of the regular polygon. The function returns the sum, rounded to 4 decimal places.
#
# +++ IMPORTANT NOTE +++
# You must upload a .py file. Any code you enter in the box will have its spacing removed, so will be unreadable by your peers. In the box type in anything, for example, "attached".

# %%
import scipy
import sys
def polysum(n,s):
  numerador = area = 0.25 * n * s**2
  denominador = scipy.tan(math.radians(1)/7)
  area = numerador/denominador
  perimetro = n * s
  frase = "el area es",area,"el perìmetro es", perimetro
  return frase
  sys.os()

# %% [markdown]
# Cada mes, el extracto de la tarjeta de crédito vendrá con la opción de pagar una cantidad mínima de su cargo, normalmente el 2% del saldo adeudado. Sin embargo, la compañía de tarjetas de crédito gana dinero cobrando intereses sobre el saldo que no pagas. Así que, aunque pagues las cuotas de la tarjeta de crédito a tiempo, los intereses se siguen acumulando en el saldo pendiente.
#
# Digamos que has hecho una compra de 5.000 dólares con una tarjeta de crédito con un tipo de interés anual del 18% y un pago mínimo mensual del 2%. Si sólo pagas la cantidad mínima mensual durante un año, ¿cuál es el saldo restante?
#
# Puedes pensar en esto de la siguiente manera.

# %% [markdown]
# Al comienzo del mes 0 (cuando llegue el estado de cuenta de la tarjeta de crédito), suponga que debe una cantidad a la que llamaremos b0 b para el equilibrio; subíndice 0 para indicar que este es el saldo en el mes 0).
# Cualquier pago que realice durante ese mes se deducirá del saldo. Llamemos al pago que realiza en el mes 0, p0. Por lo tanto, su saldo pendiente del mes 0 , ub0, es igual a b0-p0
#
# # **`ub0 = b0 - p0`**

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# Al comienzo del mes 1, la compañía de la tarjeta de crédito le cobrará intereses sobre su saldo impago. Entonces, si su tasa de interés anual es r ,luego, al comienzo del mes 1, su nuevo saldo es su saldo impago anterior ub0, más los intereses de este saldo impago del mes. En álgebra, este nuevo equilibrio sería.

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# En el mes 1, haremos otro pago, p1 . Ese pago tiene que cubrir parte de los costes de los intereses, por lo que no se destina por completo al pago de la carga original. El saldo al principio del mes 2,b2 , puede calcularse calculando primero el saldo impagado después de pagar ,p1 y añadiendo después los intereses acumulados:

# %% [markdown]
# ![3.PNG](data:image/png;base64,...)

# %% [markdown]
# Si opta por limitarse a pagar la cuota mínima cada mes, verá que el interés compuesto reducirá drásticamente su capacidad de reducir su deuda

# %% [markdown]
# Veamos un ejemplo. Si tienes un saldo de 5.000 dólares en una tarjeta de crédito con un tipo de interés anual del 18%, y el pago mínimo mensual es del 2% del saldo actual, tendríamos el siguiente calendario de amortización si sólo pagas el pago mínimo cada mes:

# %% [markdown]
# ![4.PNG](data:image/png;base64,...)

# %% [markdown]
# Puedes ver que gran parte de tu pago va a cubrir los intereses, y si trabajas
#
# # esto hasta el mes 12, verás que después de un año,
#
# # habrás pagado $1165.63
#
# # y** sin embargo todavía deberás
#
# # $4691.11
#
# # **en lo que originalmente era una deuda de $5000.00. ¡Bastante deprimente!**

# %% [markdown]
# # ***Problem 1***

# %% [markdown]
# Escribe un programa que calcule el saldo de la tarjeta de crédito al cabo de un año si una persona sólo paga cada mes el mínimo exigido por la compañía de la tarjeta de crédito.
#
# Las siguientes variables contienen los valores que se describen a continuación:

# %% [markdown]
# 1. saldo - el saldo pendiente de la tarjeta de crédito
# 2. annualInterestRate - tipo de interés anual como decimal
# 3. monthlyPaymentRate - tasa de pago mensual mínima como decimal
#
# Para cada mes, calcule los estados de cuenta sobre el pago mensual y el saldo restante. Al final de los 12 meses, imprime el saldo restante. Asegúrate de no imprimir más de dos dígitos decimales de exactitud - así que imprime

# %% [markdown]
# Saldo restante: 813,41

# %% [markdown]
# en lugar de

# %% [markdown]
# Saldo restante: 813,4141998135

# %% [markdown]
# Así, su programa sólo imprime una cosa: el saldo restante al final del año en el formato

# %% [markdown]
# Saldo restante: 4784.0

# %% [markdown]
# A continuación encontrará un resumen de los cálculos necesarios:

# %% [markdown]
# ```
# Tipo de interés mensual= (Tipo de interés anual) / 12,0
# Pago mínimo mensual = (Tipo de pago mínimo mensual) x (Saldo anterior)
# Saldo mensual impagado = (Saldo anterior) - (Cuota mínima mensual)
# Saldo actualizado cada mes = (Saldo mensual impagado) + (Tipo de interés mensual x Saldo mensual impagado)
# ```

# %% [markdown]
# A continuación le ofrecemos ejemplos de casos de prueba. Le sugerimos que desarrolle su código en su propia máquina, y que se asegure de que su código pasa los casos de prueba de muestra, antes de pegarlo en el cuadro de abajo.

# %% [markdown]
# Casos de prueba para probar su código. Asegúrese de probarlos en su propia máquina - ¡y de obtener el mismo resultado! - antes de ejecutar su código en esta página web.
#
# Problema 1 Casos de prueba
#
# Nota: Dependiendo de dónde redondee en este problema, sus respuestas pueden estar desviadas por unos pocos centavos en cualquier dirección. No se preocupe si su solución está dentro de +/- 0.05 de la respuesta correcta. Asegúrate de probarlo en tu propia máquina - ¡y de que obtienes el mismo resultado! - antes de ejecutar su código en esta página web.
#
# Casos de prueba:

# %% [markdown]
#  # Test Case 1:
# 	      balance = 42
# 	      annualInterestRate = 0.2
# 	      monthlyPaymentRate = 0.04
#
# 	      # Result Your Code Should Generate Below:
# 	      Remaining balance: 31.38
#
#           # To make sure you are doing calculation correctly, this is the
#           # remaining balance you should be getting at each month for this example
#             Month 1 Remaining balance: 40.99
#             Month 2 Remaining balance: 40.01
#             Month 3 Remaining balance: 39.05
#             Month 4 Remaining balance: 38.11
#             Month 5 Remaining balance: 37.2
#             Month 6 Remaining balance: 36.3
#             Month 7 Remaining balance: 35.43
#             Month 8 Remaining balance: 34.58
#             Month 9 Remaining balance: 33.75
#             Month 10 Remaining balance: 32.94
#             Month 11 Remaining balance: 32.15
#             Month 12 Remaining balance: 31.38
#
# ```
# # Tiene formato de código
# ```

# %% [markdown]
#  # Caso de prueba 1:
# 	      saldo = 42
# 	      tasa de interés anual = 0.2
# 	      tasa de pago mensual = 0.04
#
# 	      # Resultado que su código debería generar a continuación:
# 	      Saldo restante: 31.38
#
#           # Para asegurarse de que está haciendo el cálculo correctamente, este es el
#           # saldo restante que debería obtener en cada mes para este ejemplo
#             Mes 1 Saldo restante: 40.99
#             Saldo restante del mes 2 40.01
#             Mes 3 Saldo restante: 39.05
#             Mes 4 Saldo restante: 38.11
#             Mes 5 Saldo restante: 37.2
#             Mes 6 Saldo restante: 36.3
#             Mes 7 Saldo restante: 35.43
#             Mes 8 Saldo restante: 34.58
#             Mes 9 Saldo restante: 33.75
#             Mes 10 Saldo restante: 32.94
#             Mes 11 Saldo restante: 32.15
#             Mes 12 Saldo restante: 31.38
#
# ```
# # Tiene formato de código
# ```

# %% [markdown]
# Caso de prueba 2:
# ```
# # 	      saldo = 484
# 	      tasa de interés anual = 0,2
# 	      tasa de pago mensual = 0.04
#
# 	      El resultado que su código debería generar es el siguiente
# 	      Saldo restante: 361.61
# ```

# %%
saldo  = 42 
tasa_interes = 0.2
tasa_pago_mensuales = 0.04
interes = 0 
x = 0
while x < 12 :
  Balance = saldo + interes 
  pago_min = tasa_pago_mensuales * Balance
  saldo = Balance - pago_min
  interes = (tasa_interes/12)* saldo
  x = x + 1 
  print(x,"",round(Balance,2)," ",round(pago_min,2)," ",round(saldo,2)," ",round(interes,2))
Balance = saldo + interes 
print("El saldado restante al mes 12 es ", round(Balance,2))
# Out:
# 1  42   1.68   40.32   0.67
# 2  40.99   1.64   39.35   0.66
# 3  40.01   1.6   38.41   0.64
# 4  39.05   1.56   37.49   0.62
# 5  38.11   1.52   36.59   0.61
# 6  37.2   1.49   35.71   0.6
# 7  36.3   1.45   34.85   0.58
# 8  35.43   1.42   34.01   0.57
# 9  34.58   1.38   33.2   0.55
# 10  33.75   1.35   32.4   0.54
# 11  32.94   1.32   31.62   0.53
# 12  32.15   1.29   30.87   0.51
# El saldado restante al mes 12 es  31.38

# %%
print("Programa para calcular tasas en el banco")
saldo = int(input("Introduzca su saldo: "))
tasa_interes = float(input("Introduzca la tasa de interés: "))
tasa_pago_mensuales = float(input("Introduzca la tasa de pago mensual: "))
interes = 0 
x = 0
while x < 12 :
  Balance = saldo + interes 
  pago_min = tasa_pago_mensuales * Balance
  saldo = Balance - pago_min
  interes = (tasa_interes/12)* saldo
  x = x + 1 
  print(x,"",round(Balance,2)," ",round(pago_min,2)," ",round(saldo,2)," ",round(interes,2))
Balance = saldo + interes 
print("El saldado restante al mes 12 es ", round(Balance,2))
# Out:
# Programa para calcular tasas en el banco
# Introduzca su saldo: 5000
# Introduzca la tasa de interés: 0.18
# Introduzca la tasa de pago mensual: 0.02
# 1  5000   100.0   4900.0   73.5
# 2  4973.5   99.47   4874.03   73.11
# 3  4947.14   98.94   4848.2   72.72
# 4  4920.92   98.42   4822.5   72.34
# 5  4894.84   97.9   4796.94   71.95
# 6  4868.9   97.38   4771.52   71.57
# 7  4843.09   96.86   4746.23   71.19
# 8  4817.42   96.35   4721.08   70.82
# 9  4791.89   95.84   4696.05   70.44
# 10  4766.49   95.33   4671.16   70.07
# 11  4741.23   94.82   4646.41   69.7
# 12  4716.1   94.32   4621.78   69.33
# El saldado restante al mes 12 es  4691.11

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pistas
# # ***¿Sólo dos dígitos decimales de precisión?***
#
# Utiliza la función de redondeo al final de tu código.
# # ***Nueva sección***
# ¿Cómo se puede plantear este problema?
#
# Para ayudarte a empezar, aquí tienes un esquema de las etapas que probablemente deberías seguir al escribir tu código:
#
# Para cada mes:
#
# Calcular el pago mensual, basándose en el saldo del mes anterior.
#
# Actualice el saldo pendiente eliminando el pago y cargando los intereses sobre el resultado.
#
# Indicar el mes, el pago mínimo mensual y el saldo restante.
#
# Lleve la cuenta del total de lo pagado en todos los meses pasados hasta ahora.
#
# Imprima el estado de resultados con el importe total pagado y el saldo restante.
#
# Utilice estas ideas para guiar la creación de su código.

# %% [markdown]
# Importante
#
# # ***Sólo se puede pulsar "Comprobar" una vez por envío. Sólo tiene 30 comprobaciones por problema.***
#
# ** Nuestro calificador automático puede tardar unos minutos en responder con sus comentarios. Si pulsa "Comprobar" varias veces, perderá una comprobación por cada vez que pulse el botón.
#
# ** Si no está familiarizado con el funcionamiento de nuestro calificador automático, pruebe primero uno de los problemas de verificación infinita en la secuencia de clases de Funciones.
#
# ** Por favor, sea juicioso con sus comprobaciones, ya que no podemos darle más de 30 comprobaciones. Sin embargo, esto debería ser más que suficiente: si hace su desarrollo de código en su entorno local, y se asegura de que puede pasar nuestros casos de prueba, no debería necesitar más que unas pocas comprobaciones una vez que pegue su código de trabajo y probado en nuestra caja de código.
#
#
# # ***Si crees que tienes un código correcto pero está marcado como incorrecto después de hacer clic en "Comprobar"...***
#
# ** Después de enviar su código, puede ver cada caso de prueba que los calificadores ejecutan en su código. Comparan lo que su código produce con lo que se supone que debe producir nuestro código de respuesta. Haga clic en el pequeño enlace titulado "Ver resultados completos" debajo del encabezado de los resultados de la prueba.
#
# # ***"Depuración del personal: L397 Error" significa que su código tiene un bucle infinito...***
#
# ** Al hacer clic en Comprobar puede aparecer el error:
# Hubo un problema al ejecutar su solución (Staff debug: L379). No hemos podido ejecutar su solución (Staff debug: L397)..
# Esto significa que su código está tardando demasiado o tiene un bucle infinito. Pruebe su código con más casos de prueba únicos, como valores muy grandes o muy pequeños.
#
# # **No defina sus propios valores**
#
# ** Para problemas como estos, no incluya declaraciones de entrada o defina variables que le dijimos que se le darían. Nuestras pruebas automatizadas le proporcionarán los valores - así que escriba su código en el siguiente cuadro asumiendo que esas variables ya están definidas. El código que pegue en el siguiente cuadro no debe especificar los valores de las variables balance, annualInterestRate, o monthlyPaymentRate

# %% [markdown]
# # ***Problem 2***

# %% [markdown]
# # ***Problem 2 - Paying Debt Off in a Year***

# %% [markdown]
# Ahora escriba un programa que calcule el pago mínimo mensual fijo necesario para pagar el saldo de una tarjeta de crédito en 12 meses. Por pago mensual fijo, nos referimos a un único número que no cambia cada mes, sino que es una cantidad constante que se pagará cada mes.
#
# En este problema, no vamos a tratar una tasa de pago mensual mínima.
#
# Las siguientes variables contienen los valores que se describen a continuación:
#
# balance - el saldo pendiente de la tarjeta de crédito
#
# annualInterestRate - tipo de interés anual como decimal
#
# El programa debe imprimir una línea: el pago mensual más bajo que pagará toda la deuda en menos de 1 año, por ejemplo:
#
# Pago más bajo: 180

# %% [markdown]
# Supongamos que los intereses se componen mensualmente según el saldo al final del mes (después de realizar el pago de ese mes). El pago mensual debe ser un múltiplo de $10 y es el mismo para todos los meses. Observe que es posible que el saldo sea negativo utilizando este esquema de pago, lo cual está bien. A continuación encontrará un resumen de las matemáticas requeridas:

# %% [markdown]
# ```
#
# Tasa de interés mensual = (Tasa de interés anual) / 12.0
# Saldo mensual impagado = (Saldo anterior) - (Cuota mínima mensual fija)
# Saldo actualizado cada mes = (Saldo mensual impagado) + (Tipo de interés mensual x Saldo mensual impagado)
# ```

# %% [markdown]
# Casos de prueba para probar su código. Asegúrese de probarlos en su propia máquina - ¡y de obtener el mismo resultado! - antes de ejecutar su código en esta página web.
#
# Casos de prueba del problema 2
#
# Asegúrese de probarlos en su propia máquina - ¡y de obtener el mismo resultado! - antes de ejecutar su código en esta página web.
#
# Casos de prueba:

# %% [markdown]
# ```
#         Caso de prueba 1:
# 	      saldo = 3329
# 	      tasa de interés anual = 0,2
#
# 	      Resultado que debe generar su código:
# 	      -------------------
# 	      Pago más bajo: 310
#
# ```

# %% [markdown]
# ```
#  	      Test Case 2:
# 	      balance = 4773
# 	      annualInterestRate = 0.2
#
# 	      Result Your Code Should Generate:
# 	      -------------------
# 	      Lowest Payment: 440
# ```

# %% [markdown]
# ```
# 	    Test Case 3:
# 	      balance = 3926
# 	      annualInterestRate = 0.2
#
# 	      Result Your Code Should Generate:
# 	      -------------------
# 	      Lowest Payment: 360
# ```

# %%
balance = 4473
x = balance
minimum_payment = 10
count = 0

while count <= 11: 
 unpaid_balance = balance - minimum_payment
 monthly_interest = 0.2/12 * unpaid_balance
 new_balance = unpaid_balance + monthly_interest
 balance = round(new_balance, 2)
 count += 1

 if count == 12 and balance <=0:
  print(minimum_payment)    
  break

 elif count == 12 and balance > 0:
  balance = x
  minimum_payment += 10
  count = 0
# Out:
# 410

# %% [markdown]
# # ***Problema 3 - Uso de la búsqueda por bisección para hacer el programa más rápido***

# %% [markdown]
# Te habrás dado cuenta de que en el problema 2, tu pago mensual tenía que ser un múltiplo de 10 dólares. ¿Por qué lo hicimos así? Puede intentar ejecutar su código localmente para que el pago pueda ser cualquier cantidad de dólares y centavos (en otras palabras, el pago mensual es un múltiplo de $0.01). ¿Sigue funcionando tu código? Debería, pero puede notar que su código se ejecuta más lentamente, especialmente en casos con saldos y tipos de interés muy grandes. (Nota: cuando su código se ejecuta en nuestros servidores, hay límites en la cantidad de tiempo de computación que se permite a cada envío, por lo que sus observaciones de la ejecución de este experimento en el sistema de calificación podría limitarse a un mensaje de error que se queja de demasiado tiempo tomado).
#
# Entonces, ¿cómo podemos calcular una mensualidad fija más precisa que la que hicimos en el Problema 2 sin encontrarnos con el problema del código lento? Podemos hacer que este programa se ejecute más rápido utilizando una técnica introducida en la clase: ¡la búsqueda por bisección!
#
# Las siguientes variables contienen los valores que se describen a continuación:

# %% [markdown]
# saldo - el saldo pendiente de la tarjeta de crédito
#
# annualInterestRate - tipo de interés anual en forma de decimal
#
# Recapitulando el problema: buscamos el pago mensual más pequeño para poder pagar todo el saldo en un año. ¿Cuál es un límite inferior razonable para este valor de pago? 0 es la respuesta obvia, pero se puede hacer algo mejor. Si no hubiera intereses, la deuda se puede saldar con pagos mensuales de una doceava parte del saldo original, por lo que debemos pagar al menos esta cantidad cada mes. La doceava parte del saldo original es un buen límite inferior.
#
# ¿Cuál es un buen límite superior? Imaginemos que en lugar de pagar mensualmente, pagamos todo el saldo al final del año. Lo que finalmente pagamos debe ser mayor que lo que habríamos pagado en cuotas mensuales, porque los intereses se componen sobre el saldo que no pagamos cada mes. Por lo tanto, un buen límite superior para el pago mensual sería una doceava parte del saldo, después de tener sus intereses compuestos mensualmente durante todo un año.
#
# En resumen:

# %% [markdown]
# Tipo de interés mensual = (Tipo de interés anual) / 12,0
# Límite inferior del pago mensual = Saldo / 12
# Límite superior del pago mensual = (Saldo x (1 + Tipo de interés mensual)12) / 12.0
#
# Escribe un programa que utilice estos límites y la búsqueda por bisección (para más información consulta la página de Wikipedia sobre la búsqueda por bisección) para encontrar el pago mensual más pequeño hasta el céntimo (no más múltiplos de 10 dólares) de forma que podamos pagar la deuda en un año. Pruébalo con entradas grandes y fíjate en lo rápido que es (¡prueba con las mismas entradas grandes en tu solución al problema 2 para comparar!) Produzca el mismo valor de retorno que en el problema 2.
#
# Tenga en cuenta que si no utiliza la búsqueda de bisección, su código no se ejecutará - su código sólo tiene 30 segundos para ejecutarse en nuestros servidores.
#
# Casos de prueba para probar su código. Asegúrese de probarlos en su propia máquina - ¡y de obtener la misma salida! - antes de ejecutar su código en esta página web.
#
# Casos de prueba del problema 3
#
# Nota: Las pruebas automatizadas son leinient - si sus respuestas están fuera por unos pocos centavos en cualquier dirección, su código está bien.
#
# Asegúrese de probarlos en su propia máquina - ¡y de obtener el mismo resultado! - antes de ejecutar su código en esta página web.
#
# Casos de prueba:

# %% [markdown]
# ```
# Caso de prueba 1:
# 	      saldo = 320000
# 	      tasa de interés anual = 0,2
#
# 	      Resultado que debe generar su código:
# 	      -------------------
# 	      Pago más bajo: 29157,09
# ```

# %% [markdown]
# ```
# 	      Caso de prueba 2:
# 	      saldo = 999999
# 	      tasa de interés anual = 0.18
#
# 	      Resultado que debería generar su código:
# 	      -------------------
# 	      Pago más bajo: 90325,03
# ```

# %% [markdown]
# Nota:
# Dependiendo de dónde y con qué frecuencia redondee durante esta función, sus respuestas pueden estar desviadas unos centavos en cualquier dirección. Intente redondear el menor número de veces posible para aumentar la precisión de su resultado.
#
#
# Importante:
# Sólo pulse "Comprobar" una vez por envío. Sólo tiene 30 comprobaciones por problema.
#
# ** Nuestro calificador automático puede tardar unos minutos en responder con sus comentarios. Si pulsa "Comprobar" varias veces, perderá una comprobación por cada vez que pulse el botón.
#
# ** Si no está familiarizado con el funcionamiento de nuestro calificador automático, pruebe primero uno de los problemas de verificación infinita en la secuencia de clases de Funciones.
#
# ** Por favor, sea juicioso con sus comprobaciones, ya que no podemos darle más de 30 comprobaciones. Sin embargo, esto debería ser más que suficiente: si hace su desarrollo de código en su entorno local, y se asegura de que puede pasar nuestros casos de prueba, no debería necesitar más que unas pocas comprobaciones una vez que pegue su código de trabajo y probado en nuestra caja de código.
#
# Si crees que tienes un código correcto pero está marcado como incorrecto después de hacer clic en "Comprobar"...
#
# ** Después de enviar su código, puede ver cada caso de prueba que los calificadores ejecutan en su código. Comparan lo que su código produce con lo que se supone que debe producir nuestro código de respuesta. Haga clic en el pequeño enlace titulado "Ver resultados completos" debajo del encabezado de los resultados de la prueba.
#
# "Depuración del personal: L397 Error" significa que su código tiene un bucle infinito...
#
# ** Al hacer clic en Comprobar puede aparecer el error:
# Hubo un problema al ejecutar su solución (Staff debug: L379). No hemos podido ejecutar su solución (Staff debug: L397)..
# Esto significa que su código está tardando demasiado o tiene un bucle infinito. Pruebe su código con más casos de prueba únicos, como valores muy grandes o muy pequeños.
#
# No defina sus propios valores
#
# ** Para problemas como estos, no incluya declaraciones de entrada o defina variables que le dijimos que se le darían. Nuestras pruebas automatizadas le proporcionarán los valores - así que escriba su código en el siguiente cuadro asumiendo que esas variables ya están definidas. El código que pegue en el siguiente cuadro no debe especificar los valores de las variables balance o

# %%
#balance=320000
#annualInterestRate=0.2
def balanceAfterAYear(bal, rate, payment):
        for i in range(0, 12):
            bal=bal-payment
            interest=bal*rate/12
            bal=interest+bal
        return bal

    # print(balanceAfterAYear(balance, annualInterestRate, 29157))

    monthlyRate=annualInterestRate/12

    lowerBound = balance/12
    upperBound = (balance*(1+monthlyRate)**12)/12
    guess = (upperBound+lowerBound)/2
    noGuesses = 1


    # print("LB: ",end="")
    # print(lowerBound)
    # print("UB: ",end="")
    # print(upperBound)
    # print("guess: ", end="")
    # print(guess)

    YEB=balanceAfterAYear(balance, annualInterestRate, guess)
    while(abs(YEB)>= 0.01):
        if YEB > 0:
            lowerBound=guess
        else:
            upperBound=guess
        guess=(lowerBound+upperBound)/2
        noGuesses+=1
        YEB=balanceAfterAYear(balance, annualInterestRate, guess)

    guess=round(guess, 2)

    print("Lowest Payment: ", end="")
    print(guess)

# %%
balanceAfterAYear(bal, rate, payment)
