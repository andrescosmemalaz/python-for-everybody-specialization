# %% [markdown]
# # ***Problem 1***

# %% [markdown]
# Problema 1
# Suponga que s es una cadena de caracteres en minúscula.
#
# Escribe un programa que cuente el número de vocales que contiene la cadena s. Las vocales válidas son: 'a', 'e', 'i', 'o' y 'u'. Por ejemplo, si s = 'azcbobobegghakl', tu programa debería imprimir:

# %%
frase = "azcbobobegghakl"
contador = 0 
print(s)
for i in frase:
    if i == "a" or i == "e" or i ==  "i" or i ==  "o" or i == "u":
      contador = contador + 1
      # print(i)
    else:
      continue
print("Tenemos",contador,"vocales")
# Out:
# azcbobobegghakl
# Tenemos 5 vocales

# %% [markdown]
# # ***Problem 2***

# %% [markdown]
# 0.0/10.0 puntos (calificado)
# Suponga que s es una cadena de caracteres en minúscula.
#
# Escribe un programa que imprima el número de veces que la cadena 'bob' aparece en s. Por ejemplo, si s = 'azcbobobegghakl', tu programa debería imprimir
#
# El número de veces que aparece bob es: 2

# %%
count=0

for i in range(len(frase)-2  ):
  if frase[i] == 'b':
    if frase[i+1] == 'o':
        if frase[i+2] == 'b':
            count+=1
print("Number of times bob occurs is: " + str(count))
# Out:
# Number of times bob occurs is: 2

# %%
len(frase)-2
# Out:
# 13

# %% [markdown]
# # **Problem 3**

# %% [markdown]
# Suponga que s es una cadena de caracteres en minúsculas.
#
# Escribe un programa que imprima la subcadena más larga de s en la que aparezcan las letras en orden alfabético. Por ejemplo, si s = 'azcbobobegghakl', tu programa debería imprimir
#
# La subcadena más larga en orden alfabético es: beggh
#
# En caso de empate, imprime la primera subcadena. Por ejemplo, si s = 'abcbcd', el programa debería imprimir
#
# La subcadena más larga en orden alfabético es: abc

# %% [markdown]
# Nota: Este problema puede ser un reto. Te animamos a que trabajes de forma inteligente. Si has pasado más de unas horas en este problema, te sugerimos que pases a otra parte del curso. Si tienes tiempo, vuelve a este problema después de haber descansado y despejado la mente.

# %%
s = "azcbobobegghakl"

larga = s[0]
actual = s[0]

for c in s[1:]:
    print("Letra que se está procesando:", c)
    print("Letra anterior:", actual[-1])
    if c >= actual[-1]:
        actual += c
        if len(actual) > len(larga):
            larga = actual
    else:
        actual = c
    print("actual=", actual)
    print("larga=", larga)

print("La subcadena más larga en orden alfabético es:", larga)
# Out:
# Letra que se está procesando: z
# Letra anterior: a
# actual= az
# larga= az
# Letra que se está procesando: c
# Letra anterior: z
# actual= c
# larga= az
# Letra que se está procesando: b
# Letra anterior: c
# actual= b
# larga= az
# Letra que se está procesando: o
# Letra anterior: b
# actual= bo
# larga= az
# Letra que se está procesando: b
# Letra anterior: o
# actual= b
# larga= az
# Letra que se está procesando: o
# Letra anterior: b
# actual= bo
# larga= az
# Letra que se está procesando: b
# Letra anterior: o
# actual= b
# larga= az
# Letra que se está procesando: e
# Letra anterior: b
# actual= be
# larga= az
# Letra que se está procesando: g
# Letra anterior: e
# actual= beg
# larga= beg
# Letra que se está procesando: g
# Letra anterior: g
# actual= begg
# larga= begg
# Letra que se está procesando: h
# Letra anterior: g
# actual= beggh
# larga= beggh
# Letra que se está procesando: a
# Letra anterior: h
# actual= a
# larga= beggh
# Letra que se está procesando: k
# ...
