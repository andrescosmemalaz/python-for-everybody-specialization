# %% [markdown]
# TIEMPO ESTIMADO PARA REALIZARLO: 10 minutos
#
# A continuación se presentan algunos programas cortos de Python. Para cada programa, responda a las preguntas asociadas.
#
# Intenta responder a las preguntas sin ejecutar el código. Comprueba tus respuestas y luego ejecuta el código para las que te equivoques.

# %%
notas_finales = list()
iteration = 0
count = 0
while iteration < 35:
      import random
      nota_1 = random.randrange(1,20)
      nota_2 = random.randrange(1,20)
      nota_3 = random.randrange(1,20)
      valor_1 = nota_1 * 0.15
      valor_2 = nota_2 * 0.25 
      valor_3 = nota_3 * 0.30
      nota_final = valor_1 + valor_2 + valor_3
      notas_finales.append(round(nota_final)) 
      iteration += 1
print(notas_finales)
# Out:
# [6, 4, 4, 10, 2, 3, 7, 3, 7, 7, 5, 7, 6, 11, 10, 6, 10, 8, 7, 7, 8, 5, 6, 11, 11, 11, 6, 10, 4, 8, 7, 6, 11, 7, 3]

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 0?

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 1?

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 2?

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 3?

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 4?

# %%
iteration = 0
while iteration < 5:
    count = 0
    for letter in "hello, world":
        count += 1
    print("Iteration " + str(iteration) + "; count is: " + str(count))
    iteration += 1
# Out:
# Iteration 0; count is: 12
# Iteration 1; count is: 12
# Iteration 2; count is: 12
# Iteration 3; count is: 12
# Iteration 4; count is: 12

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 0?

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 1?

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 2?

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 3?

# %%
# What is the value of the variable count that is printed out (at the print statement) on iteration 4?

# %%
iteration = 0
while iteration < 5:
    count = 0
    for letter in "hello, world":
        count += 1
        if iteration % 2 == 0:
            break
    print("Iteration " + str(iteration) + "; count is: " + str(count))
    iteration += 1
# Out:
# Iteration 0; count is: 1
# Iteration 1; count is: 12
# Iteration 2; count is: 1
# Iteration 3; count is: 12
# Iteration 4; count is: 1

# %% [markdown]
# How many times will the print statement be executed?

# %% [markdown]
# What is the largest value of the variable iteration that will be printed out (at the print statement)?

# %% [markdown]
# What is the largest value of the variable count that will be printed out (at the print statement)?

# %% [markdown]
# What is the smallest value of the variable count that will be printed out (at the print statement)?

# %% [markdown]
# # ***Exercise 2***

# %%
x = 25
epsilon = 0.01
step = 0.1
guess = 0.0

while guess <= x:
    if abs(guess**2 -x) < epsilon:
        break
    else:
        guess += step

if abs(guess**2 - x) >= epsilon:
    print('failed')
else:
    print('succeeded: ' + str(guess))
# Out:
# succeeded: 4.999999999999998

# %%
# Script enters an infinite loop and never terminates

x = 25
epsilon = 0.01
step = 0.1
guess = 0.0

while guess <= x:
    if abs(guess**2 -x) >= epsilon:
        guess += step

if abs(guess**2 - x) >= epsilon:
    print('failed')
else:
    print('succeeded: ' + str(guess))

# %%
x = 25
epsilon = 0.01
step = 0.1
guess = 0.0

while abs(guess**2-x) >= epsilon:
    if guess <= x:
        guess += step
    else:
        break

if abs(guess**2 - x) >= epsilon:
    print('failed')
else:
    print('succeeded: ' + str(guess))
# Out:
# succeeded: 4.999999999999998

# %%
x = 23
epsilon = 0.01
step = 0.1
guess = 0.0

while abs(guess**2-x) >= epsilon:
    if guess <= x:
        guess += step
    else:
        break

if abs(guess**2 - x) >= epsilon:
    print('failed')
else:
    print('succeeded: ' + str(guess))
# Out:
# failed
