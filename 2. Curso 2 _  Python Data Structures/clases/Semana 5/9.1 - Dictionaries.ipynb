# %%
pursue = dict()
# print(pursue)
pursue["money"] = 120 
pursue["candy"] = 32
pursue["tissues"] = 65 
print(pursue)
print("El valor de la clave candy es ", pursue["candy"])
# Out:
# {'money': 120, 'candy': 32, 'tissues': 65}
# El valor de la clave candy es  32

# %%
print(pursue["candy"]) 
pursue["candy"] = pursue["candy"] + 45
print(pursue)
# Out:
# 32
# {'money': 120, 'candy': 77, 'tissues': 65}

# %%
#Comparando listas y diccionarios
#lista
lst = list()
lst.append(21)
lst.append(183)
print(lst)
lst[0] = 27 #Cambio de una lista
print(lst)
# Out:
# [21, 183]
# [27, 183]

# %%
#Comparando listas y diccionarios
#diccionarios
diccionario = dict()
diccionario['age'] = 24
diccionario['course'] = 128
print(diccionario)
diccionario['age'] = 27
print(diccionario)
# Out:
# {'age': 24, 'course': 128}
# {'age': 27, 'course': 128}

# %%
def imprimir(a):
  print("El valor de la clave ", ,"es", pursue["candy"])
