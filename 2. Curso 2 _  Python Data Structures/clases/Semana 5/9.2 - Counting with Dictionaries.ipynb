# %%
#Many counters with a dictionary
ccc = dict()
ccc['nombre'] = 1
ccc['apellido'] = 1
print(ccc)
# Out:
# {'nombre': 1, 'apellido': 1}

# %%
ccc['nombre'] = ccc['nombre'] + 1 
print(ccc)
# Out:
# {'nombre': 2, 'apellido': 1}

# %%
'nombre' in  ccc
# Out:
# False

# %%
ccc = dict()
print(ccc['nombre'])
#llave que no existe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-02034e2f88ba> in <module>()
#       1 ccc = dict()
# ----> 2 print(ccc['nombre'])
#       3 nombre in  ccc
#
# KeyError: 'nombre'

# %%
counts = dict()
names = ['luisa','derect','maximo','luis','maximo']

# %%
for name in names:
    if name not in counts:
      counts[name] = 1 
    else:
      counts[name] = counts[name] + 1
print(counts) 
print(names)
# Out:
# {'luisa': 1, 'derect': 1, 'maximo': 2, 'luis': 1}
# ['luisa', 'derect', 'maximo', 'luis', 'maximo']

# %%
# El método get para diccionarios
if name in counts:
  x = counts[name]
else:
  x = 0 

x = counts.get(name,0)
print(x)
# Out:
# 2

# %%
counts = dict()
names = ['luisa','derect','maximo','luis','maximo']
for name in names:
  counts[name] = counts.get(name,0) + 1 
print(counts)
# Out:
# {'luisa': 1, 'derect': 1, 'maximo': 2, 'luis': 1}
