# %%
mbox = open("/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox.txt",'r')
# Contador de líneas
count = 0
for line in mbox:
  count = count + 1 
print("Lineas contadas",count)
# Out:
# Lineas contadas 132045

# %%
mbox = open('/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox.txt')
texto = mbox.read()
print(len(texto))
# Out:
# 6687002

# %%
print(texto[:21])
# Out:
# From stephen.marquard

# %%
mbox = open('/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox.txt')
for line in mbox:
  line = line.strip()
  if line.startswith('Received:'):
    print(line)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# Received: (from apache@localhost)
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from icestorm.mr.itd.umich.edu (icestorm.mr.itd.umich.edu [141.211.93.149])
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# Received: (from apache@localhost)
# Received: from murder (mail.umich.edu [141.211.14.46])
# ...

# %%
mbox = open('/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox.txt')
for line in mbox:
  line = line.strip()
  if line.startswith('Author:'):
    print(line)
# Out:
# Author: stephen.marquard@uct.ac.za
# Author: louis@media.berkeley.edu
# Author: zqian@umich.edu
# Author: rjlowe@iupui.edu
# Author: zqian@umich.edu
# Author: rjlowe@iupui.edu
# Author: cwen@iupui.edu
# Author: cwen@iupui.edu
# Author: gsilver@umich.edu
# Author: gsilver@umich.edu
# Author: zqian@umich.edu
# Author: gsilver@umich.edu
# Author: wagnermr@iupui.edu
# Author: zqian@umich.edu
# Author: antranig@caret.cam.ac.uk
# Author: gopal.ramasammycook@gmail.com
# Author: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# Author: stephen.marquard@uct.ac.za
# Author: louis@media.berkeley.edu
# Author: louis@media.berkeley.edu
# Author: ray@media.berkeley.edu
# Author: cwen@iupui.edu
# Author: cwen@iupui.edu
# Author: cwen@iupui.edu
# Author: ray@media.berkeley.edu
# Author: cwen@iupui.edu
# Author: zqian@umich.edu
# Author: cwen@iupui.edu
# Author: zqian@umich.edu
# Author: zqian@umich.edu
# ...

# %%
mbox = open('/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox.txt')
for line in mbox:
  line = line.strip()
  if not line.startswith('Author:'):
    continue #Skip
  print(line)
# Out:
# Author: stephen.marquard@uct.ac.za
# Author: louis@media.berkeley.edu
# Author: zqian@umich.edu
# Author: rjlowe@iupui.edu
# Author: zqian@umich.edu
# Author: rjlowe@iupui.edu
# Author: cwen@iupui.edu
# Author: cwen@iupui.edu
# Author: gsilver@umich.edu
# Author: gsilver@umich.edu
# Author: zqian@umich.edu
# Author: gsilver@umich.edu
# Author: wagnermr@iupui.edu
# Author: zqian@umich.edu
# Author: antranig@caret.cam.ac.uk
# Author: gopal.ramasammycook@gmail.com
# Author: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# Author: stephen.marquard@uct.ac.za
# Author: louis@media.berkeley.edu
# Author: louis@media.berkeley.edu
# Author: ray@media.berkeley.edu
# Author: cwen@iupui.edu
# Author: cwen@iupui.edu
# Author: cwen@iupui.edu
# Author: ray@media.berkeley.edu
# Author: cwen@iupui.edu
# Author: zqian@umich.edu
# Author: cwen@iupui.edu
# Author: zqian@umich.edu
# Author: zqian@umich.edu
# ...

# %%
#Ursing in to Select lines
mbox = open('/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox.txt')
for line in mbox:
  line = line.strip()
  if not '@uct.ac.za'in line  :
    continue
  print(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to stephen.marquard@uct.ac.za using -f
# From: stephen.marquard@uct.ac.za
# Author: stephen.marquard@uct.ac.za
# From david.horwitz@uct.ac.za Fri Jan  4 07:02:32 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# r39753 | david.horwitz@uct.ac.za | 2008-01-04 13:05:51 +0200 (Fri, 04 Jan 2008) | 1 line
# From david.horwitz@uct.ac.za Fri Jan  4 06:08:27 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# From david.horwitz@uct.ac.za Fri Jan  4 04:49:08 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# ...

# %%
# Promt for file name
archivo = input('Enter the file name:')
archivo = open(archivo)
count = 0 
for line in archivo:
  if line.startswith('Subject:'):
    count = count + 1
print('There were', count, 'subject line in' ,archivo)
# Out:
# Enter the file name:/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox.txt
# There were 1797 subject line in <_io.TextIOWrapper name='/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox.txt' mode='r' encoding='UTF-8'>

# %%
# Promt for file name
archivo = input('Enter the file name:')
archivo = open(archivo)
count = 0 
for line in archivo:
  if line.startswith('It'):
    count = count + 1
print('There were', count, 'It  in' ,archivo)
# Out:
# Enter the file name:/content/romeo.txt
# There were 1 It  in <_io.TextIOWrapper name='/content/romeo.txt' mode='r' encoding='UTF-8'>

# %%
# Promt for file name
archivo = input('Enter the file name:')
word_search = input("Enter the word that you want to :")
try : 
  archivo = open(archivo)
except:
  print('File cannot be opened :', archivo)
  quit() #Para dejar de ejecutar y continuar 

count = 0 
for line in archivo:
  if line.startswith(word_search):
    count = count + 1
print('There were', count, word_search ,"in",archivo)
# Out:
# Enter the file name:/content/romeo.txt
# Enter the word that you want to :It
# There were 1 It in <_io.TextIOWrapper name='/content/romeo.txt' mode='r' encoding='UTF-8'>
