# %% [markdown]
# #7.2 Write a program that prompts for a file name, then opens that file and reads through the file, looking for lines of the form:
# #X-DSPAM-Confidence:    0.8475
# #Count these lines and extract the floating point values from each of the lines and
# #compute the average of those values and produce an output as shown below.
# #Do not use the sum() function or a variable named sum in your solution.
# #You can download the sample data at http://www.py4e.com/code3/mbox-short.txt when you are testing below enter mbox-short.txt as the file name.
#
# # Use the file name mbox-short.txt as the file name

# %%
archivo = input("Enter your File :")
archivo = open(archivo)
n = 0 
sum = 0 
XDSPAM = 0 
flotante = float(n)
for line in archivo:
    if not line.startswith("X-DSPAM-Confidence:"):
      continue
    n = n + 1
    #Extrae el texto encontrado luego del inicio del decimal
    XDSPAM = line[line.find('0') : ]
    XDSPAM_numero_flotante = float(XDSPAM)
    sum = sum + XDSPAM_numero_flotante
average = sum/n
print("El promedio de spam encontrado ",average)
# Out:
# Enter your File :/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox-short.txt
# El promedio de spam encontrado  0.7507185185185187

# %%
fname = input("Enter file name: ")
fh = open(fname)
n = 0 # for amount of lines
n1 = 0 #for summ
xDSPAM = 0
nfloat = float(n)
for line in fh:
    if not line.startswith("X-DSPAM-Confidence:") : continue
    n = n + 1
    xDSPAM = line[line.find('0') : ]
    xDSPAMfl = float(xDSPAM)
    n1 = n1 + xDSPAMfl
median = n1 / n
print("Average spam confidence:", median)

# %%
archivo = input("Enter your File :")
archivo = open(archivo)
n = 0 
sum = 0 
SAK = 0 
flotante = float(n)
for line in archivo:
    if not line.startswith("SAK-"):
      continue
    n = n + 1
    #Extrae el texto encontrado luego del inicio del decimal
    SAK = line[line.find('-')+ 1 : 8]
    SAK_numero_flotante = float(SAK)
    sum = sum + SAK_numero_flotante
average = sum/n
print("El promedio de SAK",average)
# Out:
# Enter your File :/content/drive/MyDrive/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Curso 2 /clases /Semana 3/mbox-short.txt
# El promedio de SAK 2470.0555555555557
