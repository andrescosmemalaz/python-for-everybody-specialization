# %%
# 1.Pregunta 1
# How are "collection" variables different from normal variables?
Collection variables can store multiple values in a single variable

# %%
# 2.Pregunta 2
# What are the Python keywords used to construct a loop to iterate through a list?
for/in

# %%
# 3.Pregunta 3
# For the following list, how would you print out 'Sally'?
friends = [ 'Joseph', 'Glenn', 'Sally' ]
print(friends[2])
# Out:
# Sally

# %%
# 4.Pregunta 4
# What would the following Python code print out?
fruit = 'Banana'
fruit[0] = 'b'
print(fruit)
#Nothing would print - the program fails with a traceback error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-71765c031f15> in <module>()
#       2 # What would the following Python code print out?
#       3 fruit = 'Banana'
# ----> 4 fruit[0] = 'b'
#       5 print(fruit)
#
# TypeError: 'str' object does not support item assignment

# %%
# 5.Pregunta 5
# Which of the following Python statements would print out the length of a list stored in the variable data?
print(len(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-26a560253a95> in <module>()
#       1 # 5.Pregunta 5
#       2 # Which of the following Python statements would print out the length of a list stored in the variable data?
# ----> 3 print (len(data))
#
# NameError: name 'data' is not defined

# %%
# 6.Pregunta 6
# What type of data is produced when you call the range() function?
x = list(range(5))
print(x)
for i in x:
  print(type(i))
type(x)
#A list of integers
# Out:
# [0, 1, 2, 3, 4]
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# list

# %%
# 7.Pregunta 7
# What does the following Python code print out?
a = [1, 2, 3]
b = [4, 5, 6]
c = a + b
print(len(c))
# Out:
# 6

# %%
# 8. Pregunta 8
# Which of the following slicing operations will produce the list [12, 3]?
t = [9, 41, 12, 3, 74, 15]
print(t[2:4])
# Out:
# [12, 3]

# %%
# 9. Pregunta 9
# What list method adds a new item to the end of an existing list?
lista = []
lista.append("Amor")
print(lista)
# Out:
# ['Amor']

# %%
# 10.Pregunta 10
# What will the following Python code print out?
friends = [ 'Joseph', 'Glenn', 'Sally' ]
friends.sort()#Ordenando
print(friends)
print(friends[0])
# Out:
# ['Glenn', 'Joseph', 'Sally']
# Glenn
