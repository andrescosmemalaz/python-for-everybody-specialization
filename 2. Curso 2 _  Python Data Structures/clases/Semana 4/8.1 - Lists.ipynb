# %%
friends = ['Joseph','Gleen','Sally']
carryon = ['socks','shirt','perfume']
print(friends[1])
# Out:
# Gleen

# %%
print(['Joseph','Gleen','Sally'])
# Out:
# ['Joseph', 'Gleen', 'Sally']

# %%
print([1,24,76])
# Out:
# [1, 24, 76]

# %%
print(['red','blue','yellow'])
# Out:
# ['red', 'blue', 'yellow']

# %%
print(['red','blue','yellow'])

# %%
print(['red',24,98.6])
# Out:
# ['red', 24, 98.6]

# %%
print(['red',24,98.6,[5,6]])
# Out:
# ['red', 24, 98.6, [5, 6]]

# %% [markdown]
# Recorrer listas

# %%
for i in friends:
  print('Happy New Year : ',i)
print("End")
# Out:
# Happy New Year :  Joseph
# Happy New Year :  Gleen
# Happy New Year :  Sally
# End

# %%
for i in [5,4,3,2,1]:
  print(i)
print("Boom")
# Out:
# 5
# 4
# 3
# 2
# 1
# Boom

# %%
# List are mutable
#Usando el indice de la lista
fruit = 'banana'
fruit[0]= 'e'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-bf2339306203> in <module>()
#       2 #Usando el indice de la lista
#       3 fruit = 'banana'
# ----> 4 fruit[0]= 'e'
#
# TypeError: 'str' object does not support item assignment

# %%
x = ['red','blue','yellow']
x[2] = 'black'
print(x)
# Out:
# ['red', 'blue', 'black']

# %%
greet = 'Hello rick'
print(len(greet))
# Out:
# 10

# %%
x = [1,2,'joe',99]
print(len(x))
# Out:
# 4

# %%
print(range(4))
# Out:
# range(0, 4)

# %%
friends = ['Joseph','Gleen','Sally']
print(len(friends))
# Out:
# 3

# %%
for i in range(len(friends)):
  friend = friends[i]
  print('Happy New Year', friend)
# Out:
# Happy New Year Joseph
# Happy New Year Gleen
# Happy New Year Sally

# %%
print(range(len(friends)))
# Out:
# range(0, 3)
