# %%
abc = 'With three words'
cadena = abc.split()
print(abc)
print(cadena)
# Out:
# With three words
# ['With', 'three', 'words']

# %%
print(len(abc))
# Out:
# 16

# %%
print(len(cadena))
# Out:
# 3

# %%
print(cadena[1])
# Out:
# three

# %%
print(abc[0])
# Out:
# W

# %%
for i in abc:
  print(i)
# Out:
# W
# i
# t
# h
#
# t
# h
# r
# e
# e
#
# w
# o
# r
# d
# s

# %%
for i in cadena:
  print(i)
# Out:
# With
# three
# words

# %%
line = ''

# %%
abc  = 'with three words'
detalle  = abc.split()# con el método slit divides una cadena
print(detalle)
for x in detalle:
  print(x)
# Out:
# ['with', 'three', 'words']
# with
# three
# words

# %%
c
# Out:
# 3

# %%
print(detalle[0])
# Out:
# with

# %%
line = 'with three words        space'
etc = line.split()#Separar por espacio
print(etc)
# Out:
# ['with', 'three', 'words', 'space']

# %%
line = 'first;second;third'
thing= line.split()
print(thing)
c
# Out:
# ['first;second;third']
# 1

# %%
thing = line.split(";")#Dividir por punto y coma
print(thing)
print(len(thing))
# Out:
# ['first', 'second', 'third']
# 3

# %%
line = "From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008"
words = line.split()
print(words)
# Out:
# ['From', 'stephen.marquard@uct.ac.za', 'Sat', 'Jan', '5', '09:14:16', '2008']

# %%
line = "From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008"
words = line.split() #Guardamos la variable  words , con line ajustada a la varuable split
email = words[1] # Extraemos el número 1 de word
detalle = email.split('@') #Extraer los variablñes entre arroba 
print(email)
print(detalle)
# Out:
# stephen.marquard@uct.ac.za
# ['stephen.marquard', 'uct.ac.za']

# %%
fhand = open("/content/mbox-short.txt")
for line in fhand:
  line = line.rstrip()
  if not line.startswith("From "):continue
  words = line.split()
  print(words[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %%
fhand = open("/content/mbox-short.txt")
for line in fhand:
  line = line.rstrip()
  print(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
import re 
fhand = open("/content/Simapro.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# el sistema integral de medición y avance
#
# de la productividad simapro es una
#
# metodología de uso libre impulsada y
#
# avalada por la organización
#
# internacional del trabajo organismo
#
# especializado de las naciones unidas-
#
# las características distintivas de simav
#
# se pueden resumir en que promueve el
#
# trabajo decente a través de un aumento
#
# significativo en la productividad de las
#
# organizaciones y una mejora sustancial
#
# en las condiciones de trabajo las cuales
#
# se logran a partir de el establecimiento
#
# del diálogo social del partido entre
#
# trabajadores y empleadores la reducción
#
# la mejora en las condiciones de
#
# seguridad y salud en el trabajo el
#
# en las horas-hombre de capacitación de
#
# competencias laborales un aumento en la
#
# este se mide en puntos de efectividad
#
# ciento promedio el ausentismo
#
# y retardos y un retorno de la inversión
#
# reto de implementación el centro de
#
# modelos y macro son las personas la
#
# ...

# %%
import re 
fhand = open("/content/Reduciendo brechas en la productividad de la agricultura peruana - Ricardo Fort (1).txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# el estudio que nosotros hemos hecho
#
# desde grade trata de responder a la
#
# segunda pregunta del documento que
#
# presenta hoy el banco mundial que tiene
#
# que ver con cuán productiva es la
#
# agricultura peruana y cuáles son las
#
# oportunidades para desarrollar el
#
# crecimiento futuro reduciendo las
#
# desigualdades de la productividad dentro
#
# del sector agrícola y aquí la palabra
#
# clave es dentro del sector agrícola
#
# porque como hemos visto hemos escuchado
#
# al inicio y hemos visto en la
#
# presentación de michael es difícil
#
# hablar de un sector agrícola en el caso
#
# del perú los estudios que hay que han
#
# habido sobre los cálculos de
#
# productividad para el perú han tenido
#
# todos la condición de que han sido a
#
# nivel nacional no hay tres o cuatro
#
# estudios que han comparado la
#
# productividad la evolución de la
#
# productividad en el perú con algunos
#
# otros países en este caso presentamos el
#
# ...

# %%
import os
file = open("/content/salida.txt", "w")
file.write(line + os.linesep)
file.close()
# Out:
# /content/salida.txt

# %%
import re 
fhand = open("/content/SNI.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# la investigación que requiere la
#
# industria peruana
#
# hola doctor
#
# buenos días
#
# en primer lugar quiero agradecer la
#
# invitación de expósito para hacer esta
#
# presentación
#
# mi nombre es jorge pesqueira soy segundo
#
# vicepresidente de la sociedad industrias
#
# estoy
#
# en este evento representando al
#
# al señor ricardo márquez que se
#
# encuentra fuera del país por razones de
#
# salud
#
# y también tengo que aclarar que no soy
#
# doctor bueno
#
# no me pidan que ok a nadie
#
# estudié ingeniería industrial en la
#
# única que una maestría
#
# en investigación de operación de
#
# enséñame allí
#
# en los últimos años estoy en el sector
#
# empresarial pero he tenido varias vidas
#
# anteriormente
#
# y
#
# recientemente he sido convocado y
#
# pertenezco al
#
# al consejo de concytec
#
# lo cual es un gran reto
#
# porque uno siempre tiene muchas cosas
#
# que hacer pero no podía dejar de darme
#
# aporte en algo que considero que es
#
# vital para el país
#
# ...

# %%
import re 
fhand = open("/content/milagro agroexportador.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# nos encontramos en un mundo de espárrago
#
# un producto emblemático de las
#
# agroexportaciones peruanas pues durante
#
# el espárrago fresco y en conserva era el
#
# principal producto de la canasta agro
#
# exportable no tradicional peruana a
#
# acompañamiento el impulso de productos
#
# como la uva la palta el mango cítricos
#
# maracuyá entre otros inicia un
#
# crecimiento que no ha dejado de parar
#
# características por lo que muchos han
#
# denominado el milagro de las
#
# agroexportaciones peruanas que más que
#
# un milagro en la función de esfuerzos
#
# tanto de la inversión privada como de
#
# las mejores condiciones de clima y
#
# geografía que nuestra biodiversidad
#
# peruana nos ha proporcionado bien amigos
#
# el tema de hoy el tema que vamos a
#
# tratar es el milagro exportador peruano
#
# si el milagro exportador el milagro
#
# agroexportadores si en sentido abreviado
#
# lo estamos haciendo milagro exportador
#
# peruano
#
# ...

# %%
import re 
fhand = open("/content/Camposol.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# rebelde presenta fuerza en movimiento en
#
# alianza con avianca
#
# hoy en fuerza en movimiento perú es uno
#
# de los diez principales países que
#
# alimentan al mundo
#
# y ya el mundo está cambiando el mundo
#
# hoy día quiere comida saludable comida
#
# fresca y tienen capacidad de ir por más
#
# tenemos tierras disponibles tenemos agua
#
# y hay muchos proyectos que podrían
#
# gastar mucho más oferta al mundo
#
# productor una oferta que se podría
#
# lograr con tesón y creatividad creo que
#
# latinoamérica tiene la fuerza de poder
#
# generar este tipo de productos con valor
#
# agregado y poder ofrecerlos al mundo
#
# entero
#
# esto es fuerza en movimiento pero los
#
# frutos de la innovación
#
# tres casos destacados de la
#
# agroindustria peruana que buscan
#
# expandir la oferta nacional a más mesas
#
# millones de personas según las naciones
#
# unidas dos mil millones más que ahora y
#
# muchos se preguntan de dónde van a salir
#
# ...

# %%
import re 
fhand = open("/content/visualpoitik-Holanda.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# Muchos nos habéis pedido que hagamos este vídeo.
#
# Este vídeo es una actualización de uno que subimos hace varios años y que tuvimos que
#
# eliminar por problemas técnicos.
#
# Así que hemos revisado el guión, hemos actualizado los datos y ahora os lo volvemos a presentar
#
# ¿Por qué Países Bajos es la mayor potencia agrícola del mundo?
#
# Ahora mismo os lo vamos a contar.
#
# Os voy a hacer una pregunta y no vale buscarlo en Google ¿Cuál es la mayor potencia agrícola
#
# de Europa?
#
# Muchos pensaréis en España, Italia, o tal vez Francia.
#
# A fin de cuentas, son países con buen clima y con miles de hectáreas de tierra cultivable.
#
# Sin embargo, ninguno de estos países le llega a la suela del zapato a los PAÍSES BAJOS,
#
# también conocido como HOLANDA.
#
# Para que os hagáis una idea, Holanda es el mayor exportador de alimentos del mundo, sólo
#
# superado por Estados Unidos.
#
# ¿Qué decís?
#
# ¿Qué no estáis sorprendidos?
#
# Pues pensadlo bien.
#
# ...

# %%
import re 
fhand = open("/content/PRODUCTIVIDAD Y COMPETITIVIDAD.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# y seguro que han oído en más de una
#
# ocasión que en españa tenemos que
#
# mejorar la productividad y la
#
# competitividad pero eso es exactamente
#
# cómo se concreta se lo vamos a preguntar
#
# a un experto economista y catedrático de
#
# la universidad politécnica de madrid
#
# julián pago en buenos días
#
# buenos días porque es verdad que lo
#
# oímos muy a menudo pero no todos tenemos
#
# muy claro que es ser productivo por
#
# ejemplo qué significa cómo se traduce a
#
# la realidad uno en primer lugar en dejar
#
# claro que productividad y competitividad
#
# son dos términos distintos y que también
#
# hay que tratar de hablar de
#
# productividad a nivel de empresa y
#
# competitividad a nivel de empresa y
#
# productividad de competitividad a nivel
#
# de país ya título individual no uno no
#
# es más productivo o menos porque cuando
#
# hablamos de empresa
#
# imaginemos que estamos en una fábrica de
#
# alfileres y hay dos trabajadores a los
#
# ...

# %%
import re 
fhand = open("/content/mantenimiento.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# otros profesionales encuentran
#
# dificultades para hacer un plan de
#
# mantenimiento en muchas ocasiones porque
#
# no tienen una idea clara de qué es lo
#
# que cuál es el trabajo que tienen que
#
# desarrollar
#
# qué es un plan de mantenimiento un plan
#
# de mantenimiento no es más que un
#
# conjunto de tareas es el conjunto de
#
# tareas que es necesario llevar a cabo
#
# para recuperar las prestaciones perdidas
#
# para compensar el desgaste que tener la
#
# instalación por tanto lo que tenemos que
#
# hacer es identificar las tareas que
#
# tenemos que llevar a cabo en toda la
#
# instalación para conseguir compensar el
#
# desgaste que podrá sufrido o para evitar
#
# que podrá surgir determinados problemas
#
# en la instalación averías fallos etc
#
# existen tres formas de determinar las
#
# tareas que es necesario llevar a cabo en
#
# una instalación la primera de las formas
#
# es basarse en las instrucciones del
#
# fabricante la segunda de las formas es
#
# ...

# %%
import re 
fhand = open("/content/Nisan.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# el cuerpo del autobús se fabrica de
#
# rollos de acero
#
# la mayoría de los rollos son ligeros
#
# rígidos y resistentes a la corrosión una
#
# el acero en el molde con las láminas
#
# cortadas a la medida son prensadas por
#
# un dado para darles forma entonces la
#
# prensa de estampado los presiona desde
#
# arriba los moldes que consisten en
#
# secciones inferiores y superiores que
#
# varían de acuerdo a la parte en la
#
# moldes
#
# luego del estampado las planchas de
#
# metal se colocan en un carrito especial
#
# después de una inspección de calidad las
#
# partes estampados se llevan al taller de
#
# ensamblado
#
# las puertas el techo y el piso son
#
# soldados durante el ensamblaje
#
# con el marco del cuerpo del auto en
#
# posición los robots de soldadura
#
# comienzan a trabajar los brazos de los
#
# robots con puntas bifurcadas soldán las
#
# a los cuerpos ya ensamblados se les
#
# agregan otras partes como el guarda
#
# maletas y las defensas luego de otro
#
# ...

# %%
import re 
fhand = open("/content/ERP.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# Hola, me llamo Laura, de la empresa de desarrollo de software Aplimedia, y hoy te voy a explicar
#
# qué es un ERP y para qué sirve.
#
# Las siglas ERP vienen de Enterprise Resource Planning.
#
# La traducción literal al español sería Planificación de Recursos Empresariales.
#
# Si haces una búsqueda rápida en Internet lo más probable es que encuentres cientos
#
# de definiciones y que todas sean diferentes entre ellas. La razón es que hay muchas empresas
#
# que los comercializan y que ofrecen diferentes funcionalidades. Esto te puede daruna idea
#
# de las enormes posibilidades que existen dentro del mundo de los ERPs y de todas las soluciones
#
# que vas a encontrar. Pero entonces, ¿qué es un ERP? Lo más probable es que si intentas
#
# buscar su definición en las siglas te quedes como estás. Lo que tenemos que hacer es reflexionar
#
# y mirar el contexto para entender todos los procesos que engloba la planificación de
#
# ...
