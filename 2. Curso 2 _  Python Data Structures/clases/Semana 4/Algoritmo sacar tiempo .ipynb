# %%
import re 
fhand = open("/content/SESION 05-SIG.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# [Música]
#
# y
#
# [Música]
#
# y
#
# [Música]
#
# [Aplausos]
#
# [Música]
#
# gestión de la calidad ahora nos
#
# donde vamos a revisar el capítulo de
#
# apoyo soy la ingeniera mireya aucapiña
#
# consultora líder en sistemas integrados
#
# de gestión si comparto el enlace para
#
# que puedan comunicarse conmigo en caso
#
# que tengan alguna duda alguna inquietud
#
# o de alguna consulta con respecto a las
#
# clases que hemos estado revisando en el
#
# contamos con ocho sesiones
#
# correcto desde la primera sesión hemos
#
# revisado la introducción leemos luego
#
# hemos revisado el contexto de ahí el
#
# liderazgo
#
# por último
#
# revisamos la planificación correcto
#
# ahora en esta quinta expresión vamos a
#
# revisar el capítulo de apoyo
#
# dentro del capítulo de apoyo vamos a ir
#
# revisando punto por punto
#
# sub capítulo de recursos competencia
#
# toma de conciencia comunicación
#
# información documentada
#
# también bien comenzamos con recursos
#
# ...

# %%
import re 
fhand = open("/content/SESION 06-SIG.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# [Música]
#
# [Aplausos]
#
# [Música]
#
# e
#
# [Música]
#
# [Aplausos]
#
# [Música]
#
# gestión de la calidad estamos en la
#
# presentación vamos a revisar todo lo
#
# concerniente a los requisitos que nos
#
# exige la norma con respecto a operación
#
# soy la ingeniera mireya aucapiña voy a
#
# estar a cargo del curso a cargo de la
#
# sesión si comparto el enlace en caso
#
# tengan alguna duda alguna inquietud
#
# alguna consulta siéntense con la
#
# libertad de
#
# comunicarse por esa red profesional
#
# mencionarles una vez más la estructura
#
# del módulo contamos con ocho sesiones
#
# correcto desde la introducción hasta el
#
# capítulo de mejora y actualmente estamos
#
# operación dentro de operación observamos
#
# estructura de la norma correcto entonces
#
# vamos a comenzar con el capítulo
#
# el sub capítulo número uno de
#
# planificación y control operacional
#
# antes de ello vamos a poder visualizar
#
# un vídeo
#
# estructura para entender mejor el
#
# requisito
#
# ...

# %%
import re 
fhand = open("/content/SIG SESION 01 ISO 14001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# buenos días buenas tardes buenas noches
#
# estimados alumnos en el momento en que
#
# estén viendo este vídeo es un gusto
#
# saludarlos mi nombre es india estefanía
#
# galarza volvió el día de hoy vamos a ver
#
# al curso del sistema de gestión
#
# esta sesión uno va a ser una sesión
#
# básicamente de introducción al sistema
#
# de gestión ambiental vamos a ver en qué
#
# consiste
#
# en qué consiste digamos una norma que es
#
# la hizo no cuáles son digamos
#
# cualquier la estructura de alto nivel no
#
# de la cual se habla en la norma ya
#
# también el capítulo introductorio de la
#
# norma y algunos puntos que son de
#
# interés como por ejemplo el ciclo php al
#
# ciclo de mejora continua del cual nos
#
# introductoria ya también vamos a ver
#
# algunas definiciones respecto al sistema
#
# de gestión ambiental que la norma nos
#
# nos dice que debemos de conocer
#
# en principio para posteriormente hacer
#
# una implementación de un sistema de
#
# gestión ambiental
#
# ...

# %%
import re 
fhand = open("/content/SIG SESION 04 ISO 14001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# estimados alumnos cómo están buenos días
#
# buenas tardes buenas noches en el
#
# momento en que estén viendo este este
#
# vídeo espero que todos se encuentran muy
#
# bien de salud así como sus familiares
#
# bueno en esta sesión es la sesión número
#
# sistema de gestión ambiental y
#
# específicamente vamos a ver el capítulo
#
# entonces en esta nueva oportunidad vamos
#
# que se trata no recordando que el
#
# forman parte de lo que es la
#
# planificación
#
# dentro del ciclo de mejora continua del
#
# ciclo de demi no cíclope h
#
# creo que ya ustedes me conocen
#
# igualmente
#
# presentó brevemente soy sin que éste
#
# tenía del estado león soy ingeniera
#
# ambiental de la universidad nacional
#
# agraria de la molina
#
# egresada de la maestría de ciencias
#
# ambientales convención en desarrollo
#
# sustentable en minería y recursos
#
# energéticos por la universidad nacional
#
# mayor de san marcos
#
# y bueno en mi experiencia
#
# una experiencia pues data de diversos
# ...

# %%
import re 
fhand = open("/content/SIG SESION 01 ISO 14001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# buenos días buenas tardes buenas noches
#
# estimados alumnos en el momento en que
#
# estén viendo este vídeo es un gusto
#
# saludarlos mi nombre es india estefanía
#
# galarza volvió el día de hoy vamos a ver
#
# al curso del sistema de gestión
#
# esta sesión uno va a ser una sesión
#
# básicamente de introducción al sistema
#
# de gestión ambiental vamos a ver en qué
#
# consiste
#
# en qué consiste digamos una norma que es
#
# la hizo no cuáles son digamos
#
# cualquier la estructura de alto nivel no
#
# de la cual se habla en la norma ya
#
# también el capítulo introductorio de la
#
# norma y algunos puntos que son de
#
# interés como por ejemplo el ciclo php al
#
# ciclo de mejora continua del cual nos
#
# introductoria ya también vamos a ver
#
# algunas definiciones respecto al sistema
#
# de gestión ambiental que la norma nos
#
# nos dice que debemos de conocer
#
# en principio para posteriormente hacer
#
# una implementación de un sistema de
#
# gestión ambiental
#
# ...

# %%
import re 
fhand = open("/content/SIG SESION 02 ISO 14001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# buenos días buenas tardes buenas noches
#
# estimados alumnos espero que todos se
#
# encuentren muy bien de salud
#
# en esta oportunidad vamos a ver el
#
# módulo
#
# sistema de gestión ambiental
#
# los diferentes requisitos no vamos a
#
# revisar los diferentes requisitos del
#
# sistema de gestión ambiental donde la
#
# sesión
#
# digamos no pretendo que ustedes se
#
# aprendan todos los requisitos que nos
#
# solicita la norma lo que sí es que si
#
# quiero que veamos algunos puntos
#
# relevantes no que digamos que están
#
# abordados por la norma ya y qué bueno
#
# que que deben ser considerados por
#
# ustedes cuando ustedes implementen un
#
# sistema de gestión sin embargo el
#
# desarrollo de cada capítulo de la norma
#
# no con ejemplos digamos más con mayor
#
# profundidad
#
# lo vamos a hacer pues a partir de la
#
# siguiente clase que vamos a ver desde el
#
# capítulo que corresponde a la parte de
#
# implementación ya entonces en esta
#
# ...

# %%
import re 
fhand = open("/content/SIG SESION 03 ISO 14001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# estimados alumnos cómo están muy buenos
#
# días muy buenas tardes muy buenas noches
#
# en el momento en que estén viendo este
#
# este vídeo
#
# espero que todos se encuentren muy bien
#
# de salud así como sus familiares el día
#
# de sistema de gestión ambiental vamos a
#
# ver lo que es la lo que son los
#
# mencionado anteriormente
#
# la implementación de la norma se da a
#
# vemos básicamente lo que es lo que son
#
# lineamientos generales no alcance de la
#
# norma
#
# referencias normativas que en este caso
#
# comentado anteriormente no tiene
#
# referencias normativas o no digamos
#
# dentro de este dentro de esta norma no
#
# se nos indican referencias normativas
#
# puesto que cada país tiene normas
#
# distintas
#
# y bueno sin embargo si respeta lo que es
#
# la estructura de alto nivel porque todas
#
# las normas tienen que respetar la
#
# estructura de alto nivel
#
# entonces
#
# se hace
#
# de conocimiento algunas definiciones que
#
# ...

# %%
import re 
fhand = open("/content/sesiòn5.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# estimados alumnos como están
#
# buenos días van a estar les van las
#
# noches en el momento en que estén viendo
#
# esta estación
#
# bueno el día de hoy vamos a ver la
#
# implementación del sistema de gestión
#
# ambiental
#
# lo que vamos a ver es básicamente el
#
# estos momentos ya estamos viendo todo lo
#
# que es la implementación entonces un
#
# poco para recordar lo que hemos estado
#
# viendo
#
# durante la primera la primera parte del
#
# curso hemos visto respecto a la una
#
# introducción hemos dicho una
#
# introducción general respecto al sistema
#
# de gestión ambiental hemos visto el
#
# contexto en la organización no también
#
# hemos visto el liderazgo de
#
# planificación que a partir de aquí ya
#
# empezamos con un ciclo de demi yo les
#
# comentaba una dificultad de partir del
#
# implementación del sistema de gestión
#
# tres primeros capítulos eran básicamente
#
# introductorios
#
# hablaban del alcance hablaba de los de
#
# ...

# %%
import re 
fhand = open("/content/sesiòn6 ISo 14001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# bueno buenos días buenas tardes
#
# que estén viendo
#
# esta sesión y en este capítulo un poco
#
# para para insertarnos en este capítulo
#
# de la norma
#
# vamos a ver digamos cómo es que ya la
#
# norma no se empieza a hablar no de
#
# algunos controles operacionales que
#
# tienen que ver
#
# en el sistema de gestión ambiental y
#
# vamos a ver estos controles
#
# operacionales pues están relacionados a
#
# otros capítulos que ya hemos ido
#
# desarrollando en la norma
#
# ustedes recordarán pues que en lo que
#
# tenía que ver con por ejemplo la matriz
#
# de riesgos y oportunidades la matriz de
#
# aspectos de impactos ambientales
#
# nosotros si bien es cierto por ejemplo
#
# en la matriz de aspectos impactos
#
# ambientales
#
# identificamos
#
# cuál es cuál podría ser un aspecto
#
# ambiental
#
# de un determinado proceso dentro de la
#
# organización y cuál podría ser el
#
# impacto ambiental también que se podría
#
# originar producto
#
# ...

# %%
import re 
fhand = open("/content/sesiòn7 ISo 14001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# estimados alumnos cómo están buenos días
#
# buenas tardes ganas noches en el momento
#
# en que estén viendo este
#
# este esta sesión que es la sesión número
#
# básicamente lo que es la implementación
#
# del sistema de gestión ambiental y nos
#
# vamos a enfocar en un capítulo que es el
#
# anteriormente hemos visto desde el
#
# conversado mucho en relación a los
#
# requisitos que tiene cada capítulo de la
#
# norma entonces en esta oportunidad vamos
#
# vamos a ver el día de hoy este capítulo
#
# evaluación del desempeño no
#
# ya anteriormente hemos conversado
#
# respecto al ciclo ph o ciclo de mismo y
#
# yo les comentaba que la norma digamos en
#
# términos
#
# sencillos en términos generales estaba
#
# en dos grandes grupos no un primer grupo
#
# que
#
# que iba desde el capítulo cero o uno
#
# hasta el capítulo tres más que
#
# era básicamente de información general
#
# no nos proporcionaba información
#
# respecto al alcance el objetivo de la
#
# ...

# %%
import re 
fhand = open("/content/sesiòn8 ISo 14001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# buenos días buenas tardes buenas noches
#
# estimados alumnos en el momento en que
#
# estén viendo esta sesión por decisión
#
# la última sesión correspondiente a la
#
# implementación del sistema de gestión
#
# ambiental
#
# y el día de hoy vamos a ver básicamente
#
# estaríamos culminando todo lo
#
# relacionado al tema de implementar un
#
# sistema de gestión ambiental
#
# ya ya es el último la última sesión y en
#
# esta parte de nuestra última sesión
#
# la norma de la mejora ya
#
# ciclo de mejora continua el ciclo de
#
# demi ya estaríamos en la parte de la
#
# cual ya porque recuerden que desde el
#
# los capítulos que se implementan en los
#
# cuales nos ayudan a implementar un
#
# sistema de gestión ambiental dentro de
#
# una organización o una organización
#
# digamos un atrás
#
# entonces dentro de este último capítulo
#
# de la norma dentro de la de la mejora
#
# vamos a ver tres acápite físicos
#
# nosotros ya hemos pasado pues por todo
#
# ...

# %%
import re 
fhand = open("/content/SIG Sesión 1 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# pues bueno con todos hechos el día de
#
# hoy vamos a ver la parte introductoria
#
# es esta es una norma relacionada con la
#
# implementación de un sistema de gestión
#
# de seguridad en el trabajo es uno
#
# internacional no está se puede decir que
#
# la primera norma hizo en temas de
#
# seguridad en el trabajo bueno es esta
#
# esta clase este programa éste está
#
# dividido en dos sesiones en caso de
#
# financiación vamos a ver este punto la
#
# parte introductoria que íbamos a ir
#
# vamos a ir viendo este sucesivamente es
#
# la parte del contexto la parte liderar o
#
# el tema planificación el tema del apoyo
#
# el tema de cooperación en tema de
#
# evaluación y seguimiento y el tema mejor
#
# vamos a ir así despedir al mando este
#
# por semanas y la idea es que en este
#
# programa nos saquen provecho sobre los
#
# temas que se va a presentar no va a
#
# haber bastante parte de este parte de
#
# implementación como también tema de
#
# ...

# %%
import re 
fhand = open("/content/SIG Sesión 2 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# qué tal con todos el diario y cuando
#
# saber es todo lo relacionado un tercio
#
# con el tema del contexto ya la necesidad
#
# anterior hemos visto un poco de la
#
# historia
#
# como yo buscando la normativa
#
# internacional el tema esté seguros en el
#
# trabajo como es que nace en el tema de
#
# cosas es decir el uno es su versión al
#
# como la cosa que mis dos términos hay
#
# dos de bastante en el tema de directriz
#
# y para implementar el sistema es que
#
# bajó motivados a de ahí te hemos visto
#
# también este también como la la hizo
#
# porque el uno ha ido esté pasando varios
#
# procesos de revisión no para por fin en
#
# hizo
#
# también he visto algunos vamos a tener
#
# en cuenta y los la definiciones
#
# las descripciones que son muy
#
# importantes porque estas definiciones
#
# nos van a ayudar a
#
# como este entender la norma también
#
# hemos visto ahí algunos puntos
#
# importantes
#
# del tema los requisitos el tema los
#
# deberes se acabe estrenando a los
# ...

# %%
import re 
fhand = open("/content/SIG Sesión 3 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# bueno con todos muchachos el día de hoy
#
# vamos a ver
#
# lo que nos toca del
#
# pero siempre bueno uno va a hacer un
#
# pequeño repaso y un pequeño repaso de lo
#
# que vimos en la sesión anterior la
#
# acción de los muchachos vivimos lo que
#
# es la parte del contexto de la
#
# organización esta parte de cada
#
# muchachos nos indicaba este es una parte
#
# de más más más completa o sea que en
#
# esta parte díaz este en los indicadores
#
# como parte del sistema de gestión
#
# ya sea ver los temas de las actuaciones
#
# internas y externas
#
# ese concepto es nuevo en todas las
#
# normas entonces dentro del tema del
#
# contexto de la organización y ahora de
#
# cuatro puntos
#
# el mismo también la semana pasada
#
# [Música]
#
# la comprensión de la organización y de
#
# su contexto entonces en esta parte aquí
#
# está la norma nos nos pedía muchachos
#
# que nosotros este analicemos cualquier
#
# cuáles serían esas presiones internas y
#
# ...

# %%
import re 
fhand = open("/content/SIG Sesión 3 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# bueno con todos muchachos el día de hoy
#
# vamos a ver
#
# lo que nos toca del
#
# pero siempre bueno uno va a hacer un
#
# pequeño repaso y un pequeño repaso de lo
#
# que vimos en la sesión anterior la
#
# acción de los muchachos vivimos lo que
#
# es la parte del contexto de la
#
# organización esta parte de cada
#
# muchachos nos indicaba este es una parte
#
# de más más más completa o sea que en
#
# esta parte díaz este en los indicadores
#
# como parte del sistema de gestión
#
# ya sea ver los temas de las actuaciones
#
# internas y externas
#
# ese concepto es nuevo en todas las
#
# normas entonces dentro del tema del
#
# contexto de la organización y ahora de
#
# cuatro puntos
#
# el mismo también la semana pasada
#
# [Música]
#
# la comprensión de la organización y de
#
# su contexto entonces en esta parte aquí
#
# está la norma nos nos pedía muchachos
#
# que nosotros este analicemos cualquier
#
# cuáles serían esas presiones internas y
#
# ...

# %%
import re 
fhand = open("/content/SIG Sesión 3 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)

# %%
import re 
fhand = open("/content/SIG SESION 05 ISO 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# y bueno bien con todo muchacho ser bueno
#
# continuando con la quinta
#
# la sesión anterior este vimos es lo
#
# relacionado con el tema de abordar los
#
# riesgos y los riesgos y oportunidades
#
# como hacer un especial
#
# de resumen la semana pasada recordemos
#
# tema de acciones para abordar riesgos y
#
# oportunidades
#
# en este caso vimos que es una forma de
#
# analizar estos riesgos de dónde nacen
#
# los riesgos y estas oportunidades
#
# vimos que éstos nacen de acá de contexto
#
# si no me equivoco en el tema de al
#
# análisis de contexto el tema de parte
#
# interesada y el tema de alcance de la
#
# aseguración del sistema de gestión de
#
# servicio de trabajo entonces esto aquí
#
# nos va a hacer ninguno nos sirve con un
#
# mecanismo de entrada para hallar los
#
# riesgos desde y los otros riesgos
#
# y las oportunidades y
#
# oportunidades entonces
#
# comenzamos a enseñar que nosotros
#
# hablamos y mediante eso hacemos una
#
# evaluación de riesgos hacemos la
#
# ...

# %%
import re 
fhand = open("/content/SIG SESION 06 ISO 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# todo el día vamos a ver un tema ya que
#
# ya vamos hablando del tema del ciclo de
#
# mejora continua si ustedes recuerdan
#
# empezamos a la parte este inicial con el
#
# tema de planificar
#
# empezamos con el tema del hacer
#
# el tema de verificada y el tema de
#
# actuado y hemos visto
#
# lo que es el tema aquí el planificar
#
# llegando a sabemos la parte de
#
# planificar en la sesión anterior vimos
#
# parte de hacer y ahora los podcast en la
#
# entonces si se dan cuenta señores
#
# poco a poco la norma se va adaptando al
#
# ciclo mejora continua
#
# la idea es que nosotros cerramos el tema
#
# del ciclo como ya hemos visto el tema
#
# planificar ahora vamos a terminar el
#
# tema ver el tema del hacer la próxima
#
# ver el tema de este seguimiento
#
# temas de
#
# evaluación del desempeño en el capítulo
#
# huantina entonces cada capítulo se llamó
#
# en la isla línea señores el tema de
#
# ciclo mejora continua
#
# ahora bien lo que lo que vamos a ver va
#
# ...

# %%
import re 
fhand = open("/content/SIG SESION 07ISO 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# fechas de la noche con todos el día de
#
# tema de la evaluación del desempeño
#
# entonces esta parte lo que lo que vamos
#
# a ver es
#
# [Música]
#
# hacerle este seguimiento una medición
#
# análisis del todo lo que nosotros
#
# debemos planificar lo que hemos
#
# planificado en el tema del tel el
#
# tenemos a través hacerle seguimiento
#
# vamos a hacer medición y vamos a ver si
#
# te está cumpliendo lo apretamos este lo
#
# que nos hemos planificado
#
# en estas pláticas señores de éste
#
# si se dan cuenta ya estamos cerrando el
#
# tema es que el ciclo de mejora continua
#
# es con el tema del ph uva no entonces
#
# este más o menos es la lógica o el
#
# script del sistema de gestión que se
#
# maneja bajo el simple mejora continua
#
# entonces recordemos que cuando empezamos
#
# cual teme al planear vivimos acá en
#
# del tema
#
# de la planificación ahora en el capítulo
#
# aquí vimos ya de parte del apoyo y
#
# estamos la parte d
#
# el tema de operacional
#
# ...

# %%
import re 
fhand = open("/content/SIG SESION 08 ISO 45001.txt")
for line in fhand:
  if re.findall('[0-9:0-9]',line):
    continue
  else:
    print(line)
# Out:
# todos el día de hoy bueno ya estamos
#
# terminando el
#
# en la última sesión del programa de la
#
# el tema extra de el punto de mejora en
#
# mejora este donde vivió en tres
#
# claustros la plaza que vemos acá va a
#
# ser el tema esto de él la generalidad es
#
# y ahí vamos a ver algunos puntos que la
#
# norma y eso nos indica y la parte bueno
#
# donde vamos a ver más mayor este
#
# mayor y mayor detalles en este para la
#
# investigación de la de accidentes y no
#
# conformidades y las acciones correctivas
#
# la investigación de incidentes no
#
# conformidades y acciones colectivos ese
#
# vamos a agarrar y complementar con lo
#
# que nos pide la ley
#
# la ley también este maneja
#
# algunas definiciones totalmente por y
#
# vamos a comparar lo que define la norma
#
# hizo con lo que define la ley entonces
#
# también va a hacer algunas metodologías
#
# algunos templos
#
# también le voy a mostrar un ejemplo de
#
# una no conformidad para nosotros tenga
#
# ...
