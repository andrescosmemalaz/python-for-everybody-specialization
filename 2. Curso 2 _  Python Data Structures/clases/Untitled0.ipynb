# %%
contador = 0 
while True:
  x = int(input("Introduzca número : "))  
  if x < 0 :
    break
  else:
    contador  = contador + 1 

print(contador)
# Out:
# Introduzca número8
# Introduzca número9
# Introduzca número45
# Introduzca número98
# Introduzca número45
# Introduzca número-1
# 5
