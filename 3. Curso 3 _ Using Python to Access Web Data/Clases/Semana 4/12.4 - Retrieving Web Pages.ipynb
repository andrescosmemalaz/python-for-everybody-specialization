# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen("https://www.tuasaude.com/es/dolor-abdominal-en-lado-izquierdo/")
for line in fhand:
  print(line.decode().strip())
# Out:
# <!DOCTYPE html><html lang="es"><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"><title>Dolor abdominal del lado izquierdo: principales causas y qué hacer - Tua Saúde</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/><link rel="shortcut icon" href="https://static.tuasaude.com/favicon.ico"/><link rel="canonical" href="https://www.tuasaude.com/es/dolor-abdominal-en-lado-izquierdo/"/>  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-P8PXWDX');</script> <link href="https://plus.google.com/109663646160449411903" rel="publisher"/><link rel="alternate" type="application/
# ...

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen("http://data.pr4e.org/romeo.txt")
for line in fhand:
  print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen("http://data.pr4e.org/romeo.txt")

counts = dict()
for line in fhand:
  words = line.decode().strip()
  for word in words:
    counts[word] = counts.get(word, 0) + 1 
print(counts)
# Out:
# {'B': 1, 'u': 6, 't': 12, ' ': 29, 's': 11, 'o': 8, 'f': 3, 'w': 4, 'h': 9, 'a': 10, 'l': 6, 'i': 13, 'g': 3, 'r': 7, 'y': 2, 'n': 9, 'd': 6, 'e': 12, 'b': 1, 'k': 3, 'I': 1, 'J': 1, 'A': 1, 'v': 1, 'm': 1, 'W': 1, 'c': 1, 'p': 1}

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen("https://www.tuasaude.com/es/dolor-abdominal-en-lado-izquierdo/")

counts = dict()
for line in fhand:
  words = line.decode().strip()
  for word in words:
    counts[word] = counts.get(word, 0) + 1 
print(counts)
# Out:
# {'<': 979, '!': 7, 'D': 66, 'O': 62, 'C': 89, 'T': 85, 'Y': 14, 'P': 43, 'E': 135, ' ': 5296, 'h': 672, 't': 2900, 'm': 1346, 'l': 2256, '>': 979, 'a': 4403, 'n': 2530, 'g': 832, '=': 849, '"': 2212, 'e': 4763, 's': 3334, 'd': 2341, 'c': 1915, 'r': 2567, 'u': 1584, 'f': 516, '-': 864, '8': 145, 'p': 1242, 'q': 236, 'i': 3041, 'v': 564, 'X': 9, 'U': 28, 'A': 113, 'o': 3109, 'b': 560, 'I': 43, 'w': 249, ',': 506, '1': 379, 'x': 134, 'z': 181, ':': 417, 'y': 350, 'é': 84, 'S': 143, 'ú': 24, '/': 1228, ';': 76, 'F': 33, 'k': 85, '.': 728, '(': 82, ')': 82, '{': 80, '[': 50, ']': 50, '|': 16, "'": 84, 'j': 110, '}': 80, 'B': 28, 'N': 45, '0': 806, 'L': 39, '?': 18, '&': 10, '+': 19, 'G': 45, 'M': 48, 'W': 10, '9': 172, '6': 282, '3': 283, '4': 121, 'R': 44, 'í': 88, 'ñ': 29, 'ó': 114, 'á': 47, '@': 11, '\\': 386, 'Q': 38, '2': 267, '5': 136, '_': 112, 'V': 21, 'H': 23, '7': 167, '*': 1, 'K': 8, 'J': 3, 'Z': 2, '¿': 6, '›': 1, '%': 4, '\xa0': 40, '#': 9, 'º': 3, 'ç': 1, 'õ': 1, '¡': 1, 'Ú'
# ...

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
url = input("Ingresé su url : ")
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')

tags = soup('a')
for tag in tags:
  print(tag.get('href', None))
# fhand = urllib.request.urlopen("")

# counts = dict()
# for line in fhand:
#   words = line.decode().strip()
#   for word in words:
#     counts[word] = counts.get(word, 0) + 1 
# print(counts)
# Out:
# Ingresé su url : https://www.tuasaude.com/es/dolor-abdominal-en-lado-izquierdo/
# /es/
# /es/c/dieta-y-nutricion/
# /es/c/remedios-caseros/
# /es/c/adelgazar/
# /es/c/embarazo/
# /es/c/plantas-medicinales/
# /es/c/remedios-caseros/
# /es/c/adelgazar/
# /es/c/embarazo/
# /es/c/plantas-medicinales/
# /es/c/belleza-y-cosmetica/
# /es/c/fertilidad-y-control-de-la-natalidad/
# /es/c/coronavirus/
# /es/c/diabetes/
# /es/c/colesterol/
# /es/c/menopausia/
# /es/c/enfermedades-de-piel/
# /es/c/trastornos-psicologicos/
# /es/c/trastornos-gastrointestinales/
# /es/c/medicina-general/
# /es/c/enfermedades-geneticas/
# /es/c/enfermedades-respiratorias/
# /es/c/enfermedades-raras/
# /es/c/enfermedades-degenerativas/
# /es/c/sintomas/
# /es/c/alergias/
# /es/
# /es/t/gases-intestinales/
# /es/gonzalo-ramirez/
# /es/gonzalo-ramirez/
# ...
