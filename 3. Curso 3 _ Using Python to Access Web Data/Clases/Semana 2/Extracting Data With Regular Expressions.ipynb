# %% [markdown]
# https://docs.python.org/es/3/library/re.html

# %% [markdown]
# https://docs.python.org/3/howto/regex.html

# %%
import re

hand = open("/content/regex_sum_24962.txt")
x=list()
for line in hand:
     y = re.findall('[0-9]+',line)
     x = x+y

sum=0
for z in x:
    sum = sum + int(z)

print(sum)
# Out:
# 372517
