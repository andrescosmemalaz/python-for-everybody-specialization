# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Analisis exploratorio y visualización de datos/ Data Visualization Using Matplotlib/ Subplots/Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2)
fig.suptitle('Iris Dataset')
ax1.hist(data.SepalLengthCm,color='green')
ax1.set_title('SepalLengthCm')
ax1.set_xlabel("SepalLengthCm")
ax1.set_ylabel("Count")

ax2.hist(data.PetalLengthCm,color='y')
ax2.set_title('PetalLengthCm')
ax2.set_xlabel("PetalLengthCm")
ax2.set_ylabel("Count")

plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2)
fig.suptitle('Iris Dataset')
ax1.hist(data.SepalLengthCm,color='green')
ax1.set_title('SepalLengthCm')
ax1.set_xlabel("SepalLengthCm")
ax1.set_ylabel("Count")

ax2.hist(data.PetalLengthCm,color='y')
ax2.set_title('PetalLengthCm')
ax2.set_xlabel("PetalLengthCm")
ax2.set_ylabel("Count")
plt.tight_layout()

plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=2,ncols=1)
fig.suptitle('Iris Dataset')
ax1.hist(data.SepalLengthCm,color='green')
ax1.set_title('SepalLengthCm')
ax1.set_xlabel("SepalLengthCm")
ax1.set_ylabel("Count")

ax2.hist(data.PetalLengthCm,color='y')
ax2.set_title('PetalLengthCm')
ax2.set_xlabel("PetalLengthCm")
ax2.set_ylabel("Count")
plt.tight_layout()

plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2)
fig.suptitle('Iris Dataset')
ax1.hist(data.SepalLengthCm,color='g')
ax1.set_title('SepalLengthCm')
ax1.set_xlabel("SepalLengthCm")
ax1.set_ylabel("Count")

ax2.hist(data.PetalLengthCm,color='y')
ax2.set_title('PetalLengthCm')
ax2.set_xlabel("PetalLengthCm")
ax2.set_ylabel("Count")

ax3.hist(data.SepalWidthCm,color='b')
ax3.set_title('SepalWidthCm')
ax3.set_xlabel("SepalWidthCm")
ax3.set_ylabel("Count")

ax4.hist(data.PetalWidthCm,color='r')
ax4.set_title('PetalWidthCm')
ax4.set_xlabel("PetalWidthCm")
ax4.set_ylabel("Count")


plt.tight_layout()
plt.show()

# %% [markdown]
# # **SHaREX an dSharey**

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,sharex=True,
                                       sharey=True)
fig.suptitle('Iris Dataset')
ax1.hist(data.SepalLengthCm,color='g')
ax1.set_title('SepalLengthCm')
ax1.set_xlabel("SepalLengthCm")
ax1.set_ylabel("Count")

ax2.hist(data.PetalLengthCm,color='y')
ax2.set_title('PetalLengthCm')
ax2.set_xlabel("PetalLengthCm")
ax2.set_ylabel("Count")

ax3.hist(data.SepalWidthCm,color='b')
ax3.set_title('SepalWidthCm')
ax3.set_xlabel("SepalWidthCm")
ax3.set_ylabel("Count")

ax4.hist(data.PetalWidthCm,color='r')
ax4.set_title('PetalWidthCm')
ax4.set_xlabel("PetalWidthCm")
ax4.set_ylabel("Count")


plt.tight_layout()
plt.show()

# %% [markdown]
# Change Figure Size & Color

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,sharex=True,
                                       sharey=True,
                                       figsize=(10,6))
fig.suptitle('Iris Dataset')
ax1.hist(data.SepalLengthCm,color='g')
fig.set_edgecolor('black')
# fig.set_linewidth(3)
fig.set_facecolor('lightblue')
ax1.set_title('SepalLengthCm')
ax1.set_xlabel("SepalLengthCm")
ax1.set_ylabel("Count")

ax2.hist(data.PetalLengthCm,color='y')
ax2.set_title('PetalLengthCm')
ax2.set_xlabel("PetalLengthCm")
ax2.set_ylabel("Count")

ax3.hist(data.SepalWidthCm,color='b')
ax3.set_title('SepalWidthCm')
ax3.set_xlabel("SepalWidthCm")
ax3.set_ylabel("Count")

ax4.hist(data.PetalWidthCm,color='r')
ax4.set_title('PetalWidthCm')
ax4.set_xlabel("PetalWidthCm")
ax4.set_ylabel("Count")


plt.tight_layout()
plt.show()
