# %%
peliculas = ['Comedia','Terror','Ficciòn','Animada']
votos = [4,7,8,9]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # ***1. Draw A Pie Chart***

# %%
plt.pie(votos)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa88369b050>,
# ...
#  [Text(0.9910657451172095, 0.47727213291294374, ''),
#   Text(-0.12316096757443418, 1.0930834259406412, ''),
#   Text(-1.0724206837565986, -0.24477311341532132, ''),
#   Text(0.5852353838281754, -0.9313965565297568, '')])

# %%
plt.pie(votos)
plt.show()

# %% [markdown]
# # ***2. Give Title, Label (Also Change Label Distance), And Legend ***

# %%
plt.title('Favorite type movie ')
plt.pie(votos)
plt.show()

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas)
plt.show()

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas)
plt.legend()
plt.show()

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas,
        labeldistance=1.1)
plt.legend(loc=0)
plt.show()

# %% [markdown]
# # ***3. Pull out Action and Drama Wedges***

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0.15,0,0])    
plt.legend(loc=5)
plt.show()

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0,0.15])    
plt.legend(loc=5)
plt.show()

# %% [markdown]
# # ***4. Change The Start Angle To 90 Degree***

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90)    
plt.legend(loc=5)
plt.show()

# %% [markdown]
# # ***5. Set The Color of Each Wedge***

# %% [markdown]
# ```
# 'g' - Green
# 'r' - red
# 'y' - yellow
# 'c' - cyan
# 'm' - magenta
# 'w'- White
# 'k' - Black
# 'b' - blue
# ```

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90,
        colors = ['g','m','c','k'])    
plt.legend(loc=5)
plt.show()

# %% [markdown]
# # ***6. Display Percentage & Change Distance Inside Each Wedge***

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90,
        colors = ['g','m','c','y'],
        autopct = '%0.2f')    
plt.legend(loc=5)
plt.show()

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90,
        colors = ['g','m','c','y'],
        autopct = '%0.2f%%')    
plt.legend(loc=5)
plt.show()

# %%
plt.title('Favorite type movie ')
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90,
        colors = ['g','m','c','y'],
        autopct = '%0.2f%%',
        pctdistance= 0.8)    
plt.legend(loc=5,bbox_to_anchor=(1, 0.1, 0.5, 0.5))
plt.show()

# %% [markdown]
# # ***`7. Change Radius of The Pie Chart`***

# %%
plt.title('Favorite type movie ',y=1.35)
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90,
        colors = ['g','m','c','y'],
        autopct = '%0.2f%%',
        pctdistance= 0.8,
        radius=2)    
plt.legend(loc=5)
plt.show()

# %% [markdown]
# # ***8. Set Labels Size of The Pie Chart***

# %%
plt.title('Favorite type movie ',y=1.35)
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90,
        colors = ['g','m','c','y'],
        autopct = '%0.2f%%',
        pctdistance= 0.8,
        radius=2,
        textprops={'fontsize':12})    
plt.legend(loc=5,bbox_to_anchor=(1, 1, 0.5, 0.5))
plt.show()

# %% [markdown]
# # ***9. Set Border of The Wedges***

# %%
plt.title('Favorite type movie ',y=1.35)
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90,
        colors = ['g','m','c','y'],
        autopct = '%0.2f%%',
        pctdistance= 0.8,
        radius=2,
        textprops={'fontsize':12},
      ###
        wedgeprops={'edgecolor':'black',
                    'linewidth':'2',
                    'linestyle':':'},
        shadow = True)   
### 
plt.legend(loc=5)
plt.show()

# %% [markdown]
# # ***10. Add A shadow to the Pie Chart***

# %%
plt.figure(figsize=(10,4),edgecolor='black',
           linewidth= 3,facecolor='lightblue')
plt.title('Favorite type movie ',y=1.35)
plt.pie(votos,labels=peliculas,
        labeldistance=1.1,
        explode= [0,0,0.1,0.1],
        startangle=90,
        colors = ['g','m','c','y'],
        autopct = '%0.2f%%',
        pctdistance= 0.8,
        radius=2,
        textprops={'fontsize':12},
      ###
        wedgeprops={'edgecolor':'black',
                    'linewidth':'2',
                    'linestyle':':'},
        shadow = True)   
### 
plt.legend(loc='upper right',bbox_to_anchor=(1, 1, 0.5, 0.5))
plt.show()
