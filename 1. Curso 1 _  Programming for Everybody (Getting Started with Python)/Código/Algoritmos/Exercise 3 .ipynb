# %%
# Finding the largest value
largest_so_far = -1
print('Before', largest_so_far)

for the_num in [9, 41, 12, 3, 74, 15]:
    if the_num > largest_so_far:
        largest_so_far = the_num
    print(largest_so_far, the_num)

print('After', largest_so_far)
# Out:
# Before -1
# 9 9
# 41 41
# 41 12
# 41 3
# 74 74
# 74 15
# After 74

# %%
primer_numero = 0
print("Actual",primer_numero)
for tour in [12,78,72,16,3,74,95]:
  if  tour > primer_numero:
    primer_numero = tour
  print(primer_numero, tour)
  
print("Despues",primer_numero)
# Out:
# Actual 0
# 12 12
# 78 78
# 78 72
# 78 16
# 78 3
# 78 74
# 95 95
# Despues 95

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Determinamos el valor del primer_numero  con 0 
primer_numero = 0
# Comprobamos el valor de la variable asignada
print("Actual",primer_numero)
# Con el ciclo for por cada valor dentro de la lista 
for tour in [12,78,72,16,3,74,95]:
  #Podemos comprobar el valor para recorrido
  print(tour)
  # con un estructura de control de si el valor tour 
  # de la ieración es mayor al valor asignado al primer_numero
  if  tour > primer_numero:
    # guardamos el valor tour en la variable primer_numero
    primer_numero = tour
  #Procedemos a mostrar el valor nuevo con primer_numero y el valor que se itero
  print(primer_numero, tour)

print("Despues",primer_numero) # finalmente cuando se termina el bucle for imprimimos el mayor valor
# Out:
# Actual 0
# 12
# 12 12
# 78
# 78 78
# 72
# 78 72
# 16
# 78 16
# 3
# 78 3
# 74
# 78 74
# 95
# 95 95
# Despues 95

# %%
# Determinados la variable contador la variable contador 
contador = 0
primer_numero = 0
sum = 0 
print("Actual",primer_numero)
for tour in [12,78,72,16,3,74,95]:
  # Cada vez que recorre un valor tour se agrega 1 al contador
  contador = contador + 1
  # cada vez que recorre el valor de tour que proviene de la cadena, se suma 
  # y se guarda en la variable suma
  sum = sum + tour
  if  tour > primer_numero:
    primer_numero = tour       
  print(primer_numero, tour, contador) #Finalmente mostramos el valor de los números
  
print("Despues","El mayor valor es",primer_numero,"La cantidad de números es ", contador,"La suma de los valores es",sum,"El promedio de la lista es",sum/contador)
# Out:
# Actual 0
# 12 12 1
# 78 78 2
# 78 72 3
# 78 16 4
# 78 3 5
# 78 74 6
# 95 95 7
# Despues El mayor valor es 95 La cantidad de números es  7 La suma de los valores es 350 El promedio de la lista es 50.0

# %%
lista = []
while True :
  x = int(input("Ingresé su número: "))
  if x == 0 :
    break
  else:
    lista.append(x)
print(lista)
# Out:
# Ingresé su número: 15
# Ingresé su número: 18
# Ingresé su número: 0
# [15, 18]

# %%
# Determinados la variable contador la variable contador 
contador = 0
primer_numero = 0
sum = 0 
#print("Actual",primer_numero)
for tour in [12,78,72,16,3,74,95]:
  # Cada vez que recorre un valor tour se agrega 1 al contador
  contador = contador + 1
  # cada vez que recorre el valor de tour que proviene de la cadena, se suma 
  # y se guarda en la variable suma
  sum = sum + tour
  if  tour > primer_numero:
    primer_numero = tour       
  #print(primer_numero, tour, contador) #Finalmente mostramos el valor de los números
  
print("El promedio de la lista es",sum/contador)
# Out:
# El promedio de la lista es 50.0

# %%
def  anaytics_list(x):
  contador = 0
  primer_numero = 0
  sum = 0 
  print("Actual",primer_numero)
  for tour in x:
    contador = contador + 1
    sum = sum + tour
    if  tour > primer_numero:
      primer_numero = tour       
      print(primer_numero, tour, contador) #Finalmente mostramos el valor de los números
  print("Despues","El mayor valor es",primer_numero,"La cantidad de números es ", contador,"La suma de los valores es",sum,"El promedio de la lista es",sum/contador)

# %%
anaytics_list(lista)
# Out:
# Actual 0
# 7 7 1
# 8 8 2
# 9 9 3
# 10 10 4
# 12 12 5
# 15 15 6
# 16 16 7
# 74 74 8
# 789 789 9
# Despues El mayor valor es 789 La cantidad de números es  10 La suma de los valores es 1432 El promedio de la lista es 143.2

# %%
lista = []
while True :
  x = int(input("Ingresé su número: "))
  if x == 0 :
    break
  else:
    lista.append(x)
print(lista)
# Out:
# Ingresé su número: 250
# Ingresé su número: 700
# Ingresé su número: 195
# Ingresé su número: 789
# Ingresé su número: 45
# Ingresé su número: 789
# Ingresé su número: 782
# Ingresé su número: 105000
# Ingresé su número: 0
# [250, 700, 195, 789, 45, 789, 782, 105000]

# %%
anaytics_list(lista)
# Out:
# Actual 0
# 250 250 1
# 700 700 2
# 789 789 4
# 105000 105000 8
# Despues El mayor valor es 105000 La cantidad de números es  8 La suma de los valores es 108550 El promedio de la lista es 13568.75

# %%
def  anaytics_list(x):
  contador = 0
  primer_numero = 0
  mayor = 0
  menor = 0
  sum = 0 
  # print("Actual",mayor)
  for tour in x:
    contador = contador + 1
    sum = sum + tour
    if  tour > mayor:
      mayor = tour
    if tour < mayor:
      menor = tour
      # print(primer_numero, tour, contador) #Finalmente mostramos el valor de los números
  print("Despues","El mayor valor es",mayor,"La cantidad de números es ", contador,"La suma de los valores es",sum,"El promedio de la lista es", round(sum/contador,2) , "El valor menor de la lista es",menor)

# %%
lista = []
while True :
  x = int(input("Ingresé su número: "))
  if x == 0 :
    break
  else:
    lista.append(x)
print(lista)
# Out:
# Ingresé su número: 250
# Ingresé su número: 1250
# Ingresé su número: 75
# Ingresé su número: 189
# Ingresé su número: 0
# [250, 1250, 75, 189]

# %%
anaytics_list(lista)
# Out:
# Despues El mayor valor es 1250 La cantidad de números es  4 La suma de los valores es 1764 El promedio de la lista es 441.0 El valor menor de la lista es 189
