# %%
smallest = None
# Seen nothing so far, so will wait.

print('Before', smallest)

for value in [9, 41, 12, 3, 74, 15]:
    if smallest is None:
        smallest = value
    # This will happen the first time where smallest = 9
    # After the first time, it'll be permanently false
    elif value < smallest:
        smallest = value
    # This runs until the loop iterates through the array
    print(smallest, value)

print('After', smallest)

# Only use is when checking for None or False or True
# Other times, use comparison operator ==
# Out:
# Before None
# 9 9
# 9 41
# 9 12
# 3 3
# 3 74
# 3 15
# After 3

# %%
number = None

print("Inicio")

for valor in [9,15,78,3,64,13,20]:
  if number is None:
    number  = valor
  elif valor > number:
    number = valor
  print(number,valor)

print('Final',number,"mayor")
# Out:
# Inicio
# 9 9
# 15 15
# 78 78
# 78 3
# 78 64
# 78 13
# 78 20
# Final 78 mayor

# %%
number = None

print("Inicio")

for valor in [9,15,78,3,64,13,20]:
  if number is None:
    number  = valor
  elif valor < number:
    number = valor
  print(number,valor)

print('Final',number,"menor")
# Out:
# Inicio
# 9 9
# 9 15
# 9 78
# 3 3
# 3 64
# 3 13
# 3 20
# Final 3 menor
