# %%
hrs = input("Enter Hours: ")
hrs_int = float(hrs)

hourly_rate = input("Hourly Rate: ")
hourly_rate_int = float(hourly_rate)
overtime_multiplier = 1.5
hourly_overtime = hourly_rate_int * overtime_multiplier

if hrs_int <= 40:
    gross_pay = hrs_int * hourly_rate_int
    print(gross_pay)
else:
    hrs_over = hrs_int - 40
    gross_pay_overtime = (40 * hourly_rate_int) + (hrs_over * hourly_overtime)
    print(gross_pay_overtime)
# Out:
# Enter Hours: 56
# Hourly Rate: 4
# 256.0

# %%
# Determinas una variable para ingresar horas por el usuario
horas = input("Ingresé el número de Horas :")
# convertimos la variable ingresada debemos convertirla en un entero con int 
horas = int(horas)
# Ingresamos el valor de tarifa por hora
ratio_precio = input("Ingresé el valor de tarifa por hora :")
# convertimos la variable ingresada debemos convertirla en un entero con int 
ratio_precio = float(ratio_precio)
# Determinamos el valor de hora extra 
valor_por_hora_extra = 1.5
#Determinamos el valor por cada valor extra
hora_extraeordinaria = ratio_precio * valor_por_hora_extra

if horas <= 40:
  salario_bruto = horas * ratio_precio
  print(salario_bruto)
else:
  horas_nuevo = horas - 40 
  salario_bruto_nuevo = (40 * ratio_precio) +(horas_nuevo *hora_extraeordinaria )
# Out:
# Ingresé el número de Horas :4
# Ingresé el valor 5
