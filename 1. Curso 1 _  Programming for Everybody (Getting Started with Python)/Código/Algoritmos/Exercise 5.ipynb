# %%
# Se declara una variable con un string 
fruit = 'banana'
# iniciamos el lector con el index en 0
index = 0
# Definimos una estructura iterativa 
# donde mientras el index sea menor que 
# la cantidad de letras que encuentra la función len
# almacenas el indice y de acuerdo a la palabra , se determina una variable
# letter , conforme se generan las iteraciones, se realiza el analisis 

while index < len(fruit):
    letter = fruit[index]
    print(index, letter)
    index += 1

print (" ")

for letter in fruit:
    print(letter)
# Out:
# 0 b
# 1 a
# 2 n
# 3 a
# 4 n
# 5 a
#
# b
# a
# n
# a
# n
# a

# %%
def index_letter(a):
  index = 0
  while index < len(a):
    letter = a[index]
    print(index, letter)
    index += 1

# %%
index_letter("Andres cosme Malasquez")
# Out:
# 0 A
# 1 n
# 2 d
# 3 r
# 4 e
# 5 s
# 6
# 7 c
# 8 o
# 9 s
# 10 m
# 11 e
# 12
# 13 M
# 14 a
# 15 l
# 16 a
# 17 s
# 18 q
# 19 u
# 20 e
# 21 z

# %%
len(fruit)
# Out:
# 6

# %%
# Out:
# ['andres']
