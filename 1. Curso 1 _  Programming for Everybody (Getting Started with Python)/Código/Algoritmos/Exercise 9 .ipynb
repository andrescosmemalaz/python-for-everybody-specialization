# %%
def greet(lang):
    if lang == 'es':
        print('Hola')
    elif lang == 'fr':
        print('Bonjour')
    else:
        print('Hello')   

greet('fr')
greet("")
greet("es")
# Out:
# Bonjour
# Hello
# Hola
