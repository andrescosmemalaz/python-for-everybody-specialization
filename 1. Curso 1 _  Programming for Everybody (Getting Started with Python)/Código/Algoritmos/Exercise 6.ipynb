# %%
  
# Definimos la funcion add two 
# definimos la funcion added a + b 
# 
def addtwo(a, b):
    added = a + b
    return added
# a,b are parameters

x = addtwo(3, 5)
print(x)
# 3,5 are arguments
# Out:
# 8

# %%
def subtractiontwo(a,b):
  subtraction = a - b
  return subtraction

# %%
x = subtractiontwo(9,10)
# ,5 are arguments
print(x)
# Out:
# -1
