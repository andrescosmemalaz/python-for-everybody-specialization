# %% [markdown]
# # ***Project - 5 (Case Study - 5) | Data Analysis With Python Pandas ***

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Tratamiento y transformación de Datos/Pandas/Project/Project - 5 (Case Study - 5) | Data Analysis With Python Pandas /googleplaystore.csv")

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
data.describe(include='all')
# Out:
#            App Category  ...         Current Ver Android Ver
# count    10841    10841  ...               10833       10838
# unique    9660       34  ...                2832          33
# top     ROBLOX   FAMILY  ...  Varies with device  4.1 and up
# freq         9     1972  ...                1459        2451
# mean       NaN      NaN  ...                 NaN         NaN
# std        NaN      NaN  ...                 NaN         NaN
# min        NaN      NaN  ...                 NaN         NaN
# 25%        NaN      NaN  ...                 NaN         NaN
# 50%        NaN      NaN  ...                 NaN         NaN
# 75%        NaN      NaN  ...                 NaN         NaN
# max        NaN      NaN  ...                 NaN         NaN
#
# [11 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data.shape
# Out:
# (10841, 13)

# %% [markdown]
# # ***1. Display Top 5 Rows of The Dataset***

# %%
data.head(5)
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %% [markdown]
# # ***2. Check the Last 3 Rows of The Dataset***

# %%
data.tail(3)
# Out:
#                                                  App  ...         Android Ver
# 10838                         Parkinson Exercices FR  ...          2.2 and up
# 10839                  The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [3 rows x 13 columns]

# %% [markdown]
# # ***3. Find Shape of Our Dataset (Number of Rows & Number of Columns)***

# %%
print("filas",data.shape[0])
print("columns",data.shape[1])
# Out:
# filas 10841
# columns 13

# %% [markdown]
# # ***4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement***

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # *5. Get Overall Statistics About The Dataframe*

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
data.describe(include='all')
# Out:
#            App Category  ...         Current Ver Android Ver
# count    10841    10841  ...               10833       10838
# unique    9660       34  ...                2832          33
# top     ROBLOX   FAMILY  ...  Varies with device  4.1 and up
# freq         9     1972  ...                1459        2451
# mean       NaN      NaN  ...                 NaN         NaN
# std        NaN      NaN  ...                 NaN         NaN
# min        NaN      NaN  ...                 NaN         NaN
# 25%        NaN      NaN  ...                 NaN         NaN
# 50%        NaN      NaN  ...                 NaN         NaN
# 75%        NaN      NaN  ...                 NaN         NaN
# max        NaN      NaN  ...                 NaN         NaN
#
# [11 rows x 13 columns]

# %% [markdown]
# # ***6. Total Number of App Titles Contain Astrology***

# %%
data.head(1)
# Out:
#                                               App  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
#
# [1 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data[data['App'].str.contains('Astrology',case=False)]
# Out:
#                                                      App  ...         Android Ver
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  ...        4.0.3 and up
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  ...        4.0.3 and up
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [3 rows x 13 columns]

# %%
len(data[data['App'].str.contains('Astrology',case=False)])
# Out:
# 3

# %% [markdown]
# # ***7. Find Average App Rating***

# %%
data['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
z = round(data['Rating'].mean(),2)
print("Average App Rating is", z)
# Out:
# Average App Rating is 4.19

# %% [markdown]
# # ***8.  Find Total Number of Unique Category***

# %%
data.head(1)
# Out:
#                                               App  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
#
# [1 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
data['Category'].nunique()
# Out:
# 34

# %% [markdown]
# # ***9. Which Category Getting The Highest Average Rating?***

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.groupby('Category')['Rating'].mean()
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %%
data.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
max(data.groupby('Category')['Rating'].mean())
# Out:
# 19.0

# %% [markdown]
# # *10. Find Total Number of App having 5 Star Rating*

# %%
data.head(5)
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data['Rating'].value_counts()
# Out:
# 4.4     1109
# 4.3     1076
# 4.5     1038
# 4.2      952
# 4.6      823
# 4.1      708
# 4.0      568
# 4.7      499
# 3.9      386
# 3.8      303
# 5.0      274
# 3.7      239
# 4.8      234
# 3.6      174
# 3.5      163
# 3.4      128
# 3.3      102
# 4.9       87
# 3.0       83
# 3.1       69
# 3.2       64
# 2.9       45
# 2.8       42
# 2.6       25
# 2.7       25
# 2.5       21
# 2.3       20
# 2.4       19
# 1.0       16
# 2.2       14
# 1.9       13
# 2.0       12
# 2.1        8
# 1.7        8
# 1.8        8
# 1.6        4
# 1.4        3
# 1.5        3
# 1.2        1
# 19.0       1
# Name: Rating, dtype: int64

# %%
data['Rating'] == 5
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837     True
# 10838    False
# 10839    False
# 10840    False
# Name: Rating, Length: 10841, dtype: bool

# %%
data[data['Rating'] == 5]
# Out:
#                                               App  ...   Android Ver
# 329                  Hojiboy Tojiboyev Life Hacks  ...  4.0.3 and up
# 612                 American Girls Mobile Numbers  ...  4.0.3 and up
# 615                                  Awake Dating  ...    4.4 and up
# 633                         Spine- The dating app  ...  4.0.3 and up
# 636    Girls Live Talk - Free Text and Video Chat  ...  4.0.3 and up
# ...                                           ...  ...           ...
# 10721                           Mad Dash Fo' Cash  ...    4.1 and up
# 10742                       GKPB FP Online Church  ...    4.4 and up
# 10776                            Monster Ride Pro  ...    2.3 and up
# 10820                             Fr. Daoud Lamei  ...    4.1 and up
# 10837            Fr. Mike Schmitz Audio Teachings  ...    4.1 and up
#
# [274 rows x 13 columns]

# %%
len(data[data['Rating'] == 5])
# Out:
# 274

# %% [markdown]
# # ***11. Find Average Value of Reviews***

# %%
data.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
data['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
data['Reviews'].value_counts()
# Out:
# 0        596
# 1        272
# 2        214
# 3        175
# 4        137
#         ...
# 21159      1
# 29495      1
# 14210      1
# 20763      1
# 10806      1
# Name: Reviews, Length: 6002, dtype: int64

# %%
len(data['Reviews'].value_counts())/sum(data['Reviews'].value_counts())
# Out:
# 0.5536389631952772

# %%
data['Reviews'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-ddff1a043af0> in <module>()
# ----> 1 data['Reviews'].astype('float')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data['Reviews'] == '3.0M'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Reviews, Length: 10841, dtype: bool

# %%
data[data['Reviews'] == '3.0M']
# Out:
#                                            App Category  ...  Current Ver Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9  ...   4.0 and up         NaN
#
# [1 rows x 13 columns]

# %%
data['Reviews'] = data['Reviews'].replace('3.0M',3.0)

# %%
data['Reviews'] = data['Reviews'].astype('float')

# %%
data['Reviews'].dtype
# Out:
# dtype('float64')

# %%
data['Reviews'].mean()
# Out:
# 444111.9265750392

# %% [markdown]
# # ***12. Find Total Number of Free and Paid Apps***

# %%
data.head(1)
# Out:
#                                               App  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
#
# [1 rows x 13 columns]

# %%
data['Type']
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10841, dtype: object

# %%
data['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %% [markdown]
# # ***13.  Which App Has Maximum Reviews?***

# %%
data.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data['Reviews']
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10836        38.0
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 10841, dtype: float64

# %%
data['Reviews'].sort_values(ascending=False)
# Out:
# 2544     78158306.0
# 3943     78128208.0
# 336      69119316.0
# 381      69119316.0
# 3904     69109672.0
#             ...
# 5100            0.0
# 10762           0.0
# 9557            0.0
# 630             0.0
# 7737            0.0
# Name: Reviews, Length: 10841, dtype: float64

# %%
data.head(2545)
# Out:
#                                                     App  ...         Android Ver
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                   Coloring book moana  ...        4.0.3 and up
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                 Sketch - Draw & Paint  ...          4.2 and up
# 4                 Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                 ...  ...                 ...
# 2540                       PatientPORTAL by InteliChart  ...          5.0 and up
# 2541                   Hypertension High blood pressure  ...        4.0.3 and up
# 2542                                         Fever Care  ...        4.0.3 and up
# 2543                         1800 Contacts - Lens Store  ...          5.0 and up
# 2544                                           Facebook  ...  Varies with device
#
# ...

# %%
data['Reviews'].max()
# Out:
# 78158306.0

# %%
data['Reviews'].max() == data['Reviews']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Reviews, Length: 10841, dtype: bool

# %%
data[data['Reviews'].max() == data['Reviews']]
# Out:
#            App Category  ...         Current Ver         Android Ver
# 2544  Facebook   SOCIAL  ...  Varies with device  Varies with device
#
# [1 rows x 13 columns]

# %% [markdown]
# # ***14. Display Top 5 Apps Having Highest Reviews***

# %%
data_extraida = data['Reviews'].sort_values(ascending=False).head(5)

# %%
entradas = pd.Series([11, 18, 12, 16, 9, 16, 22, 28, 31, 29, 30, 12],
            index = ["ene", "feb", "mar", "abr", "may", "jun", "jul", "ago",
             "sep", "oct", "nov", "dic"])
salidas = pd.Series([9, 26, 18, 15, 6, 22, 19, 25, 34, 22, 21, 14],
            index = ["ene", "feb", "mar", "abr", "may", "jun", "jul", "ago",
             "sep", "oct", "nov", "dic"])

# %%
almacén = pd.DataFrame({"entradas": entradas, "salidas": salidas})
almacén["neto"] = almacén.entradas - almacén.salidas

# %%
almacén.head()
# Out:
#      entradas  salidas  neto
# ene        11        9     2
# feb        18       26    -8
# mar        12       18    -6
# abr        16       15     1
# may         9        6     3

# %%
data['Reviews'].sort_values(ascending=False).head().index
# Out:
# Int64Index([2544, 3943, 336, 381, 3904], dtype='int64')

# %%
index = data['Reviews'].sort_values(ascending=False).head().index

# %%
data.iloc[index]
# Out:
#                      App       Category  ...         Current Ver         Android Ver
# 2544            Facebook         SOCIAL  ...  Varies with device  Varies with device
# 3943            Facebook         SOCIAL  ...  Varies with device  Varies with device
# 336   WhatsApp Messenger  COMMUNICATION  ...  Varies with device  Varies with device
# 381   WhatsApp Messenger  COMMUNICATION  ...  Varies with device  Varies with device
# 3904  WhatsApp Messenger  COMMUNICATION  ...  Varies with device  Varies with device
#
# [5 rows x 13 columns]

# %%
data.iloc[index]['App']
# Out:
# 2544              Facebook
# 3943              Facebook
# 336     WhatsApp Messenger
# 381     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %% [markdown]
# # ***15. Find Average Rating of Free and Paid Apps***

# %%
data.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
data.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# # ***16. Display Top  5 Apps Having Maximum Installs***

# %%
data['Installs'].sort_values()
# Out:
# 9148                0
# 5486               0+
# 8614               0+
# 9337               0+
# 9719               0+
#              ...
# 4041     500,000,000+
# 4147     500,000,000+
# 4048     500,000,000+
# 3767     500,000,000+
# 10472            Free
# Name: Installs, Length: 10841, dtype: object

# %%
index_new = data['Installs'].sort_values(ascending=False).head().index

# %%
data['Installs'].dtype
# Out:
# dtype('O')

# %%
data.iloc[index_new]
# Out:
#                                            App  ...         Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame  ...                 NaN
# 3767              Flipboard: News For Our Time  ...  Varies with device
# 4048                                   Dropbox  ...  Varies with device
# 4147              Gboard - the Google Keyboard  ...  Varies with device
# 4041                              Temple Run 2  ...          4.0 and up
#
# [5 rows x 13 columns]

# %%
data.iloc[index_new]['App']
# Out:
# 10472    Life Made WI-Fi Touchscreen Photo Frame
# 3767                Flipboard: News For Our Time
# 4048                                     Dropbox
# 4147                Gboard - the Google Keyboard
# 4041                                Temple Run 2
# Name: App, dtype: object

# %%
data['Installs_value'] = data['Installs'].str.replace('+','')

# %%
data.head(1)
# Out:
#                                               App  ... Installs_value
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...         10,000
#
# [1 rows x 14 columns]

# %%
data['Installs_value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-a2b53c0748e3> in <module>()
# ----> 1 data['Installs_value'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data[data['Installs_value'] == '10,000'].astype('int')
# Out:
#                                                   App  ... Installs_value
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ...         10,000
# 9                       Kids Paint Free - Drawing Fun  ...         10,000
# 17                           350 Diy Room Decor Ideas  ...         10,000
# 25                         Harley Quinn wallpapers HD  ...         10,000
# 28                              Pencil Sketch Drawing  ...         10,000
# ...                                               ...  ...            ...
# 10813                                  DICT.fr Mobile  ...         10,000
# 10818                            Gold Quote - Gold.fr  ...         10,000
# 10824                                       Cardio-FR  ...         10,000
# 10828                         Manga-FR - Anime Vostfr  ...         10,000
# 10829                  Bulgarian French Dictionary Fr  ...         10,000
#
# [1054 rows x 14 columns]

# %%
data['Installs_value'] = data['Installs_value'].str.replace('10,000','10000')

# %%
data['Installs_value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-a2b53c0748e3> in <module>()
# ----> 1 data['Installs_value'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data['Installs_value'] = data['Installs_value'].str.replace('500,000','500000')

# %%
data['Installs_value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-a2b53c0748e3> in <module>()
# ----> 1 data['Installs_value'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data['Installs_value'] = data['Installs_value'].str.replace('5,000,000','5000000')

# %%
data['Installs_value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-a2b53c0748e3> in <module>()
# ----> 1 data['Installs_value'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data['Installs_value'] = data['Installs_value'].str.replace('50,000,000','50000000')

# %%
data['Installs_value'] = data['Installs_value'].str.replace('100,000','100000')

# %%
data['Installs_value'] = data['Installs_value'].str.replace('1,000,000','1000000')

# %%
data['Installs_value'] = data['Installs_value'].str.replace('10000,000','10000000')

# %%
data['Installs_value'] = data['Installs_value'].str.replace('50,000','50000')

# %%
data['Installs_value'] = data['Installs_value'].str.replace('5,000','5000')

# %%
data['Installs_value'] = data['Installs_value'].str.replace('100000,000','100000000')

# %%
data['Installs_value'] = data['Installs_value'].str.replace('1000000,000','1000000000')

# %%
data['Installs_value'] = data['Installs_value'].str.replace('1000000,000','1000000000')

# %%
data['Installs_value'] = data['Installs'].str.replace('+','')

# %%
data['Installs_value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-204-a2b53c0748e3> in <module>()
# ----> 1 data['Installs_value'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data['Installs_value'] = data['Installs'].str.replace(',','')

# %%
data['Installs_value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-a2b53c0748e3> in <module>()
# ----> 1 data['Installs_value'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data['Installs_value']
# Out:
# 0           10000+
# 1          500000+
# 2         5000000+
# 3        50000000+
# 4          100000+
#            ...
# 10836        5000+
# 10837         100+
# 10838        1000+
# 10839        1000+
# 10840    10000000+
# Name: Installs_value, Length: 10841, dtype: object

# %%
data['Installs_value'] = data['Installs'].str.replace('+','')

# %%
data['Installs_value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-209-a2b53c0748e3> in <module>()
# ----> 1 data['Installs_value'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data['Installs_value'] = data['Installs_value'].astype('str')

# %%
data['Installs_value'] = data['Installs'].str.replace(',','')
data['Installs_value'] = data['Installs'].str.replace('+','')

# %%
data['Installs_value']
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs_value, Length: 10841, dtype: object

# %%
data['Installs_value'].astype('str')
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs_value, Length: 10841, dtype: object

# %%
data[] = data['Installs'].str.replace(',','')

# %%
data.drop(['Installs_value'], axis=1)
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# ...

# %%
data['Installs_1'] = data['Installs'].str.replace(',','')

# %%
data.head()
# Out:
#                                                  App  ... Installs_1
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...     10000+
# 1                                Coloring book moana  ...    500000+
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...   5000000+
# 3                              Sketch - Draw & Paint  ...  50000000+
# 4              Pixel Draw - Number Art Coloring Book  ...    100000+
#
# [5 rows x 15 columns]

# %%
data['Installs_1'] = data['Installs_1'].str.replace('+','')

# %%
data.head()
# Out:
#                                                  App  ... Installs_1
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...      10000
# 1                                Coloring book moana  ...     500000
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...    5000000
# 3                              Sketch - Draw & Paint  ...   50000000
# 4              Pixel Draw - Number Art Coloring Book  ...     100000
#
# [5 rows x 15 columns]

# %%
data['Installs_1'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-232-991a23e0cd05> in <module>()
# ----> 1 data['Installs_1'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data['Installs_1'] == 'Free'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Installs_1, Length: 10841, dtype: bool

# %%
data[data['Installs_1'] == 'Free']
# Out:
#                                            App  ... Installs_1
# 10472  Life Made WI-Fi Touchscreen Photo Frame  ...       Free
#
# [1 rows x 15 columns]

# %%
data['Installs_1'] = data['Installs_1'].str.replace('Free','0')

# %%
data['Installs_1'].astype('int')
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs_1, Length: 10841, dtype: int64

# %%
index = data['Installs_1'].sort_values(ascending=False).head().index

# %%
index = data['Installs_1'].sort_values(ascending=False).head().index
data.iloc[index]
# Out:
#                   App            Category  ...  Installs_value  Installs_1
# 385   Viber Messenger       COMMUNICATION  ...      500000000+   500000000
# 1662              Pou                GAME  ...      500000000+   500000000
# 1885              Pou                GAME  ...      500000000+   500000000
# 1702              Pou                GAME  ...      500000000+   500000000
# 3796          Twitter  NEWS_AND_MAGAZINES  ...      500000000+   500000000
#
# [5 rows x 15 columns]

# %%
data.iloc[index]['App']
# Out:
# 385     Viber Messenger
# 1662                Pou
# 1885                Pou
# 1702                Pou
# 3796            Twitter
# Name: App, dtype: object

# %%
import pandas as pd
data1 = pd.read_csv("/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Tratamiento y transformación de Datos/Pandas/Project/Project - 5 (Case Study - 5) | Data Analysis With Python Pandas /googleplaystore.csv")

# %%
data1.head(1)
# Out:
#                                               App  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
#
# [1 rows x 13 columns]

# %%
data1['Installs'].dtype
# Out:
# dtype('O')

# %%
data1['Installs_1'] = data1['Installs'].str.replace(',','')

# %%
data1['Installs_1'] = data1['Installs_1'].str.replace('+','')

# %%
data1['Installs_1'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-248-3a449a343f10> in <module>()
# ----> 1 data1['Installs_1'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
data1['Installs_1'] = data1['Installs_1'].str.replace('Free','0')

# %%
data1['Installs_1'] = data1['Installs_1'].str.replace('1,000,000,000+','1000000000')

# %%
data1['Installs_1'].astype('int')
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs_1, Length: 10841, dtype: int64

# %%
index = data1['Installs_1'].sort_values(ascending=False).head().index
data1.iloc[index]
# Out:
#                   App            Category  ...         Android Ver Installs_1
# 385   Viber Messenger       COMMUNICATION  ...  Varies with device  500000000
# 1662              Pou                GAME  ...          4.0 and up  500000000
# 1885              Pou                GAME  ...          4.0 and up  500000000
# 1702              Pou                GAME  ...          4.0 and up  500000000
# 3796          Twitter  NEWS_AND_MAGAZINES  ...  Varies with device  500000000
#
# [5 rows x 14 columns]

# %%
500000000<1000000000
# Out:
# True

# %%
data1.iloc[[4096,3234]]
# Out:
#          App       Category  ...         Android Ver  Installs_1
# 4096   Gmail  COMMUNICATION  ...  Varies with device  1000000000
# 3234  Google          TOOLS  ...  Varies with device  1000000000
#
# [2 rows x 14 columns]
