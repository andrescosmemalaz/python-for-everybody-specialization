# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Tratamiento y transformación de Datos/Pandas/Project/Project - 8 (Case Study - 8) /top-5000-youtube-channels.csv")

# %%
data
# Out:
#          Rank Grade  ... Subscribers  Video views
# 0         1st  A++   ...    18752951  20869786591
# 1         2nd  A++   ...    61196302  47548839843
# 2         3rd  A++   ...    19238251   9793305082
# 3         4th  A++   ...    31180559  22675948293
# 4         5th  A++   ...    32852346  26273668433
# ...       ...   ...  ...         ...          ...
# 4995  4,996th   B+   ...     2072942    441202795
# 4996  4,997th   B+   ...     1055091    377331722
# 4997  4,998th   B+   ...     3265735    311758426
# 4998  4,999th   B+   ...       32990     14563764
# 4999  5,000th   B+   ...       21172     73312511
#
# [5000 rows x 6 columns]

# %% [markdown]
# # ***1. Display All Rows Except the Last 5 rows Using Head Method***

# %%
lista1 = list()
for x in range(1,4995):
  lista1.append(x)

# %%
data.info
# Out:
# <bound method DataFrame.info of          Rank Grade  ... Subscribers  Video views
# 0         1st  A++   ...    18752951  20869786591
# 1         2nd  A++   ...    61196302  47548839843
# 2         3rd  A++   ...    19238251   9793305082
# 3         4th  A++   ...    31180559  22675948293
# 4         5th  A++   ...    32852346  26273668433
# ...       ...   ...  ...         ...          ...
# 4995  4,996th   B+   ...     2072942    441202795
# 4996  4,997th   B+   ...     1055091    377331722
# 4997  4,998th   B+   ...     3265735    311758426
# 4998  4,999th   B+   ...       32990     14563764
# 4999  5,000th   B+   ...       21172     73312511
#
# [5000 rows x 6 columns]>

# %%
data.iloc[lista1]
# Out:
#          Rank Grade  ... Subscribers  Video views
# 1         2nd  A++   ...    61196302  47548839843
# 2         3rd  A++   ...    19238251   9793305082
# 3         4th  A++   ...    31180559  22675948293
# 4         5th  A++   ...    32852346  26273668433
# 5         6th  A++   ...    17149705  16618094724
# ...       ...   ...  ...         ...          ...
# 4990  4,991st   B+   ...         --     127185704
# 4991  4,992nd   B+   ...      663114    141933264
# 4992  4,993rd   B+   ...      131766     74304638
# 4993  4,994th   B+   ...     1586835    371299166
# 4994  4,995th   B+   ...     1099659    346175699
#
# [4994 rows x 6 columns]

# %%
data.head(-5)
# Out:
#          Rank Grade  ... Subscribers  Video views
# 0         1st  A++   ...    18752951  20869786591
# 1         2nd  A++   ...    61196302  47548839843
# 2         3rd  A++   ...    19238251   9793305082
# 3         4th  A++   ...    31180559  22675948293
# 4         5th  A++   ...    32852346  26273668433
# ...       ...   ...  ...         ...          ...
# 4990  4,991st   B+   ...         --     127185704
# 4991  4,992nd   B+   ...      663114    141933264
# 4992  4,993rd   B+   ...      131766     74304638
# 4993  4,994th   B+   ...     1586835    371299166
# 4994  4,995th   B+   ...     1099659    346175699
#
# [4995 rows x 6 columns]

# %%
data.head(4995)
# Out:
#          Rank Grade  ... Subscribers  Video views
# 0         1st  A++   ...    18752951  20869786591
# 1         2nd  A++   ...    61196302  47548839843
# 2         3rd  A++   ...    19238251   9793305082
# 3         4th  A++   ...    31180559  22675948293
# 4         5th  A++   ...    32852346  26273668433
# ...       ...   ...  ...         ...          ...
# 4990  4,991st   B+   ...         --     127185704
# 4991  4,992nd   B+   ...      663114    141933264
# 4992  4,993rd   B+   ...      131766     74304638
# 4993  4,994th   B+   ...     1586835    371299166
# 4994  4,995th   B+   ...     1099659    346175699
#
# [4995 rows x 6 columns]

# %% [markdown]
# # ***2. Display All Rows Except the First 5 Rows Using Tail Method***

# %%
lista = list()
for x in range(5,5000):
  lista.append(x)

# %%
data.iloc[lista]
# Out:
#          Rank Grade  ... Subscribers  Video views
# 5         6th  A++   ...    17149705  16618094724
# 6         7th  A++   ...    11373567  23898730764
# 7         8th  A++   ...    12149206  17202609850
# 8         9th  A++   ...    16082927  24518098041
# 9        10th  A++   ...     2841811   2591830307
# ...       ...   ...  ...         ...          ...
# 4995  4,996th   B+   ...     2072942    441202795
# 4996  4,997th   B+   ...     1055091    377331722
# 4997  4,998th   B+   ...     3265735    311758426
# 4998  4,999th   B+   ...       32990     14563764
# 4999  5,000th   B+   ...       21172     73312511
#
# [4995 rows x 6 columns]

# %%
data.tail(-5)
# Out:
#          Rank Grade  ... Subscribers  Video views
# 5         6th  A++   ...    17149705  16618094724
# 6         7th  A++   ...    11373567  23898730764
# 7         8th  A++   ...    12149206  17202609850
# 8         9th  A++   ...    16082927  24518098041
# 9        10th  A++   ...     2841811   2591830307
# ...       ...   ...  ...         ...          ...
# 4995  4,996th   B+   ...     2072942    441202795
# 4996  4,997th   B+   ...     1055091    377331722
# 4997  4,998th   B+   ...     3265735    311758426
# 4998  4,999th   B+   ...       32990     14563764
# 4999  5,000th   B+   ...       21172     73312511
#
# [4995 rows x 6 columns]

# %% [markdown]
# # ***3. Find Shape of Our Dataset (Number of Rows And Number of Columns)***

# %%
data.shape
# Out:
# (5000, 6)

# %% [markdown]
# # ***4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement***

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %% [markdown]
# # ***5. Get Overall Statistics About The Dataframe***

# %%
data.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %%
data.describe(include="all")
# Out:
#          Rank Grade Channel name Video Uploads Subscribers   Video views
# count    5000  5000         5000          5000        5000  5.000000e+03
# unique   5000     6         4993          2286        4612           NaN
# top     887th   B+    Super Kids            20         --            NaN
# freq        1  2956            2            17         387           NaN
# mean      NaN   NaN          NaN           NaN         NaN  1.071449e+09
# std       NaN   NaN          NaN           NaN         NaN  2.003844e+09
# min       NaN   NaN          NaN           NaN         NaN  7.500000e+01
# 25%       NaN   NaN          NaN           NaN         NaN  1.862329e+08
# 50%       NaN   NaN          NaN           NaN         NaN  4.820548e+08
# 75%       NaN   NaN          NaN           NaN         NaN  1.124368e+09
# max       NaN   NaN          NaN           NaN         NaN  4.754884e+10

# %% [markdown]
# # ***6. Data Cleaning  (Replace '--'  to NaN)***

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.head(3)
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0  1st  A++                       Zee TV         82757    18752951  20869786591
# 1  2nd  A++                     T-Series         12661    61196302  47548839843
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082

# %%
data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
import numpy as np
data = data.replace('--',np.nan,regex=True)

# %%
data.head(20)
# Out:
#     Rank Grade  ... Subscribers  Video views
# 0    1st  A++   ...    18752951  20869786591
# 1    2nd  A++   ...    61196302  47548839843
# 2    3rd  A++   ...    19238251   9793305082
# 3    4th  A++   ...    31180559  22675948293
# 4    5th  A++   ...    32852346  26273668433
# 5    6th  A++   ...    17149705  16618094724
# 6    7th  A++   ...    11373567  23898730764
# 7    8th  A++   ...    12149206  17202609850
# 8    9th  A++   ...    16082927  24518098041
# 9   10th  A++   ...     2841811   2591830307
# 10  11th   A+   ...    33492951   8587520379
# 11  12th   A+   ...    39409726  19291034467
# 12  13th   A+   ...     7662886   2540099931
# 13  14th   A+   ...    18824912   8727783225
# 14  15th   A+   ...    15899764  10989179147
# 15  16th   A+   ...    11569723   9388600275
# 16  17th   A+   ...    15830098  11102158475
# 17  18th   A+   ...         NaN   1428274554
# 18  19th   A+   ...    23603062   5860444053
# 19  20th   A+   ...    17687229  14022189654
#
# ...

# %% [markdown]
# # ***7. Check Null Values In The Dataset***

# %%
data.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(data.isnull())

# %%
per_missing = data.isnull().sum() * 100/ len(data)

# %%
per_missing
# Out:
# Rank             0.00
# Grade            0.00
# Channel name     0.00
# Video Uploads    0.12
# Subscribers      7.74
# Video views      0.00
# dtype: float64

# %%
sns.heatmap(data.isnull())

# %%
data.dropna(axis=0,inplace=True)

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# # ***8. Data Cleaning [ Rank Column ]***

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0  1st  A++                       Zee TV         82757    18752951  20869786591
# 1  2nd  A++                     T-Series         12661    61196302  47548839843
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3  4th  A++                    SET India         27323    31180559  22675948293
# 4  5th  A++                          WWE         36756    32852346  26273668433

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data['Rank'] = data['Rank'].str[0:-2] #Anula los valores string

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0    1  A++                       Zee TV         82757    18752951  20869786591
# 1    2  A++                     T-Series         12661    61196302  47548839843
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3    4  A++                    SET India         27323    31180559  22675948293
# 4    5  A++                          WWE         36756    32852346  26273668433

# %%
data['Rank'] = data['Rank'].str.replace(',','') # Reemplazamos el valor str con un espacio vacio con la función replace

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  Video views
# 0    1  A++                       Zee TV         82757    18752951  20869786591
# 1    2  A++                     T-Series         12661    61196302  47548839843
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251   9793305082
# 3    4  A++                    SET India         27323    31180559  22675948293
# 4    5  A++                          WWE         36756    32852346  26273668433

# %%
data['Rank'] = data['Rank'].astype('int') # Transformarlo en entero con int

# %%
data.head()
# Out:
#    Rank Grade  ... Subscribers  Video views
# 0     1  A++   ...    18752951  20869786591
# 1     2  A++   ...    61196302  47548839843
# 2     3  A++   ...    19238251   9793305082
# 3     4  A++   ...    31180559  22675948293
# 4     5  A++   ...    32852346  26273668433
#
# [5 rows x 6 columns]

# %%
data.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %% [markdown]
# # ***9. Data Cleaning [ Video Uploads & Subscribers ]***

# %%
data['Video Uploads'] = data['Video Uploads'].astype('int')

# %%
data['Subscribers'] = data['Subscribers'].astype('int')

# %%
data.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads     int64
# Subscribers       int64
# Video views       int64
# dtype: object

# %% [markdown]
# # ***10. Data Cleaning [ Grade Column ]***

# %%
data.head()
# Out:
#    Rank Grade  ... Subscribers  Video views
# 0     1  A++   ...    18752951  20869786591
# 1     2  A++   ...    61196302  47548839843
# 2     3  A++   ...    19238251   9793305082
# 3     4  A++   ...    31180559  22675948293
# 4     5  A++   ...    32852346  26273668433
#
# [5 rows x 6 columns]

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade'] = data['Grade'].map({'A++ ':5, 'A+ ':4, 'A ':3, 'A- ':2, 'B+ ':1})#Método map para convertir en variable numerica una variable

# %%
data['Grade']
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 4995    1
# 4996    1
# 4997    1
# 4998    1
# 4999    1
# Name: Grade, Length: 4610, dtype: int64

# %%
data.dtypes
# Out:
# Rank              int64
# Grade             int64
# Channel name     object
# Video Uploads     int64
# Subscribers       int64
# Video views       int64
# dtype: object

# %% [markdown]
# # ***11. Find Average Views For Each Channel***

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.head(5)
# Out:
#    Rank  Grade  ... Subscribers  Video views
# 0     1      5  ...    18752951  20869786591
# 1     2      5  ...    61196302  47548839843
# 2     3      5  ...    19238251   9793305082
# 3     4      5  ...    31180559  22675948293
# 4     5      5  ...    32852346  26273668433
#
# [5 rows x 6 columns]

# %%
data['Video views'].dtypes
# Out:
# dtype('int64')

# %%
data.groupby('Channel name')["Video views"].mean()
# Out:
# Channel name
# #Desenhos Kids BR               8.404115e+07
# #FIRST WINGS FILM PRODUCTION    1.267895e+07
# #Mentale Zuflucht               3.634114e+08
# #Mind Warehouse                 1.337877e+09
# #Refugio Mental                 1.262197e+09
#                                     ...
# 핑크퐁 (인기 동요・동화)                  1.595353e+09
# 허팝Heopop                        1.690027e+09
# 헤이지니 Hey Jini                   4.550237e+08
# 헬로카봇 - hello carbot…            3.291915e+08
# 흔한남매                            1.196532e+08
# Name: Video views, Length: 4604, dtype: float64

# %%
data['Avg_views'] = (data['Video views']/data["Video Uploads"])

# %%
data.head( )
# Out:
#    Rank  Grade  ...  Video views     Avg_views
# 0     1      5  ...  20869786591  2.521815e+05
# 1     2      5  ...  47548839843  3.755536e+06
# 2     3      5  ...   9793305082  2.625551e+07
# 3     4      5  ...  22675948293  8.299216e+05
# 4     5      5  ...  26273668433  7.148130e+05
#
# [5 rows x 7 columns]

# %%
data['Avg_views']
# Out:
# 0       2.521815e+05
# 1       3.755536e+06
# 2       2.625551e+07
# 3       8.299216e+05
# 4       7.148130e+05
#             ...
# 4995    6.249331e+05
# 4996    4.734401e+05
# 4997    2.834168e+06
# 4998    4.191011e+03
# 4999    2.886319e+05
# Name: Avg_views, Length: 4610, dtype: float64

# %% [markdown]
# # ***12. Find Out Top Five Channels With Maximum Number of Video Uploads***

# %%
data.head()
# Out:
#    Rank  Grade  ...  Video views     Avg_views
# 0     1      5  ...  20869786591  2.521815e+05
# 1     2      5  ...  47548839843  3.755536e+06
# 2     3      5  ...   9793305082  2.625551e+07
# 3     4      5  ...  22675948293  8.299216e+05
# 4     5      5  ...  26273668433  7.148130e+05
#
# [5 rows x 7 columns]

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data['Video Uploads'].sort_values(ascending=False).head(7)
# Out:
# Int64Index([3453, 1149, 2223, 323, 2956, 4112, 4583], dtype='int64')

# %%
z = data['Video Uploads'].sort_values(ascending=False).head().index

# %%
data.iloc[z]['Channel name'] #Respuesta iuncorredya
# Out:
# 3734    Lalitha Audios And Videos
# 1241                    JFlaMusic
# 2416                  Astro Arena
# 349               Goldmines Hindi
# 3206                       GugaTV
# Name: Channel name, dtype: object

# %%
data.sort_values(by='Video Uploads',ascending=False).head() # Verdadera Respuesta correcta
# Out:
#       Rank  Grade Channel name  ...  Subscribers  Video views     Avg_views
# 3453  3454      1   AP Archive  ...       746325    548619569   1299.042846
# 1149  1150      2     YTN NEWS  ...       820108   1640347646   4607.769879
# 2223  2224      1    SBS Drama  ...      1418619   1565758044   4666.646928
# 323    324      3     GMA News  ...      2599175   2786949164  10357.902975
# 2956  2957      1          MLB  ...      1434206   1329206392   4966.229622
#
# [5 rows x 7 columns]

# %% [markdown]
# # ***13. Find Correlation Matrix***

# %%
data.corr()
# Out:
#                    Rank     Grade  ...  Video views  Avg_views
# Rank           1.000000 -0.865083  ...    -0.402873  -0.153670
# Grade         -0.865083  1.000000  ...     0.477423   0.155231
# Video Uploads -0.073180  0.088773  ...     0.087830  -0.064408
# Subscribers   -0.383329  0.429213  ...     0.791241   0.289386
# Video views   -0.402873  0.477423  ...     1.000000   0.294422
# Avg_views     -0.153670  0.155231  ...     0.294422   1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# # **`*14.  Which Grade Has A Maximum Number of Video Uploads?*`**

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views', 'Avg_views'],
#       dtype='object')

# %%
sns.barplot(x='Grade',y='Video Uploads',data=data)

# %%
data.head(2)
# Out:
#    Rank  Grade Channel name  ...  Subscribers  Video views     Avg_views
# 0     1      5       Zee TV  ...     18752951  20869786591  2.521815e+05
# 1     2      5     T-Series  ...     61196302  47548839843  3.755536e+06
#
# [2 rows x 7 columns]

# %%
data.groupby('Grade')['Video Uploads'].describe()
# Out:
#       count unique    top freq
# Grade
# A       963    788      8    6
# A+       41     41   5704    1
# A++      10     10  74607    1
# A-     1024    764    235    6
# B+     2956   1545     84   12
#           6      1     --    6

# %%
data.groupby('Grade')['Video Uploads'].count()
# Out:
# Grade
# A        963
# A+        41
# A++       10
# A-      1024
# B+      2956
#            6
# Name: Video Uploads, dtype: int64

# %% [markdown]
# # ***15.Which Grade Has The Highest Average Views?***

# %%
data.groupby('Grade')['Video views'].mean()
# Out:
# Grade
# A       2.361317e+09
# A+      6.053121e+09
# A++     2.119909e+10
# A-      1.041149e+09
# B+      5.265217e+08
#         9.912005e+07
# Name: Video views, dtype: float64

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views', 'Avg_views'],
#       dtype='object')

# %%
sns.barplot(x='Grade',y='Avg_views',data=data)

# %% [markdown]
# # ***16.  Which Grade Has The Highest Number of Subscribers? ***

# %%
data.groupby('Grade')['Subscribers'].count()
# Out:
# Grade
# A        963
# A+        41
# A++       10
# A-      1024
# B+      2956
#            6
# Name: Subscribers, dtype: int64

# %%
sns.barplot(x='Grade',y='Subscribers',data=data)

# %% [markdown]
# # ***17. Which Grade Has The Highest Video Views? ***

# %%
data.groupby('Grade')['Video views'].count()
# Out:
# Grade
# A        963
# A+        41
# A++       10
# A-      1024
# B+      2956
#            6
# Name: Video views, dtype: int64

# %%
sns.barplot(x='Grade',y='Video views',data=data)
