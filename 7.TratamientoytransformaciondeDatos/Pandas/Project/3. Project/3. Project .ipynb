# %% [markdown]
# Una forma de entender cómo funciona el gobierno de una ciudad es ver a quién emplea y cómo se compensa a sus empleados. Estos datos contienen los nombres, el cargo y la remuneración de los empleados de la ciudad de San Francisco anualmente de 2011 a 2014.

# %% [markdown]
# # ***Ideas de exploración***

# %% [markdown]
# Para ayudarlo a comenzar, aquí hay algunas ideas de exploración de datos:
#
# *   ¿Cómo han cambiado los salarios a lo largo del tiempo entre diferentes grupos de personas?
# *   ¿Cómo se asignan el salario base, el pago de horas extra y los beneficios entre los diferentes grupos?
# *   ¿Existe alguna evidencia de discriminación salarial basada en el género en este conjunto de datos?
# *   ¿Cómo se asigna el presupuesto en función de los diferentes grupos y responsabilidades?
#
# ¿Tienes otras ideas que tienes curiosidad de que alguien más las explore? Publícalos en este hilo del foro.

# %% [markdown]
# # ***Data Description***

# %% [markdown]
# sf-salaries-release - *. zip (descargable a través del enlace "Descargar datos" en el encabezado de arriba) contiene una tabla CSV y una base de datos SQLite (con los mismos datos que el archivo CSV). Aquí está el código que crea esta publicación de datos.
#
# La fuente original de estos datos está aquí. Hemos tomado los archivos sin procesar aquí y los hemos combinado / normalizado en un solo archivo CSV, así como en una base de datos SQLite con una tabla definida de manera equivalente.

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Tratamiento y transformación de Datos/Pandas/Project/3. Project/Salaries.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#             Id       EmployeeName  ...         Agency Status
# 0            1     NATHANIEL FORD  ...  San Francisco    NaN
# 1            2       GARY JIMENEZ  ...  San Francisco    NaN
# 2            3     ALBERT PARDINI  ...  San Francisco    NaN
# 3            4  CHRISTOPHER CHONG  ...  San Francisco    NaN
# 4            5    PATRICK GARDNER  ...  San Francisco    NaN
# ...        ...                ...  ...            ...    ...
# 148649  148650      Roy I Tillery  ...  San Francisco     PT
# 148650  148651       Not provided  ...  San Francisco    NaN
# 148651  148652       Not provided  ...  San Francisco    NaN
# 148652  148653       Not provided  ...  San Francisco    NaN
# 148653  148654          Joe Lopez  ...  San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# # ***1.  Display Top 10 Rows of The Dataset***

# %%
data.head(10)
# Out:
#    Id        EmployeeName  ...         Agency Status
# 0   1      NATHANIEL FORD  ...  San Francisco    NaN
# 1   2        GARY JIMENEZ  ...  San Francisco    NaN
# 2   3      ALBERT PARDINI  ...  San Francisco    NaN
# 3   4   CHRISTOPHER CHONG  ...  San Francisco    NaN
# 4   5     PATRICK GARDNER  ...  San Francisco    NaN
# 5   6      DAVID SULLIVAN  ...  San Francisco    NaN
# 6   7           ALSON LEE  ...  San Francisco    NaN
# 7   8       DAVID KUSHNER  ...  San Francisco    NaN
# 8   9      MICHAEL MORRIS  ...  San Francisco    NaN
# 9  10  JOANNE HAYES-WHITE  ...  San Francisco    NaN
#
# [10 rows x 13 columns]

# %%
data.tail(10)
# Out:
#             Id      EmployeeName  ...         Agency Status
# 148644  148645      Randy D Winn  ...  San Francisco     PT
# 148645  148646  Carolyn A Wilson  ...  San Francisco     PT
# 148646  148647      Not provided  ...  San Francisco    NaN
# 148647  148648    Joann Anderson  ...  San Francisco     PT
# 148648  148649       Leon Walker  ...  San Francisco     PT
# 148649  148650     Roy I Tillery  ...  San Francisco     PT
# 148650  148651      Not provided  ...  San Francisco    NaN
# 148651  148652      Not provided  ...  San Francisco    NaN
# 148652  148653      Not provided  ...  San Francisco    NaN
# 148653  148654         Joe Lopez  ...  San Francisco     PT
#
# [10 rows x 13 columns]

# %% [markdown]
# # ***3. Find Shape of Our Dataset (Number of Rows And Number of Columns)***

# %%
data.shape
# Out:
# (148654, 13)

# %%
print("Nomber of rows",data.shape[0])
print("Nomber of columns",data.shape[1])
# Out:
# Nomber of rows 148654
# Nomber of columns 13

# %% [markdown]
# # ***4.  Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, ***

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# # ***5. Check Null Values In The Dataset***

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of             Id       EmployeeName  ...         Agency Status
# 0            1     NATHANIEL FORD  ...  San Francisco    NaN
# 1            2       GARY JIMENEZ  ...  San Francisco    NaN
# 2            3     ALBERT PARDINI  ...  San Francisco    NaN
# 3            4  CHRISTOPHER CHONG  ...  San Francisco    NaN
# 4            5    PATRICK GARDNER  ...  San Francisco    NaN
# ...        ...                ...  ...            ...    ...
# 148649  148650      Roy I Tillery  ...  San Francisco     PT
# 148650  148651       Not provided  ...  San Francisco    NaN
# 148651  148652       Not provided  ...  San Francisco    NaN
# 148652  148653       Not provided  ...  San Francisco    NaN
# 148653  148654          Joe Lopez  ...  San Francisco     PT
#
# [148654 rows x 13 columns]>

# %%
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# # ***6. Drop ID, Notes, Agency, and Status Columns***

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data = data.drop(['Id','Notes','Agency','Status'], axis=1)

# %%
data
# Out:
#              EmployeeName  ...  Year
# 0          NATHANIEL FORD  ...  2011
# 1            GARY JIMENEZ  ...  2011
# 2          ALBERT PARDINI  ...  2011
# 3       CHRISTOPHER CHONG  ...  2011
# 4         PATRICK GARDNER  ...  2011
# ...                   ...  ...   ...
# 148649      Roy I Tillery  ...  2014
# 148650       Not provided  ...  2014
# 148651       Not provided  ...  2014
# 148652       Not provided  ...  2014
# 148653          Joe Lopez  ...  2014
#
# [148654 rows x 9 columns]

# %% [markdown]
# # ***7. Get Overall Statistics About The Dataframe***

# %%
data.describe
# Out:
# <bound method NDFrame.describe of              EmployeeName  ...  Year
# 0          NATHANIEL FORD  ...  2011
# 1            GARY JIMENEZ  ...  2011
# 2          ALBERT PARDINI  ...  2011
# 3       CHRISTOPHER CHONG  ...  2011
# 4         PATRICK GARDNER  ...  2011
# ...                   ...  ...   ...
# 148649      Roy I Tillery  ...  2014
# 148650       Not provided  ...  2014
# 148651       Not provided  ...  2014
# 148652       Not provided  ...  2014
# 148653          Joe Lopez  ...  2014
#
# [148654 rows x 9 columns]>

# %%
data.describe(include='all')
# Out:
#        EmployeeName          JobTitle  ...  TotalPayBenefits           Year
# count        148654            148654  ...     148654.000000  148654.000000
# unique       110811              2159  ...               NaN            NaN
# top       Kevin Lee  Transit Operator  ...               NaN            NaN
# freq             13              7036  ...               NaN            NaN
# mean            NaN               NaN  ...      93692.554811    2012.522643
# std             NaN               NaN  ...      62793.533483       1.117538
# min             NaN               NaN  ...       -618.130000    2011.000000
# 25%             NaN               NaN  ...      44065.650000    2012.000000
# 50%             NaN               NaN  ...      92404.090000    2013.000000
# 75%             NaN               NaN  ...     132876.450000    2014.000000
# max             NaN               NaN  ...     567595.430000    2014.000000
#
# [11 rows x 9 columns]

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %% [markdown]
# # ***8. Find Occurrence of The Employee Names  (Top 5)***

# %%
data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
data['EmployeeName'].value_counts()
# Out:
# Kevin Lee            13
# William Wong         11
# Richard Lee          11
# Steven Lee           11
# Michael Wong          9
#                      ..
# Hugh Meade            1
# BRENDA JONES          1
# HELGA ZIMMERER        1
# Andrew De La Rosa     1
# PAUL OSPITAL          1
# Name: EmployeeName, Length: 110811, dtype: int64

# %% [markdown]
# # ***9. Find The Number of Unique Job Titles***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# # ***10.Total Number of Job Titles Contain Captain***

# %%
data['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
data['JobTitle'].str.contains('CAPTAIN')
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
data[data['JobTitle'].str.contains('CAPTAIN')]
# Out:
#            EmployeeName  ...  Year
# 1          GARY JIMENEZ  ...  2011
# 2        ALBERT PARDINI  ...  2011
# 11     PATRICIA JACKSON  ...  2011
# 17       SEBASTIAN WONG  ...  2011
# 22        GEORGE GARCIA  ...  2011
# ...                 ...  ...   ...
# 8684      JEANNE SEYLER  ...  2011
# 10485        JANE SMITH  ...  2011
# 11198     KATHRYN BROWN  ...  2011
# 31297   MARCO CARNIGLIA  ...  2011
# 34124     JOHN FORBES-3  ...  2011
#
# [141 rows x 9 columns]

# %%
len(data[data['JobTitle'].str.contains('CAPTAIN',case=False)])
# Out:
# 552

# %%
data[data['JobTitle'].str.contains('CAPTAIN')].count()
# Out:
# EmployeeName        141
# JobTitle            141
# BasePay             141
# OvertimePay         141
# OtherPay            141
# Benefits              0
# TotalPay            141
# TotalPayBenefits    141
# Year                141
# dtype: int64

# %% [markdown]
# # ***11. Display All the Employee Names From Fire Department***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
data['JobTitle'].value_counts()
# Out:
# Transit Operator                                      7036
# Special Nurse                                         4389
# Registered Nurse                                      3736
# Public Svc Aide-Public Works                          2518
# Police Officer 3                                      2421
#                                                       ...
# CHIEF NURSERY SPECIALIST                                 1
# Cashier 3                                                1
# PRINCIPAL INVESTIGATOR, TAX COLLECTOR                    1
# CAPTAIN, BUREAU OF FIRE PREVENTION AND PUBLIC SAFE       1
# Chief Investment Officer                                 1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
data['JobTitle'].str.contains('fire',case=False)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
data[data['JobTitle'].str.contains('fire',case=False)]
# Out:
#               EmployeeName  ...  Year
# 4          PATRICK GARDNER  ...  2011
# 6                ALSON LEE  ...  2011
# 8           MICHAEL MORRIS  ...  2011
# 9       JOANNE HAYES-WHITE  ...  2011
# 10           ARTHUR KENNEY  ...  2011
# ...                    ...  ...   ...
# 145956    Kenneth C Farris  ...  2014
# 147556       Edward A Dunn  ...  2014
# 148021      Kari A Johnson  ...  2014
# 148209        Sheryl K Lee  ...  2014
# 148554     Lawrence F Gatt  ...  2014
#
# [5879 rows x 9 columns]

# %%
data[data['JobTitle'].str.contains('fire',case=False)] ['EmployeeName']
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %% [markdown]
# # ***12. Find Minimum, Maximum, and Average BasePay***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['BasePay']
# Out:
# 0               167411
# 1               155966
# 2               212739
# 3                77916
# 4               134402
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
data['BasePay'].describe()
# Out:
# count     148049.0
# unique    109900.0
# top            0.0
# freq         875.0
# Name: BasePay, dtype: float64

# %% [markdown]
# # ***13. Replace 'Not Provided' in EmployeeName' Column to NaN ***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
import numpy as np
data['EmployeeName'] = data['EmployeeName'].replace('Not provided',np.nan)

# %%
data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %% [markdown]
# 14. Elimine las filas que tienen 5 valores perdidos

# %%
data.isnull()
# Out:
#         EmployeeName  JobTitle  BasePay  ...  TotalPay  TotalPayBenefits   Year
# 0              False     False    False  ...     False             False  False
# 1              False     False    False  ...     False             False  False
# 2              False     False    False  ...     False             False  False
# 3              False     False    False  ...     False             False  False
# 4              False     False    False  ...     False             False  False
# ...              ...       ...      ...  ...       ...               ...    ...
# 148649         False     False    False  ...     False             False  False
# 148650          True     False    False  ...     False             False  False
# 148651          True     False    False  ...     False             False  False
# 148652          True     False    False  ...     False             False  False
# 148653         False     False    False  ...     False             False  False
#
# ...

# %%
data.isnull().sum(axis=1) == 5
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Length: 148654, dtype: bool

# %%
data[data.isnull().sum(axis=1) == 5]
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
data.drop(data[data.isnull().sum(axis=1) == 5].index,axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# EmployeeName            4
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
data.isnull().sum(axis=1)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 148649    0
# 148650    1
# 148651    1
# 148652    1
# 148653    0
# Length: 148654, dtype: int64

# %% [markdown]
# # ***15. Find Job Title of ALBERT PARDINI***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
data['EmployeeName'] == 'ALBERT PARDINI'
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: EmployeeName, Length: 148654, dtype: bool

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']
# Out:
#      EmployeeName                         JobTitle  ... TotalPayBenefits  Year
# 2  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  ...        335279.91  2011
#
# [1 rows x 9 columns]

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %% [markdown]
# # ***16. How Much ALBERT PARDINI Make (Include Benefits)?***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']
# Out:
#      EmployeeName                         JobTitle  ... TotalPayBenefits  Year
# 2  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  ...        335279.91  2011
#
# [1 rows x 9 columns]

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']['TotalPay']
# Out:
# 2    335279.91
# Name: TotalPay, dtype: float64

# %% [markdown]
# 17. Nombre para mostrar de la persona que tiene el pago base más alto

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['BasePay']
# Out:
# 0               167411
# 1               155966
# 2               212739
# 3                77916
# 4               134402
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
data.isnull().sum()
# Out:
# EmployeeName            4
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
for x in data['BasePay'].value_counts():
  print(type(x))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
z = data['BasePay'].value_counts()

# %%
z
# Out:
# 0.0          875
# 0.00         423
# 54703.00     327
# 55026.0      297
# 48472.4      210
#             ...
# 118352.14      1
# 42596.9        1
# 118354.4       1
# 18218.56       1
# 88177.83       1
# Name: BasePay, Length: 109900, dtype: int64

# %%
data['BasePay']
# Out:
# 0               167411
# 1               155966
# 2               212739
# 3                77916
# 4               134402
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
data['BasePay'][148650] == 0
# Out:
# False

# %%
data['BasePay'][148650].replace('Not provided',int(0)) # No se puede reemplazar data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-ad89211198cb> in <module>()
# ----> 1 data['BasePay'][148650].replace('Not provided',int(0))
#
# TypeError: replace() argument 2 must be str, not int

# %% [markdown]
# Nop se pudo cambiar los valores, pero si eliminar datos

# %%
data['BasePay'] = data['BasePay'].drop([148650,148651,148652,148646],axis=0)

# %% [markdown]
# Realizando calculo

# %%
data['BasePay'] = data['BasePay'].astype(float)

# %%
data['BasePay'].max()
# Out:
# 319275.01

# %%
data[data['BasePay'].max() == data['BasePay']]
# Out:
#          EmployeeName         JobTitle  ...  TotalPayBenefits  Year
# 72925  Gregory P Suhr  Chief of Police  ...         425815.28  2013
#
# [1 rows x 9 columns]

# %%
data[data['BasePay'].max() == data['BasePay']]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# # ***18.Encuentre el pago base promedio de todos los empleados por año***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
data['Year']
# Out:
# 0         2011
# 1         2011
# 2         2011
# 3         2011
# 4         2011
#           ...
# 148649    2014
# 148650    2014
# 148651    2014
# 148652    2014
# 148653    2014
# Name: Year, Length: 148654, dtype: int64

# %%
data.groupby('Year').mean()
# Out:
#            BasePay      TotalPay  TotalPayBenefits
# Year
# 2011  63595.956517  71744.103871      71744.103871
# 2012  65436.406857  74113.262265     100553.229232
# 2013  69630.030216  77611.443142     101440.519714
# 2014  66564.421924  75463.918140     100250.918884

# %%
data.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# # ***19. Encuentre el salario base promedio de todos los empleados por título de trabajo***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data.groupby('JobTitle').mean()
# Out:
#                                                      BasePay  ...     Year
# JobTitle                                                      ...
# ACCOUNT CLERK                                   43300.806506  ...  2011.00
# ACCOUNTANT                                      46643.172000  ...  2011.00
# ACCOUNTANT INTERN                               28732.663958  ...  2011.00
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000  ...  2014.00
# ACUPUNCTURIST                                   66374.400000  ...  2011.00
# ...                                                      ...  ...      ...
# X-RAY LABORATORY AIDE                           47664.773077  ...  2011.00
# X-Ray Laboratory Aide                           46086.387100  ...  2013.04
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910000  ...  2011.00
# Youth Comm Advisor                              39077.957500  ...  2013.00
# ZOO CURATOR                                     43148.000000  ...  2011.00
#
# ...

# %%
data.groupby('JobTitle').mean()['BasePay']
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %% [markdown]
# # ***20. Encuentre el salario base promedio de un empleado que tiene un puesto de trabajo CONTABLE***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
data['JobTitle'] == 'ACCOUNTANT'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
data[data['JobTitle'] == 'ACCOUNTANT']
# Out:
#            EmployeeName    JobTitle   BasePay  ...  TotalPay TotalPayBenefits  Year
# 19263  CARLITO NEPACENA  ACCOUNTANT  65392.01  ...  65392.01         65392.01  2011
# 19324     ROSALINDA TAN  ACCOUNTANT  65225.31  ...  65225.31         65225.31  2011
# 20992   NELSON ALVARADO  ACCOUNTANT  60076.24  ...  60076.24         60076.24  2011
# 25927   JEANETTE COOPER  ACCOUNTANT  42522.30  ...  45304.38         45304.38  2011
# 35285     CESAR PALARCA  ACCOUNTANT      0.00  ...   1148.40          1148.40  2011
#
# [5 rows x 9 columns]

# %%
data[data['JobTitle'] == 'ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# # ***21. Encuentre los 5 trabajos más comunes***

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
data['JobTitle'].value_counts()
# Out:
# Transit Operator                                      7036
# Special Nurse                                         4389
# Registered Nurse                                      3736
# Public Svc Aide-Public Works                          2518
# Police Officer 3                                      2421
#                                                       ...
# CHIEF NURSERY SPECIALIST                                 1
# Cashier 3                                                1
# PRINCIPAL INVESTIGATOR, TAX COLLECTOR                    1
# CAPTAIN, BUREAU OF FIRE PREVENTION AND PUBLIC SAFE       1
# Chief Investment Officer                                 1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
data['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
