# %% [markdown]
# Resumen
# Los datos se han dividido en dos grupos
#
# conjunto de entrenamiento (train.csv)
# conjunto de prueba (test.csv)
# El conjunto de entrenamiento debe utilizarse para construir sus modelos de aprendizaje automático. Para el conjunto de entrenamiento, proporcionamos el resultado (también conocido como la "verdad básica") para cada pasajero. Su modelo se basará en "características" como el género y la clase de los pasajeros. También puede utilizar la ingeniería de características para crear otras nuevas.
#
# El conjunto de pruebas debe utilizarse para comprobar el rendimiento de su modelo con datos no vistos. Para el conjunto de pruebas, no proporcionamos la verdad sobre el terreno para cada pasajero. Es su trabajo predecir estos resultados. Para cada pasajero del conjunto de prueba, utiliza el modelo que has entrenado para predecir si sobrevivieron o no al hundimiento del Titanic.
#
# También incluimos gender_submission.csv, un conjunto de predicciones que suponen que todos y sólo los pasajeros femeninos sobreviven, como ejemplo de cómo tiene que ser

# %%
import pandas as pd
data =  pd.read_csv("/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Tratamiento y transformación de Datos/Pandas/Project/Project - 4 (Case Study - 4)/Titanic.csv")

# %%
data
# Out:
#                                                Name PClass  ...     Sex Survived
# 0                      Allen, Miss Elisabeth Walton    1st  ...  female        1
# 1                       Allison, Miss Helen Loraine    1st  ...  female        0
# 2               Allison, Mr Hudson Joshua Creighton    1st  ...    male        0
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  ...  female        0
# 4                     Allison, Master Hudson Trevor    1st  ...    male        1
# ...                                             ...    ...  ...     ...      ...
# 1308                             Zakarian, Mr Artun    3rd  ...    male        0
# 1309                         Zakarian, Mr Maprieder    3rd  ...    male        0
# 1310                               Zenni, Mr Philip    3rd  ...    male        0
# 1311                               Lievens, Mr Rene    3rd  ...    male        0
# 1312                                 Zimmerman, Leo    3rd  ...    male        0
#
# ...

# %%
data1 =  pd.read_csv("/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Tratamiento y transformación de Datos/Pandas/Project/Project - 4 (Case Study - 4)/train.csv")

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# # ***2. Check the Last 3 Rows of The Dataset***

# %%
data1.tail(3)
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [3 rows x 12 columns]

# %% [markdown]
# # ***3. Find Shape of Our Dataset (Number of Rows & Number of Columns)***

# %%
data1.shape
# Out:
# (891, 12)

# %% [markdown]
# # ***4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement ***

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1313 non-null   object
#  1   PClass    1312 non-null   object
#  2   Age       756 non-null    float64
#  3   Sex       1313 non-null   object
#  4   Survived  1313 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 51.4+ KB

# %% [markdown]
# # ***5. Get Overall Statistics About The Dataframe***

# %%
data1.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
data1.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  ...        Fare        Cabin  Embarked
# count    891.000000  891.000000  891.000000  ...  891.000000          204       889
# unique          NaN         NaN         NaN  ...         NaN          147         3
# top             NaN         NaN         NaN  ...         NaN  C23 C25 C27         S
# freq            NaN         NaN         NaN  ...         NaN            4       644
# mean     446.000000    0.383838    2.308642  ...   32.204208          NaN       NaN
# std      257.353842    0.486592    0.836071  ...   49.693429          NaN       NaN
# min        1.000000    0.000000    1.000000  ...    0.000000          NaN       NaN
# 25%      223.500000    0.000000    2.000000  ...    7.910400          NaN       NaN
# 50%      446.000000    0.000000    3.000000  ...   14.454200          NaN       NaN
# 75%      668.500000    1.000000    3.000000  ...   31.000000          NaN       NaN
# ...

# %% [markdown]
# # ***6. Data Filtering***

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data1[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
data1['Sex'] == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
sum(data1['Sex'] == 'male')
# Out:
# 577

# %%
len(data1['Sex'] == 'male')
# Out:
# 891

# %%
data1[data1['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 4              5         0       3  ...   8.0500   NaN         S
# 5              6         0       3  ...   8.4583   NaN         Q
# 6              7         0       1  ...  51.8625   E46         S
# 7              8         0       3  ...  21.0750   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 883          884         0       2  ...  10.5000   NaN         S
# 884          885         0       3  ...   7.0500   NaN         S
# 886          887         0       2  ...  13.0000   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [577 rows x 12 columns]

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Sobreviuvio

# %%
  data1['Survived'] == 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
sum(data1['Survived'] == 1)
# Out:
# 342

# %% [markdown]
# # ***7.Check Null Values In The Dataset***

# %%
data1.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())

# %%
per_missing = data1.isnull().sum() * 100 / len(data)
per_missing
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            13.480579
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          52.322925
# Embarked        0.152323
# dtype: float64

# %% [markdown]
# # ***8. Drop the Column***

# %%
data1.drop('Cabin',axis=1,inplace=True)

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %% [markdown]
# # ***9. Handle Missing Values***

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
data1['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
data1['Embarked'].mode()
# Out:
# 0    S
# dtype: object

# %%
data1['Embarked'].fillna('S',inplace=True)

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
round(data1['Age'].mean(),2)
# Out:
# 29.7

# %%
data1['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data1['Age'].fillna(round(data1['Age'].mean(),2),inplace=True)

# %%
data1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
per_missing = data1.isnull().sum() * 100 / len(data)
per_missing
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# # ***10. Categorical Data Encoding***

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
data1['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data1['Gender'] = data1['Sex'].map({'male':1,'female':0})

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
x = data1['Gender'] = data1['Sex'].map({'male':1,'female':0})

# %%
data1.insert(5,'Gender_new',x)

# %%
data1.head(1)
# Out:
#    PassengerId  Survived  Pclass  ...  Fare Embarked  Gender
# 0            1         0       3  ...  7.25        S       1
#
# [1 rows x 13 columns]

# %%
data1['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
data1['Embarked'].nunique()
# Out:
# 3

# %%
data1['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
pd.get_dummies(data1,columns=['Embarked'])
# Out:
#      PassengerId  Survived  Pclass  ... Embarked_C Embarked_Q  Embarked_S
# 0              1         0       3  ...          0          0           1
# 1              2         1       1  ...          1          0           0
# 2              3         1       3  ...          0          0           1
# 3              4         1       1  ...          0          0           1
# 4              5         0       3  ...          0          0           1
# ..           ...       ...     ...  ...        ...        ...         ...
# 886          887         0       2  ...          0          0           1
# 887          888         1       1  ...          0          0           1
# 888          889         0       3  ...          0          0           1
# 889          890         1       1  ...          1          0           0
# 890          891         0       3  ...          0          1           0
#
# [891 rows x 15 columns]

# %%
data1 = pd.get_dummies(data1,columns=['Embarked'],drop_first=True)

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  ... Gender Embarked_Q  Embarked_S
# 0            1         0       3  ...      1          0           1
# 1            2         1       1  ...      0          0           0
# 2            3         1       3  ...      0          0           1
# 3            4         1       1  ...      0          0           1
# 4            5         0       3  ...      1          0           1
#
# [5 rows x 14 columns]

# %% [markdown]
# # ***¿Qué es el análisis univariado?***

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_new', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Gender', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %% [markdown]
# # ***¿Cuántas personas sobrevivieron y cuántas murieron?***

# %%
data1['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data1['Survived'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # ¿Cuántos pasajeros había en primera, segunda y tercera clase? Número de pasajeros masculinos y femeninos

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_new', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Gender', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
data1['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(data1['Pclass'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data1['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(data1['Sex'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.hist(data1['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(data1['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data1['Age'],orient='Vertical')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # ***12. Análisis bivariado ***
# ¿Cómo tiene mayor probabilidad de supervivencia hombre o mujer?

# %% [markdown]
# ¿Qué clase de pasajeros tiene más posibilidades de sobrevivir (primera, segunda o tercera clase)?

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_new', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Gender', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
sns.barplot(x='Sex', y='Survived',data=data1)

# %%
sns.barplot(x='Pclass', y = "Survived",data=data1)

# %% [markdown]
# # ***13. Ingeniería de funciones***

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_new', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Gender', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
data1['Family_Size'] = data1['SibSp'] + data1['Parch']

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked_Q Embarked_S  Family_Size
# 0            1         0       3  ...          0          1            1
# 1            2         1       1  ...          0          0            1
# 2            3         1       3  ...          0          1            0
# 3            4         1       1  ...          0          1            1
# 4            5         0       3  ...          0          1            0
#
# [5 rows x 15 columns]

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_new', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Gender', 'Embarked_Q',
#        'Embarked_S', 'Family_Size'],
#       dtype='object')

# %%
data1['Fare_Per_Person'] = data1['Fare']/(data1['Family_Size'] + 1 )

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked_S Family_Size  Fare_Per_Person
# 0            1         0       3  ...          1           1          3.62500
# 1            2         1       1  ...          0           1         35.64165
# 2            3         1       3  ...          1           0          7.92500
# 3            4         1       1  ...          1           1         26.55000
# 4            5         0       3  ...          1           0          8.05000
#
# [5 rows x 16 columns]
