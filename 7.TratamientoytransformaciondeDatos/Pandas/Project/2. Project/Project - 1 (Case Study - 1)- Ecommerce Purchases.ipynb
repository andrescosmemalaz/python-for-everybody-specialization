# %% [markdown]
# # ***Ecommerce Purchases***

# %% [markdown]
# https://www.kaggle.com/utkarsharya/ecommerce-purchases

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Tratamiento y transformación de Datos/Pandas/Project/2. Project /Ecommerce Purchases.csv')

# %%
data
# Out:
#                                                 Address  ... Purchase Price
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  ...          98.14
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  ...          70.73
# 2                      Unit 0065 Box 5052\nDPO AP 27450  ...           0.95
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  ...          78.04
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  ...          77.82
# ...                                                 ...  ...            ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  ...          82.21
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  ...          25.63
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  ...          83.98
# 9998               0096 English Rest\nRoystad, IA 12457  ...          38.84
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  ...          67.59
#
# [10000 rows x 14 columns]

# %% [markdown]
# # ***1. Display Top 10 Rows of The Dataset***

# %%
data.head(10)
# Out:
#                                              Address  ... Purchase Price
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  ...          98.14
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  ...          70.73
# 2                   Unit 0065 Box 5052\nDPO AP 27450  ...           0.95
# 3              7780 Julia Fords\nNew Stacy, WA 45798  ...          78.04
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  ...          77.82
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  ...          25.15
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  ...          88.56
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  ...          44.25
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  ...          59.54
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  ...          95.63
#
# [10 rows x 14 columns]

# %% [markdown]
# # ***2. Check Last 10 Rows of The Dataset***

# %%
data.tail(10)
# Out:
#                                                 Address  ... Purchase Price
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  ...          18.35
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  ...          25.93
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  ...          67.96
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  ...          65.61
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  ...          31.85
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  ...          82.21
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  ...          25.63
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  ...          83.98
# 9998               0096 English Rest\nRoystad, IA 12457  ...          38.84
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  ...          67.59
#
# [10 rows x 14 columns]

# %% [markdown]
# # **`*3. Check Datatype of Each Column*`**

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# # ***4. Check null values in the dataset***

# %%
data.isnull()
# Out:
#       Address    Lot  AM or PM  ...  IP Address  Language  Purchase Price
# 0       False  False     False  ...       False     False           False
# 1       False  False     False  ...       False     False           False
# 2       False  False     False  ...       False     False           False
# 3       False  False     False  ...       False     False           False
# 4       False  False     False  ...       False     False           False
# ...       ...    ...       ...  ...         ...       ...             ...
# 9995    False  False     False  ...       False     False           False
# 9996    False  False     False  ...       False     False           False
# 9997    False  False     False  ...       False     False           False
# 9998    False  False     False  ...       False     False           False
# 9999    False  False     False  ...       False     False           False
#
# [10000 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# # ***5. How many rows and columns are there in our Dataset? ***

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 14

# %%
len(data)
# Out:
# 10000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# # ***6. Highest and Lowest Purchase Prices***

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['Purchase Price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# # ***7. Average Purchase Price***

# %%
data['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# # ***¿Cuántas personas tienen el francés 'fr' como idioma?***

# %%
data['Language']
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
#         ..
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
data['Language'] == "fr"
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Language, Length: 10000, dtype: bool

# %%
data[data['Language'] == "fr"]
# Out:
#                                                 Address  ... Purchase Price
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  ...          70.73
# 19                  125 Hall Summit\nBoothton, IL 41721  ...          58.39
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  ...          10.41
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  ...          57.34
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  ...          49.04
# ...                                                 ...  ...            ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  ...          60.03
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  ...          49.61
# 9951                518 Brown Dam\nGarciaside, IN 33057  ...          57.59
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  ...          94.93
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  ...          16.05
#
# [1097 rows x 14 columns]

# %%
len(data[data['Language'] == "fr"])
# Out:
# 1097

# %%
z  = data[data['Language'] == "fr"].count()

# %%
z
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %% [markdown]
# # ***9. El puesto de trabajo contiene ingeniero***

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['Job']
# Out:
# 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: object

# %%
data['Job'].str.contains("engineer")
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
data[data['Job'].str.contains("engineer",case = False)]
# Out:
#                                                 Address  ... Purchase Price
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  ...          70.73
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  ...          78.04
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  ...          36.85
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  ...          48.74
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  ...          20.43
# ...                                                 ...  ...            ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  ...          71.89
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  ...          39.63
# 9970              0060 Keith Stream\nWestport, CO 47097  ...          17.76
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  ...          94.93
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  ...          25.63
#
# [984 rows x 14 columns]

# %%
len(data[data['Job'].str.contains("engineer",case = False)])
# Out:
# 984

# %% [markdown]
# # ***10. Busque el correo electrónico de la persona con la siguiente dirección IP: 132.207.160.22***

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['IP Address']
# Out:
# 0       149.146.147.205
# 1          15.160.41.51
# 2        132.207.160.22
# 3          30.250.74.19
# 4          24.140.33.94
#              ...
# 9995      29.73.197.114
# 9996     121.133.168.51
# 9997      156.210.0.254
# 9998       55.78.26.143
# 9999    176.119.198.199
# Name: IP Address, Length: 10000, dtype: object

# %%
data['IP Address'] == '132.207.160.22'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: IP Address, Length: 10000, dtype: bool

# %%
data[data['IP Address'] == '132.207.160.22']
# Out:
#                             Address    Lot  ... Language Purchase Price
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE  ...       de           0.95
#
# [1 rows x 14 columns]

# %%
data[data['IP Address'] == '132.207.160.22']['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# # ***11.  ¿Cuántas personas tienen Mastercard como su proveedor de tarjeta de crédito y realizaron una compra por encima de 50?***

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['CC Provider']
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: CC Provider, Length: 10000, dtype: object

# %%
data['CC Provider'] == "Mastercard"
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Provider, Length: 10000, dtype: bool

# %%
data[data['CC Provider'] == "Mastercard"]
# Out:
#                                                 Address  ... Purchase Price
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  ...          70.73
# 18    461 Christopher Square\nWest Michaelchester, C...  ...          70.15
# 31                     USNS Alvarado\nFPO AA 27052-1231  ...          94.14
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  ...          97.46
# 41    779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  ...          23.06
# ...                                                 ...  ...            ...
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  ...          49.61
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  ...          71.89
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  ...          87.15
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  ...          63.61
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  ...          60.83
#
# [816 rows x 14 columns]

# %%
(data['CC Provider'] == "Mastercard") & (data['Purchase Price'] > 50)
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
data[(data['CC Provider'] == "Mastercard") & (data['Purchase Price'] > 50)]
# Out:
#                                                 Address  ... Purchase Price
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  ...          70.73
# 18    461 Christopher Square\nWest Michaelchester, C...  ...          70.15
# 31                     USNS Alvarado\nFPO AA 27052-1231  ...          94.14
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  ...          97.46
# 90          431 Bowen Lights\nFergusonborough, MH 01362  ...          78.86
# ...                                                 ...  ...            ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  ...          60.03
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  ...          71.89
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  ...          87.15
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  ...          63.61
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  ...          60.83
#
# [405 rows x 14 columns]

# %%
len(data[(data['CC Provider'] == "Mastercard") & (data['Purchase Price'] > 50)])
# Out:
# 405

# %%
data[(data['CC Provider'] == "Mastercard") & (data['Purchase Price'] > 50)].count()
# Out:
# Address             405
# Lot                 405
# AM or PM            405
# Browser Info        405
# Company             405
# Credit Card         405
# CC Exp Date         405
# CC Security Code    405
# CC Provider         405
# Email               405
# Job                 405
# IP Address          405
# Language            405
# Purchase Price      405
# dtype: int64

# %% [markdown]
# # ***12. Find the email of the person with the following Credit Card Number: 4664825258997302***

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['Credit Card']
# Out:
# 0       6011929061123406
# 1       3337758169645356
# 2           675957666125
# 3       6011578504430710
# 4       6011456623207998
#               ...
# 9995     342945015358701
# 9996     210033169205009
# 9997    6011539787356311
# 9998     180003348082930
# 9999    4139972901927273
# Name: Credit Card, Length: 10000, dtype: int64

# %%
data['Credit Card'] == 4664825258997302
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Credit Card, Length: 10000, dtype: bool

# %%
data[data['Credit Card'] == 4664825258997302]
# Out:
#                                                 Address  ... Purchase Price
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  ...          67.96
#
# [1 rows x 14 columns]

# %%
data[data['Credit Card'] == 4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %% [markdown]
# # ***13. How many people purchase during the AM and how many people purchase during PM?***

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['AM or PM']
# Out:
# 0       PM
# 1       PM
# 2       PM
# 3       PM
# 4       AM
#         ..
# 9995    PM
# 9996    AM
# 9997    AM
# 9998    PM
# 9999    AM
# Name: AM or PM, Length: 10000, dtype: object

# %%
data['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# # ***14. How many people have a credit card that expires in 2020?***

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
def fun():
  count = 0
  for date in data['CC Exp Date']:
    if date.split('/')[1] == '20':
      count = count + 1
  print(count)

# %%
fun()
# Out:
# 988

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
data['CC Exp Date'].apply(lambda x:x[3:] == '20')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Exp Date, Length: 10000, dtype: bool

# %%
data[data['CC Exp Date'].apply(lambda x:x[3:] == '20')]
# Out:
#                                                 Address  ... Purchase Price
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  ...          98.14
# 19                  125 Hall Summit\nBoothton, IL 41721  ...          58.39
# 32                     Unit 3628 Box 6778\nDPO AE 72362  ...          56.63
# 36    9374 Skinner Common Apt. 254\nChristopherfort,...  ...           9.77
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  ...          30.07
# ...                                                 ...  ...            ...
# 9883        751 Petersen Groves\nLake Rebecca, NM 55875  ...          67.47
# 9901      908 Norman Burgs\nPhillipsberg, VT 92023-9956  ...          57.25
# 9911  44320 Gray Centers Suite 325\nJenniferfurt, OK...  ...          20.63
# 9957             73556 Chase Pine\nBrucemouth, MP 73473  ...          71.85
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  ...          67.96
#
# [988 rows x 14 columns]

# %%
len(data[data['CC Exp Date'].apply(lambda x:x[3:] == '20')])
# Out:
# 988

# %% [markdown]
# # ***15. What are the top 5 most popular email providers (e.g. gmail.com, yahoo.com, etc...) ***

# %%
list1 = []
for email in data['Email']:
  list1.append(email.split('@')[1])

# %%
data['temp'] = list1

# %%
data['temp']
# Out:
# 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: temp, Length: 10000, dtype: object

# %%
data['temp'].value_counts()
# Out:
# hotmail.com              1638
# yahoo.com                1616
# gmail.com                1605
# smith.com                  42
# williams.com               37
#                          ...
# juarez.info                 1
# frazier-zimmerman.net       1
# rogers-hayes.info           1
# kline.info                  1
# cowan.net                   1
# Name: temp, Length: 3416, dtype: int64

# %%
data['temp'].value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: temp, dtype: int64

# %%
data.head(1)
# Out:
#                                              Address  ...       temp
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  ...  yahoo.com
#
# [1 rows x 15 columns]

# %%
data['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
data['Email'].apply(lambda x:x.split('@')[1]).value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
