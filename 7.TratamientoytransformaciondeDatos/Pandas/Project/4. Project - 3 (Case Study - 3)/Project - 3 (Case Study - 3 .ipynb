# %% [markdown]
# Los ingresos anuales de un individuo son el resultado de varios factores. Intuitivamente, está influenciado por el nivel de educación del individuo, la edad, el género, la ocupación, etc.
#
# Este es un conjunto de datos KNN muy citado. Lo encontré durante mi curso, y deseo compartirlo aquí porque es un buen ejemplo de inicio para el preprocesamiento de datos y las prácticas de aprendizaje automático.
#
# Campos
# El conjunto de datos contiene 16 columnas
# Objetivo archivado: Ingresos
# -- Los ingresos se dividen en dos clases: <=50K y >50K
# Número de atributos: 14
# -- Estos son los datos demográficos y otras características para describir a una persona
#
# Podemos explorar la posibilidad de predecir el nivel de ingresos basándonos en la información personal del individuo.
#
# Agradecimientos
# Este conjunto de datos denominado "adulto" se encuentra en el repositorio de aprendizaje automático de la UCI
# http://www.cs.toronto.edu/~delve/data/adult/desc.html
#
# La descripción detallada del conjunto de datos puede encontrarse en la documentación original de la UCI
# http://www.cs.toronto.edu/~delve/data/adult/adultDetail.html

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Tratamiento y transformación de Datos/Pandas/Project/4. Project - 3 (Case Study - 3)/adult.csv")

# %%
data
# Out:
#        age     workclass  fnlwgt  ... hours-per-week  native-country income
# 0       25       Private  226802  ...             40   United-States  <=50K
# 1       38       Private   89814  ...             50   United-States  <=50K
# 2       28     Local-gov  336951  ...             40   United-States   >50K
# 3       44       Private  160323  ...             40   United-States   >50K
# 4       18             ?  103497  ...             30   United-States  <=50K
# ...    ...           ...     ...  ...            ...             ...    ...
# 48837   27       Private  257302  ...             38   United-States  <=50K
# 48838   40       Private  154374  ...             40   United-States   >50K
# 48839   58       Private  151910  ...             40   United-States  <=50K
# 48840   22       Private  201490  ...             20   United-States  <=50K
# 48841   52  Self-emp-inc  287927  ...             40   United-States   >50K
#
# [48842 rows x 15 columns]

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  ... hours-per-week  native-country income
# 0   25    Private  226802  ...             40   United-States  <=50K
# 1   38    Private   89814  ...             50   United-States  <=50K
# 2   28  Local-gov  336951  ...             40   United-States   >50K
# 3   44    Private  160323  ...             40   United-States   >50K
# 4   18          ?  103497  ...             30   United-States  <=50K
#
# [5 rows x 15 columns]

# %% [markdown]
# # ***1.Display Top 10 Rows of The Dataset***

# %%
data.head(10)
# Out:
#    age         workclass  fnlwgt  ... hours-per-week  native-country income
# 0   25           Private  226802  ...             40   United-States  <=50K
# 1   38           Private   89814  ...             50   United-States  <=50K
# 2   28         Local-gov  336951  ...             40   United-States   >50K
# 3   44           Private  160323  ...             40   United-States   >50K
# 4   18                 ?  103497  ...             30   United-States  <=50K
# 5   34           Private  198693  ...             30   United-States  <=50K
# 6   29                 ?  227026  ...             40   United-States  <=50K
# 7   63  Self-emp-not-inc  104626  ...             32   United-States   >50K
# 8   24           Private  369667  ...             40   United-States  <=50K
# 9   55           Private  104996  ...             10   United-States  <=50K
#
# [10 rows x 15 columns]

# %% [markdown]
# # ***2. Check Last 10 Rows of The Dataset***

# %%
data.tail(10)
# Out:
#        age     workclass  fnlwgt  ... hours-per-week  native-country income
# 48832   32       Private   34066  ...             40   United-States  <=50K
# 48833   43       Private   84661  ...             45   United-States  <=50K
# 48834   32       Private  116138  ...             11          Taiwan  <=50K
# 48835   53       Private  321865  ...             40   United-States   >50K
# 48836   22       Private  310152  ...             40   United-States  <=50K
# 48837   27       Private  257302  ...             38   United-States  <=50K
# 48838   40       Private  154374  ...             40   United-States   >50K
# 48839   58       Private  151910  ...             40   United-States  <=50K
# 48840   22       Private  201490  ...             20   United-States  <=50K
# 48841   52  Self-emp-inc  287927  ...             40   United-States   >50K
#
# [10 rows x 15 columns]

# %% [markdown]
# # ***3. Find Shape of Our Dataset (Number of Rows And Number of Columns)***

# %%
data.shape
# Out:
# (48842, 15)

# %%
print("Número de filas ",data.shape[0])
print("Número de columnas ",data.shape[1])
# Out:
# Número de filas  48842
# Número de columnas  15

# %% [markdown]
# # ***4. Getting Information About Our Dataset Like Total Number Rows, Total Number of  Columns, Datatypes of Each Column And Memory Requirement ***

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # ***5. Fetch Random Sample From the Dataset (50%)***

# %%
data.sample(frac=0.5)
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country income
# 29729   60           Private  103344  ...             40   United-States   >50K
# 24588   29           Private  194864  ...             18   United-States  <=50K
# 11190   55         Local-gov  193895  ...             38   United-States  <=50K
# 15686   51           Private  155963  ...             40   United-States  <=50K
# 37720   47       Federal-gov   98726  ...             40   United-States  <=50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 20652   29           Private   52636  ...             40   United-States  <=50K
# 34997   25         Local-gov  203408  ...             40   United-States  <=50K
# 23649   36  Self-emp-not-inc  135416  ...             50   United-States  <=50K
# 44117   24           Private   91999  ...             20   United-States  <=50K
# 38721   36           Private  336367  ...             50   United-States  <=50K
#
# ...

# %%
data.sample(frac=0.5,random_state=100) #Para dejar estatico la asignacián aleatoria
# Out:
#        age  workclass  fnlwgt  ... hours-per-week  native-country income
# 12393   37    Private  110331  ...             60   United-States   >50K
# 48701   23    Private   45834  ...             50   United-States  <=50K
# 17918   28    Private   89718  ...             48   United-States  <=50K
# 11352   30    Private  351770  ...             38   United-States  <=50K
# 36198   31    Private  164190  ...             40   United-States  <=50K
# ...    ...        ...     ...  ...            ...             ...    ...
# 48573   41    Private  318046  ...             48   United-States   >50K
# 47252   41  Local-gov   33658  ...             45   United-States   >50K
# 33142   69    Private  312653  ...             25   United-States  <=50K
# 2965    21          ?  334593  ...             40   United-States  <=50K
# 32089   34    Private  186269  ...             40   United-States  <=50K
#
# [24421 rows x 15 columns]

# %%
data_extraída_aleatoriamente = data.sample(frac=0.5,random_state=100)

# %%
data_extraída_aleatoriamente
# Out:
#        age  workclass  fnlwgt  ... hours-per-week  native-country income
# 12393   37    Private  110331  ...             60   United-States   >50K
# 48701   23    Private   45834  ...             50   United-States  <=50K
# 17918   28    Private   89718  ...             48   United-States  <=50K
# 11352   30    Private  351770  ...             38   United-States  <=50K
# 36198   31    Private  164190  ...             40   United-States  <=50K
# ...    ...        ...     ...  ...            ...             ...    ...
# 48573   41    Private  318046  ...             48   United-States   >50K
# 47252   41  Local-gov   33658  ...             45   United-States   >50K
# 33142   69    Private  312653  ...             25   United-States  <=50K
# 2965    21          ?  334593  ...             40   United-States  <=50K
# 32089   34    Private  186269  ...             40   United-States  <=50K
#
# [24421 rows x 15 columns]

# %% [markdown]
# # ***6.Check Null Values In The Dataset***

# %%
data.isnull()
# Out:
#          age  workclass  fnlwgt  ...  hours-per-week  native-country  income
# 0      False      False   False  ...           False           False   False
# 1      False      False   False  ...           False           False   False
# 2      False      False   False  ...           False           False   False
# 3      False      False   False  ...           False           False   False
# 4      False       True   False  ...           False           False   False
# ...      ...        ...     ...  ...             ...             ...     ...
# 48837  False      False   False  ...           False           False   False
# 48838  False      False   False  ...           False           False   False
# 48839  False      False   False  ...           False           False   False
# 48840  False      False   False  ...           False           False   False
# 48841  False      False   False  ...           False           False   False
#
# [48842 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum(axis=0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# # ***7.Perform Data Cleaning [ Replace '?' with NaN ]***

# %% [markdown]
# 7.Realice la limpieza de datos [Reemplazar '?' con NaN]

# %%
data.tail(20)
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country income
# 48822   41               NaN  202822  ...             32   United-States  <=50K
# 48823   72               NaN  129912  ...             25   United-States  <=50K
# 48824   45         Local-gov  119199  ...             48   United-States  <=50K
# 48825   31           Private  199655  ...             30   United-States  <=50K
# 48826   39         Local-gov  111499  ...             20   United-States   >50K
# 48827   37           Private  198216  ...             40   United-States  <=50K
# 48828   43           Private  260761  ...             40          Mexico  <=50K
# 48829   65  Self-emp-not-inc   99359  ...             60   United-States  <=50K
# 48830   43         State-gov  255835  ...             40   United-States  <=50K
# 48831   43  Self-emp-not-inc   27242  ...             50   United-States  <=50K
# 48832   32           Private   34066  ...             40   United-States  <=50K
# ...

# %%
data.isin(['?'])
# Out:
#          age  workclass  fnlwgt  ...  hours-per-week  native-country  income
# 0      False      False   False  ...           False           False   False
# 1      False      False   False  ...           False           False   False
# 2      False      False   False  ...           False           False   False
# 3      False      False   False  ...           False           False   False
# 4      False      False   False  ...           False           False   False
# ...      ...        ...     ...  ...             ...             ...     ...
# 48837  False      False   False  ...           False           False   False
# 48838  False      False   False  ...           False           False   False
# 48839  False      False   False  ...           False           False   False
# 48840  False      False   False  ...           False           False   False
# 48841  False      False   False  ...           False           False   False
#
# [48842 rows x 15 columns]

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
import numpy as np

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['workclass'] = data['workclass'].replace('?',np.nan) # Es la nomenclatura para reemplazar. se debe guardar en la misma data, de lo contrario no se mantiende los datos
data['occupation'] = data['occupation'].replace('?',np.nan) 
data['native-country'] = data['native-country'].replace('?',np.nan)

# %%
data.isin(['?'])
# Out:
#          age  workclass  fnlwgt  ...  hours-per-week  native-country  income
# 0      False      False   False  ...           False           False   False
# 1      False      False   False  ...           False           False   False
# 2      False      False   False  ...           False           False   False
# 3      False      False   False  ...           False           False   False
# 4      False      False   False  ...           False           False   False
# ...      ...        ...     ...  ...             ...             ...     ...
# 48837  False      False   False  ...           False           False   False
# 48838  False      False   False  ...           False           False   False
# 48839  False      False   False  ...           False           False   False
# 48840  False      False   False  ...           False           False   False
# 48841  False      False   False  ...           False           False   False
#
# [48842 rows x 15 columns]

# %%
data.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# # ***8. Drop all The Missing Values***

# %%
per_missing = data.isnull().sum() * 100/len(data)

# %%
per_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
data.dropna(how='any',inplace = True)
data.shape
# Out:
# (45222, 15)

# %%
per_missing = data.isnull().sum() * 100/len(data)

# %%
per_missing
# Out:
# age                0.0
# workclass          0.0
# fnlwgt             0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %% [markdown]
# # ***9. Check For Duplicate Data and Drop Them***

# %%
dup = data.duplicated().any()

# %%
print("Are there any duplicated values in data",dup)
# Out:
# Are there any duplicated values in data True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (45175, 15)

# %% [markdown]
# # ***10. Get Overall statics About The Dataframe ***

# %%
data.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  45175.000000  4.517500e+04  ...  45175.000000    45175.000000
# mean      38.556170  1.897388e+05  ...     88.687593       40.942512
# std       13.215349  1.056524e+05  ...    405.156611       12.007730
# min       17.000000  1.349200e+04  ...      0.000000        1.000000
# 25%       28.000000  1.173925e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783120e+05  ...      0.000000       40.000000
# 75%       47.000000  2.379030e+05  ...      0.000000       45.000000
# max       90.000000  1.490400e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %%
data.describe(include='all')
# Out:
#                  age workclass  ...  native-country income
# count   45175.000000     45175  ...           45175  45175
# unique           NaN         7  ...              41      2
# top              NaN   Private  ...   United-States  <=50K
# freq             NaN     33262  ...           41256  33973
# mean       38.556170       NaN  ...             NaN    NaN
# std        13.215349       NaN  ...             NaN    NaN
# min        17.000000       NaN  ...             NaN    NaN
# 25%        28.000000       NaN  ...             NaN    NaN
# 50%        37.000000       NaN  ...             NaN    NaN
# 75%        47.000000       NaN  ...             NaN    NaN
# max        90.000000       NaN  ...             NaN    NaN
#
# [11 rows x 15 columns]

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
data['educational-num'].unique()
# Out:
# array([ 7,  9, 12, 10,  6, 15,  4, 13, 14,  3, 11,  5, 16,  8,  2,  1])

# %% [markdown]
# # **11. Drop The Columns número de educación, ganancia de capital y pérdida de capital**

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data = data.drop(['educational-num','capital-gain','capital-loss'], axis=1)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %% [markdown]
# # ***Univariate Analysis***

# %% [markdown]
# # ***12. What Is The Distribution of Age Column?***

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data['age'].hist()

# %% [markdown]
# # ***13. Encuentre el número total de personas que tienen entre 17 y 48 años (inclusive) utilizando el método Between***

# %%
(data['age'] >= 17) & (data['age'] <=48)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 5         True
#          ...
# 48837     True
# 48838     True
# 48839    False
# 48840     True
# 48841    False
# Name: age, Length: 45175, dtype: bool

# %%
sum((data['age'] >= 17) & (data['age'] <=48))
# Out:
# 34858

# %%
data['age'].between(17,48)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 5         True
#          ...
# 48837     True
# 48838     True
# 48839    False
# 48840     True
# 48841    False
# Name: age, Length: 45175, dtype: bool

# %%
sum(data['age'].between(17,48))
# Out:
# 34858

# %% [markdown]
# # ***14. What is The Distribution of Workclass Column?***

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data['workclass']
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 45175, dtype: object

# %%
data['workclass'].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
plt.figure(figsize=(10,10))
data['workclass'].hist()

# %% [markdown]
# 15. ¿Cuántas personas tienen licenciatura y maestría?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
filter1 = data['education'] == 'Bachelors'
filter2 = data['education'] == 'Masters'

# %%
filter1 | filter2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: education, Length: 45175, dtype: bool

# %%
data[filter1 | filter2]
# Out:
#        age    workclass  fnlwgt  ... hours-per-week native-country income
# 11      36  Federal-gov  212465  ...             40  United-States  <=50K
# 15      43      Private  346189  ...             50  United-States   >50K
# 20      34      Private  107914  ...             47  United-States   >50K
# 23      25      Private  220931  ...             43           Peru  <=50K
# 24      25      Private  205947  ...             40  United-States  <=50K
# ...    ...          ...     ...  ...            ...            ...    ...
# 48817   34      Private  160216  ...             55  United-States   >50K
# 48819   38      Private  139180  ...             45  United-States   >50K
# 48825   31      Private  199655  ...             30  United-States  <=50K
# 48834   32      Private  116138  ...             11         Taiwan  <=50K
# 48835   53      Private  321865  ...             40  United-States   >50K
#
# [10072 rows x 12 columns]

# %%
len(data[filter1 | filter2])
# Out:
# 10072

# %%
data['education'].isin(['Bachelors','Masters'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: education, Length: 45175, dtype: bool

# %%
len(data['education'].isin(['Bachelors','Masters']))
# Out:
# 45175

# %% [markdown]
# # ***16. Bivariate Analsis***

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
sns.boxplot(x='income',y='age',data=data)

# %% [markdown]
# # **17. Reemplazar los valores salariales con 0 y 1**

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
data['income'].value_counts()
# Out:
# <=50K    33973
# >50K     11202
# Name: income, dtype: int64

# %%
sns.countplot('income',data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def salary_data(sal):
  if sal == '<=50K':
    return 0
  else:
    return 1

# %%
data['encoded_income'] = data['income'].apply(salary_data)

# %%
data['income']
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 5        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 45175, dtype: object

# %%
data.head(1)
# Out:
#    age workclass  fnlwgt  ... native-country income encoded_income
# 0   25   Private  226802  ...  United-States  <=50K              0
#
# [1 rows x 13 columns]

# %%
data['encoded_income']
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 5        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: encoded_income, Length: 45175, dtype: int64

# %% [markdown]
# 18. ¿Qué clase de trabajo obtiene el salario más alto?

# %%
data.groupby('workclass')['encoded_income'].mean()
# Out:
# workclass
# Federal-gov         0.390469
# Local-gov           0.295161
# Private             0.217816
# Self-emp-inc        0.554407
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Without-pay         0.095238
# Name: encoded_income, dtype: float64

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  ... native-country income encoded_income
# 0   25    Private  226802  ...  United-States  <=50K              0
# 1   38    Private   89814  ...  United-States  <=50K              0
# 2   28  Local-gov  336951  ...  United-States   >50K              1
# 3   44    Private  160323  ...  United-States   >50K              1
# 5   34    Private  198693  ...  United-States  <=50K              0
#
# [5 rows x 13 columns]

# %%
data.groupby('workclass')['encoded_income'].mean()
# Out:
# workclass
# Federal-gov         0.390469
# Local-gov           0.295161
# Private             0.217816
# Self-emp-inc        0.554407
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Without-pay         0.095238
# Name: encoded_income, dtype: float64

# %%
data.groupby('workclass')['encoded_income'].mean().sort_values()
# Out:
# workclass
# Without-pay         0.095238
# Private             0.217816
# State-gov           0.267215
# Self-emp-not-inc    0.279051
# Local-gov           0.295161
# Federal-gov         0.390469
# Self-emp-inc        0.554407
# Name: encoded_income, dtype: float64

# %%
data.groupby('workclass')['encoded_income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554407
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Private             0.217816
# Without-pay         0.095238
# Name: encoded_income, dtype: float64

# %%
data.groupby('workclass')['encoded_income'].mean().sort_values(ascending=True)
# Out:
# workclass
# Without-pay         0.095238
# Private             0.217816
# State-gov           0.267215
# Self-emp-not-inc    0.279051
# Local-gov           0.295161
# Federal-gov         0.390469
# Self-emp-inc        0.554407
# Name: encoded_income, dtype: float64

# %% [markdown]
# 19.¿Quién tiene más posibilidades de obtener un salario superior a 50 mil hombres o mujeres?

# %%
data.groupby('gender')['encoded_income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.312609
# Female    0.113692
# Name: encoded_income, dtype: float64

# %% [markdown]
# 20. Convertir el tipo de datos de las columnas de la clase de trabajo en un tipo de datos de categoría

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  object
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  object
#  12  encoded_income  45175 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 6.1+ MB

# %%
data['workclass'].astype('category')
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 45175, dtype: category
# Categories (7, object): ['Federal-gov', 'Local-gov', 'Private', 'Self-emp-inc', 'Self-emp-not-inc',
#                          'State-gov', 'Without-pay']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  object
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  object
#  12  encoded_income  45175 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 6.1+ MB
