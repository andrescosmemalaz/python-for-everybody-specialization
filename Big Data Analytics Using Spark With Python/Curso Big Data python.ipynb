# %% [markdown]
# https://grouplens.org/datasets/movielens/

# %% [markdown]
# https://www.youtube.com/watch?v=qdnosZ9Bl_o&list=PLMF23FOyQZQtIUBt5H_CZguSTvYX6O9Re&index=7

# %%
pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 281.3 MB 39 kB/s
# ...
#      |████████████████████████████████| 198 kB 13.4 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805912 sha256=260258091a5c16e2cc0a12632472461f8ec2a8d805077b5426b936ffcb44e881
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %%
spark = SparkSession.builder.appName('Pyspark').getOrCreate()

# %%
from pyspark import SparkConf, SparkContext
import collections

# %%
conf = SparkConf().setMaster('local').setAppName('RatingsHistogram')
sc = SparkContext(conf = conf)

lines = sc.textFile("/content/drive/MyDrive/Python/Curso de Técnicas de Operaciones /coursera-python-for-everybody-specialization/Big Data Analytics Using Spark With Python /ml-100k/u.data")
ratings = lines.map(lambda x: x.split()[2])
result = ratings.countByValue()

sortedResults = collections.OrderedDict(sorted(result.items()))
for key, value in sortedResults.items():
  print('%s %i'%(key,value))
