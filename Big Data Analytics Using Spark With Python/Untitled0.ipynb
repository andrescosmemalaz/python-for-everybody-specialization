# %%
pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 281.3 MB 40 kB/s
# ...
#      |████████████████████████████████| 198 kB 42.9 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805912 sha256=3a312faf3128ea195026954eb3470bd96d12422556a4081d3e2eacc9f4de593c
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# ...

# %%
# https://www.youtube.com/watch?v=bmvpZ7uSa68&list=PL_1pt6K-CLoCBM0bljTg_8rFIov4Is_12&index=3

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Pyspark').getOrCreate()

# %%
spark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-84901cd22f32> in <module>()
# ----> 1 spark
#
# NameError: name 'spark' is not defined

# %%
df = spark.read.csv('')
